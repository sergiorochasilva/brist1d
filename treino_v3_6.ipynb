# %% [markdown]
# # Brist1D - Kaggle competition

# %% [markdown]
# ## Loading and hadling dataset

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('dataset/train.csv', header=0)
print(df.shape)
df.head(5)
# Out:
# /tmp/ipykernel_29939/722352279.py:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset/train.csv', header=0)
# (177024, 508)
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:40  activity-0:35  activity-0:30  \
# 0      9.7      NaN  ...            NaN            NaN            NaN
# 1      9.2      NaN  ...            NaN            NaN            NaN
# 2      8.7      NaN  ...            NaN            NaN            NaN
# 3      8.4      NaN  ...            NaN            NaN            NaN
# 4      8.1      NaN  ...            NaN            NaN            NaN
#
#    activity-0:25  activity-0:20  activity-0:15  activity-0:10  activity-0:05  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    activity-0:00  bg+1:00
# 0            NaN     13.4
# 1            NaN     12.8
# 2            NaN     15.5
# 3            NaN     14.8
# 4            NaN     12.7
#
# [5 rows x 508 columns]

# %% [markdown]
# ## Filtering desired collumns (based on a correlation analises)

# %%
def filter_desired_columns(data, include_target: bool = True):
    desired_columns = [
        "id", "p_num", "time",
        "bg-0:00", "bg-0:05", "bg-0:10", "bg-0:15", "bg-0:20", "bg-0:25", "bg-0:30", "bg-0:35", "bg-0:40", "bg-0:45",
        "insulin-0:00", "insulin-0:05", "insulin-0:10", "insulin-0:15", "insulin-0:20",
        "hr-0:00", "hr-0:05", "hr-0:10", "hr-0:15", "hr-0:20", "hr-0:25", "hr-0:30",
        "steps-0:00", "steps-0:05", "steps-0:10", "steps-0:15",
        "cals-0:00", "cals-0:05",
    ]

    if include_target:
        desired_columns.append("bg+1:00")
        
    return data[desired_columns]

df = filter_desired_columns(df)
df.head(5)
# Out:
#       id p_num      time  bg-0:00  bg-0:05  bg-0:10  bg-0:15  bg-0:20  \
# 0  p01_0   p01  06:10:00     15.1      NaN      NaN     16.2      NaN
# 1  p01_1   p01  06:25:00     14.4      NaN      NaN     15.1      NaN
# 2  p01_2   p01  06:40:00     13.9      NaN      NaN     14.4      NaN
# 3  p01_3   p01  06:55:00     13.8      NaN      NaN     13.9      NaN
# 4  p01_4   p01  07:10:00     13.4      NaN      NaN     13.8      NaN
#
#    bg-0:25  bg-0:30  ...  hr-0:20  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0      NaN     17.3  ...      NaN      NaN      NaN         NaN         NaN
# 1      NaN     16.2  ...      NaN      NaN      NaN         NaN         NaN
# 2      NaN     15.1  ...      NaN      NaN      NaN         NaN         NaN
# 3      NaN     14.4  ...      NaN      NaN      NaN         NaN         NaN
# 4      NaN     13.9  ...      NaN      NaN      NaN         NaN         NaN
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  bg+1:00
# 0         NaN         NaN        NaN        NaN     13.4
# 1         NaN         NaN        NaN        NaN     12.8
# 2         NaN         NaN        NaN        NaN     15.5
# 3         NaN         NaN        NaN        NaN     14.8
# 4         NaN         NaN        NaN        NaN     12.7
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Filling missing values

# %%
columns_to_fill = [
    "bg-0:00", "bg-0:05", "bg-0:10", "bg-0:15", "bg-0:20", "bg-0:25", "bg-0:30", "bg-0:35", "bg-0:40", "bg-0:45",
    "insulin-0:00", "insulin-0:05", "insulin-0:10", "insulin-0:15", "insulin-0:20",
    "hr-0:00", "hr-0:05", "hr-0:10", "hr-0:15", "hr-0:20", "hr-0:25", "hr-0:30",
    "steps-0:00", "steps-0:05", "steps-0:10", "steps-0:15",
    "cals-0:00", "cals-0:05",
]

df[columns_to_fill] = df[columns_to_fill].interpolate()

# %%
imputer = SimpleImputer()

df[columns_to_fill] = imputer.fit_transform(df[columns_to_fill])

# %% [markdown]
# ## Converting time into sin and cos pair

# %% [markdown]
# ### Converting time to minutes

# %%
df['minutes_since_start'] = pd.to_datetime(df['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(df['time'], format="%H:%M:%S").dt.minute
df = df.drop(columns=['time'])

# %% [markdown]
# ### Converting minutes to sin and cos pair (summing constant 2, to avoid zero values)

# %%
df["time_sin"] = np.sin(2 * np.pi / 1440 * df['minutes_since_start']) + 2
df["time_cos"] = np.cos(2 * np.pi / 1440 * df['minutes_since_start']) + 2
df = df.drop(columns=['minutes_since_start'])
df.head(5)
# Out:
#       id p_num  bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  \
# 0  p01_0   p01     15.1  8.246322  8.33178     16.2  8.258647  8.430463
# 1  p01_1   p01     14.4  8.246322  8.33178     15.1  8.258647  8.430463
# 2  p01_2   p01     13.9  8.246322  8.33178     14.4  8.258647  8.430463
# 3  p01_3   p01     13.8  8.246322  8.33178     13.9  8.258647  8.430463
# 4  p01_4   p01     13.4  8.246322  8.33178     13.8  8.258647  8.430463
#
#    bg-0:30   bg-0:35  ...    hr-0:30  steps-0:00  steps-0:05  steps-0:10  \
# 0     17.3  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 1     16.2  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 2     15.1  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 3     14.4  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 4     13.9  8.268978  ...  81.189919   44.927039   43.967174    43.96972
#
#    steps-0:15  cals-0:00  cals-0:05  bg+1:00  time_sin  time_cos
# 0   45.359472   8.130857   8.147582     13.4  2.999048  1.956381
# 1   45.359472   8.130857   8.147582     12.8  2.994056  1.891133
# 2   45.359472   8.130857   8.147582     15.5  2.984808  1.826352
# 3   45.359472   8.130857   8.147582     14.8  2.971342  1.762314
# 4   45.359472   8.130857   8.147582     12.7  2.953717  1.699294
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Removing ID columns

# %%
cols_to_pop = ['id', 'p_num']
identifiers = df[cols_to_pop].copy()
df = df.drop(columns=cols_to_pop)
df.head(5)
# Out:
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  bg-0:30   bg-0:35  \
# 0     15.1  8.246322  8.33178     16.2  8.258647  8.430463     17.3  8.268978
# 1     14.4  8.246322  8.33178     15.1  8.258647  8.430463     16.2  8.268978
# 2     13.9  8.246322  8.33178     14.4  8.258647  8.430463     15.1  8.268978
# 3     13.8  8.246322  8.33178     13.9  8.258647  8.430463     14.4  8.268978
# 4     13.4  8.246322  8.33178     13.8  8.258647  8.430463     13.9  8.268978
#
#     bg-0:40  bg-0:45  ...    hr-0:30  steps-0:00  steps-0:05  steps-0:10  \
# 0  8.412561     17.5  ...  81.189919   44.927039   43.967174    43.96972
# 1  8.412561     17.3  ...  81.189919   44.927039   43.967174    43.96972
# 2  8.412561     16.2  ...  81.189919   44.927039   43.967174    43.96972
# 3  8.412561     15.1  ...  81.189919   44.927039   43.967174    43.96972
# 4  8.412561     14.4  ...  81.189919   44.927039   43.967174    43.96972
#
#    steps-0:15  cals-0:00  cals-0:05  bg+1:00  time_sin  time_cos
# 0   45.359472   8.130857   8.147582     13.4  2.999048  1.956381
# 1   45.359472   8.130857   8.147582     12.8  2.994056  1.891133
# 2   45.359472   8.130857   8.147582     15.5  2.984808  1.826352
# 3   45.359472   8.130857   8.147582     14.8  2.971342  1.762314
# 4   45.359472   8.130857   8.147582     12.7  2.953717  1.699294
#
# [5 rows x 31 columns]

# %%
df.to_csv("dataset/train_interpolate_circle_causalidade.csv", index=False)

# %% [markdown]
# ## Spliting train and test dataframes

# %%
train = df.sample(frac=0.75, random_state=0)
test = df.drop(train.index)

# %%
x_train = train
y_train = train.pop('bg+1:00')

# %%
print(x_train.shape)
x_train.head(5)
# Out:
# (132768, 30)
#        bg-0:00    bg-0:05    bg-0:10  bg-0:15    bg-0:20    bg-0:25  bg-0:30  \
# 91143      5.9   5.807317   8.354752      6.2   6.854918  11.098182      4.6
# 35758      8.2   8.200000   8.300000      8.5   8.700000   8.900000      8.5
# 65296      6.8   7.200000   7.900000      8.4   8.700000   8.700000      8.4
# 14652     10.5  10.600000  10.700000     10.8  10.900000  10.900000     11.0
# 54561      6.3   6.300000   6.300000      6.3   6.300000   6.300000      6.2
#
#          bg-0:35    bg-0:40  bg-0:45  ...    hr-0:25    hr-0:30  steps-0:00  \
# 91143   6.721488  11.227333      3.8  ...  86.000000  84.600000  518.000000
# 35758   8.400000   8.500000      8.8  ...  76.143817  76.139606   23.021904
# 65296   8.100000   7.900000      6.5  ...  86.300000  83.500000    8.000000
# 14652  11.200000  11.400000     11.4  ...  81.250505  81.045791   27.270000
# 54561   6.200000   6.200000      6.1  ...  53.000000  52.800000    0.000000
#
#        steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  \
# 91143  573.000000  440.000000    12.00000   8.350000   5.410000  1.357212
# 35758   23.077783   23.133661    23.18954   5.600000   5.600000  2.965926
# 65296   11.000000   14.000000    72.00000   7.090000   8.630000  1.123273
# 14652   27.193333   27.116667    27.04000   1.819452   1.817945  2.422618
# 54561    0.000000    0.000000     0.00000   5.720000   5.600000  2.939693
#
#        time_cos
# 91143  2.766044
# 35758  2.258819
# 65296  1.519011
# 14652  2.906308
# 54561  1.657980
#
# [5 rows x 30 columns]

# %%
print(y_train.shape)
y_train.head(5)
# Out:
# (132768,)
# 91143    7.6
# 35758    7.6
# 65296    6.2
# 14652    9.0
# 54561    5.7
# Name: bg+1:00, dtype: float64

# %%
x_train.to_csv("x.csv", index=False)
y_train.to_csv("y.csv", index=False)

# %% [markdown]
# ## Building model

# %% [markdown]
# ### Imports and GPU config

# %%
from keras.layers import TimeDistributed, Dense, Input, Lambda, BatchNormalization, Concatenate, Conv1D, ZeroPadding1D
from keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.callbacks import EarlyStopping
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Configurando para não alocar diretamente toda a memória da GPU (alocar conforme necessário)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)  # Aloca memória conforme necessário
    except RuntimeError as e:
        print(e)
# Out:
# 2024-11-21 15:11:36.470759: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-21 15:11:36.479946: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732212696.489492   29939 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732212696.492306   29939 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-21 15:11:36.501692: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available:  1

# %% [markdown]
# ### Model definition

# %%
def extrator_features(input_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims*4), activation=activation, use_bias=bias, kernel_regularizer="l2")(input_layer)
  # x_1 = tf.keras.layers.Dropout(0.2)(x_0)
  x_2 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_0)
  x_3 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_2)
  x_4 = Dense(int(input_dims*4), activation=activation, use_bias=bias)(x_3)
  x_bottleneck = Dense(int(input_dims), activation=activation, name='encoder', use_bias=bias, kernel_regularizer="l1")(x_4)

  return Model(input_layer, x_bottleneck, name="features")

def regressor(input_dims, output_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims/2), activation=activation, use_bias=bias)(input_layer)
  x_2 = Dense(int(input_dims/4), activation=activation, use_bias=bias)(x_0)
  saidas = Dense(output_dims, activation=None, name='regressor_saidas', use_bias=bias)(x_2)

  return Model(input_layer, saidas, name="regressor")

def build_models(input_dims, output_dims, activation, bias):
  # Camadas de entrada
  input_layer = Input(shape=[input_dims])

  x_n = BatchNormalization()(input_layer)

  # Kernels
  extrator = extrator_features(input_dims, activation, bias)

  # Features
  features = extrator(x_n)

  # Regressão
  regressao = regressor(features.shape[1], output_dims, activation, bias)

  saida = regressao(features)
  
  return (
      Model(input_layer, saida, name="regressao"),
      Model(input_layer, features, name="projecao")
  )

model, features = build_models(x_train.shape[1], 1, 'silu', True)
model.compile(optimizer='adam', loss='mse', metrics=['mae', 'mse', 'mean_absolute_percentage_error'])
plot_model(model, show_shapes=True, expand_nested=True)
# Out:
# I0000 00:00:1732212697.786730   29939 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2269 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# ### Training model

# %%
# Callback para recuperar o melhor peso, e parar quando ficar três épocas sem melhora
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Treinando o modelo
history = model.fit(x_train, y_train, epochs=200, validation_split = 0.2, callbacks=[callback])
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732212699.721822   33846 service.cc:148] XLA service 0x7fe3e0015290 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732212699.721843   33846 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2024-11-21 15:11:39.754884: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1732212699.915947   33846 cuda_dnn.cc:529] Loaded cuDNN version 90501
#  262/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 674us/step - loss: 24.6402 - mae: 3.2790 - mean_absolute_percentage_error: 41.0501 - mse: 20.7621
# I0000 00:00:1732212701.462246   33846 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 8.8680 - mae: 1.8817 - mean_absolute_percentage_error: 24.5751 - mse: 7.0431 - val_loss: 4.5742 - val_mae: 1.5463 - val_mean_absolute_percentage_error: 21.2419 - val_mse: 4.2569
# Epoch 2/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 763us/step - loss: 4.7954 - mae: 1.5977 - mean_absolute_percentage_error: 21.1957 - mse: 4.5342 - val_loss: 4.3001 - val_mae: 1.5158 - val_mean_absolute_percentage_error: 20.0505 - val_mse: 4.1334
# Epoch 3/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 747us/step - loss: 4.6071 - mae: 1.5806 - mean_absolute_percentage_error: 20.8710 - mse: 4.4553 - val_loss: 4.1986 - val_mae: 1.4945 - val_mean_absolute_percentage_error: 19.5323 - val_mse: 4.0755
# Epoch 4/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 751us/step - loss: 4.5213 - mae: 1.5754 - mean_absolute_percentage_error: 20.8392 - mse: 4.4032 - val_loss: 4.2835 - val_mae: 1.5000 - val_mean_absolute_percentage_error: 19.2344 - val_mse: 4.1745
# Epoch 5/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 775us/step - loss: 4.5241 - mae: 1.5746 - mean_absolute_percentage_error: 20.7686 - mse: 4.4196 - val_loss: 4.1072 - val_mae: 1.5113 - val_mean_absolute_percentage_error: 20.6277 - val_mse: 4.0124
# Epoch 6/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 763us/step - loss: 4.4520 - mae: 1.5633 - mean_absolute_percentage_error: 20.6494 - mse: 4.3597 - val_loss: 4.0899 - val_mae: 1.4784 - val_mean_absolute_percentage_error: 19.3358 - val_mse: 4.0036
# Epoch 7/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 744us/step - loss: 4.4985 - mae: 1.5741 - mean_absolute_percentage_error: 20.8349 - mse: 4.4107 - val_loss: 4.1394 - val_mae: 1.5101 - val_mean_absolute_percentage_error: 20.1440 - val_mse: 4.0600
# Epoch 8/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 771us/step - loss: 4.3771 - mae: 1.5517 - mean_absolute_percentage_error: 20.5370 - mse: 4.2956 - val_loss: 4.0724 - val_mae: 1.4992 - val_mean_absolute_percentage_error: 20.1901 - val_mse: 3.9956
# Epoch 9/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 773us/step - loss: 4.4357 - mae: 1.5645 - mean_absolute_percentage_error: 20.7216 - mse: 4.3556 - val_loss: 4.4813 - val_mae: 1.5661 - val_mean_absolute_percentage_error: 21.2696 - val_mse: 4.3989
# Epoch 10/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 767us/step - loss: 4.4495 - mae: 1.5667 - mean_absolute_percentage_error: 20.7901 - mse: 4.3723 - val_loss: 4.2408 - val_mae: 1.5123 - val_mean_absolute_percentage_error: 19.4527 - val_mse: 4.1683
# Epoch 11/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 764us/step - loss: 4.3737 - mae: 1.5503 - mean_absolute_percentage_error: 20.5349 - mse: 4.2994 - val_loss: 4.1299 - val_mae: 1.4812 - val_mean_absolute_percentage_error: 19.2732 - val_mse: 4.0565
# Epoch 12/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 770us/step - loss: 4.3969 - mae: 1.5561 - mean_absolute_percentage_error: 20.5470 - mse: 4.3228 - val_loss: 4.0452 - val_mae: 1.4852 - val_mean_absolute_percentage_error: 19.8033 - val_mse: 3.9764
# Epoch 13/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 777us/step - loss: 4.3749 - mae: 1.5537 - mean_absolute_percentage_error: 20.5565 - mse: 4.3045 - val_loss: 4.3510 - val_mae: 1.5671 - val_mean_absolute_percentage_error: 21.5562 - val_mse: 4.2815
# Epoch 14/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 798us/step - loss: 4.3291 - mae: 1.5439 - mean_absolute_percentage_error: 20.4462 - mse: 4.2594 - val_loss: 4.0851 - val_mae: 1.5190 - val_mean_absolute_percentage_error: 20.9325 - val_mse: 4.0173
# Epoch 15/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 793us/step - loss: 4.3395 - mae: 1.5501 - mean_absolute_percentage_error: 20.4609 - mse: 4.2713 - val_loss: 4.0374 - val_mae: 1.4711 - val_mean_absolute_percentage_error: 19.2622 - val_mse: 3.9716
# Epoch 16/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 783us/step - loss: 4.3119 - mae: 1.5410 - mean_absolute_percentage_error: 20.4390 - mse: 4.2447 - val_loss: 4.0409 - val_mae: 1.4976 - val_mean_absolute_percentage_error: 20.2261 - val_mse: 3.9669
# Epoch 17/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 785us/step - loss: 4.3172 - mae: 1.5382 - mean_absolute_percentage_error: 20.3927 - mse: 4.2502 - val_loss: 4.0987 - val_mae: 1.4902 - val_mean_absolute_percentage_error: 19.9257 - val_mse: 4.0279
# Epoch 18/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 801us/step - loss: 4.3479 - mae: 1.5468 - mean_absolute_percentage_error: 20.4875 - mse: 4.2822 - val_loss: 4.0224 - val_mae: 1.4866 - val_mean_absolute_percentage_error: 20.0686 - val_mse: 3.9600
# Epoch 19/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 787us/step - loss: 4.3017 - mae: 1.5418 - mean_absolute_percentage_error: 20.4041 - mse: 4.2356 - val_loss: 4.0116 - val_mae: 1.4778 - val_mean_absolute_percentage_error: 19.7075 - val_mse: 3.9452
# Epoch 20/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 775us/step - loss: 4.3227 - mae: 1.5426 - mean_absolute_percentage_error: 20.4648 - mse: 4.2581 - val_loss: 4.0586 - val_mae: 1.4946 - val_mean_absolute_percentage_error: 19.9038 - val_mse: 3.9924
# Epoch 21/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 786us/step - loss: 4.2825 - mae: 1.5365 - mean_absolute_percentage_error: 20.3499 - mse: 4.2175 - val_loss: 3.9882 - val_mae: 1.4697 - val_mean_absolute_percentage_error: 19.5417 - val_mse: 3.9241
# Epoch 22/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 812us/step - loss: 4.2837 - mae: 1.5368 - mean_absolute_percentage_error: 20.3926 - mse: 4.2201 - val_loss: 3.9801 - val_mae: 1.4746 - val_mean_absolute_percentage_error: 19.6770 - val_mse: 3.9137
# Epoch 23/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 827us/step - loss: 4.2611 - mae: 1.5292 - mean_absolute_percentage_error: 20.2288 - mse: 4.1951 - val_loss: 4.0573 - val_mae: 1.5065 - val_mean_absolute_percentage_error: 20.6058 - val_mse: 3.9942
# Epoch 24/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 833us/step - loss: 4.3016 - mae: 1.5372 - mean_absolute_percentage_error: 20.3625 - mse: 4.2371 - val_loss: 4.0341 - val_mae: 1.4839 - val_mean_absolute_percentage_error: 19.8647 - val_mse: 3.9696
# Epoch 25/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 787us/step - loss: 4.2761 - mae: 1.5342 - mean_absolute_percentage_error: 20.2642 - mse: 4.2119 - val_loss: 3.9721 - val_mae: 1.4650 - val_mean_absolute_percentage_error: 19.3472 - val_mse: 3.9080
# Epoch 26/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 786us/step - loss: 4.2529 - mae: 1.5269 - mean_absolute_percentage_error: 20.2190 - mse: 4.1888 - val_loss: 3.9904 - val_mae: 1.4646 - val_mean_absolute_percentage_error: 19.2810 - val_mse: 3.9274
# Epoch 27/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 782us/step - loss: 4.2425 - mae: 1.5272 - mean_absolute_percentage_error: 20.1528 - mse: 4.1783 - val_loss: 4.0019 - val_mae: 1.4731 - val_mean_absolute_percentage_error: 19.3404 - val_mse: 3.9385
# Epoch 28/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 798us/step - loss: 4.2726 - mae: 1.5338 - mean_absolute_percentage_error: 20.2192 - mse: 4.2078 - val_loss: 3.9858 - val_mae: 1.4610 - val_mean_absolute_percentage_error: 19.0590 - val_mse: 3.9182
# Epoch 29/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 797us/step - loss: 4.2469 - mae: 1.5297 - mean_absolute_percentage_error: 20.2541 - mse: 4.1810 - val_loss: 4.0379 - val_mae: 1.4700 - val_mean_absolute_percentage_error: 19.2038 - val_mse: 3.9723
# Epoch 30/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 791us/step - loss: 4.2149 - mae: 1.5239 - mean_absolute_percentage_error: 20.1337 - mse: 4.1501 - val_loss: 4.1225 - val_mae: 1.4986 - val_mean_absolute_percentage_error: 19.5220 - val_mse: 4.0566
# Epoch 31/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 788us/step - loss: 4.2427 - mae: 1.5272 - mean_absolute_percentage_error: 20.2350 - mse: 4.1757 - val_loss: 3.9596 - val_mae: 1.4650 - val_mean_absolute_percentage_error: 19.3697 - val_mse: 3.8937
# Epoch 32/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 771us/step - loss: 4.2322 - mae: 1.5275 - mean_absolute_percentage_error: 20.1965 - mse: 4.1671 - val_loss: 4.0357 - val_mae: 1.4736 - val_mean_absolute_percentage_error: 19.6073 - val_mse: 3.9703
# Epoch 33/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 794us/step - loss: 4.2528 - mae: 1.5290 - mean_absolute_percentage_error: 20.1794 - mse: 4.1862 - val_loss: 3.9739 - val_mae: 1.4631 - val_mean_absolute_percentage_error: 19.2009 - val_mse: 3.9059
# Epoch 34/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 787us/step - loss: 4.2239 - mae: 1.5237 - mean_absolute_percentage_error: 20.1561 - mse: 4.1565 - val_loss: 3.9584 - val_mae: 1.4709 - val_mean_absolute_percentage_error: 19.7086 - val_mse: 3.8907
# Epoch 35/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 794us/step - loss: 4.1964 - mae: 1.5201 - mean_absolute_percentage_error: 20.1206 - mse: 4.1287 - val_loss: 3.9695 - val_mae: 1.4636 - val_mean_absolute_percentage_error: 19.2547 - val_mse: 3.9042
# Epoch 36/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 790us/step - loss: 4.1882 - mae: 1.5185 - mean_absolute_percentage_error: 20.0771 - mse: 4.1198 - val_loss: 3.9531 - val_mae: 1.4652 - val_mean_absolute_percentage_error: 19.6110 - val_mse: 3.8857
# Epoch 37/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 785us/step - loss: 4.1810 - mae: 1.5180 - mean_absolute_percentage_error: 20.1532 - mse: 4.1119 - val_loss: 3.9521 - val_mae: 1.4587 - val_mean_absolute_percentage_error: 19.2477 - val_mse: 3.8855
# Epoch 38/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 775us/step - loss: 4.2049 - mae: 1.5208 - mean_absolute_percentage_error: 20.0863 - mse: 4.1364 - val_loss: 3.9502 - val_mae: 1.4596 - val_mean_absolute_percentage_error: 19.4699 - val_mse: 3.8822
# Epoch 39/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 768us/step - loss: 4.2012 - mae: 1.5183 - mean_absolute_percentage_error: 20.1044 - mse: 4.1325 - val_loss: 3.9404 - val_mae: 1.4584 - val_mean_absolute_percentage_error: 19.2557 - val_mse: 3.8706
# Epoch 40/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 762us/step - loss: 4.1909 - mae: 1.5202 - mean_absolute_percentage_error: 20.1358 - mse: 4.1200 - val_loss: 3.9714 - val_mae: 1.4741 - val_mean_absolute_percentage_error: 19.9583 - val_mse: 3.8994
# Epoch 41/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 791us/step - loss: 4.2074 - mae: 1.5210 - mean_absolute_percentage_error: 20.1140 - mse: 4.1360 - val_loss: 4.0475 - val_mae: 1.4661 - val_mean_absolute_percentage_error: 18.7224 - val_mse: 3.9795
# Epoch 42/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 787us/step - loss: 4.1530 - mae: 1.5083 - mean_absolute_percentage_error: 19.9647 - mse: 4.0820 - val_loss: 3.9613 - val_mae: 1.4574 - val_mean_absolute_percentage_error: 19.0688 - val_mse: 3.8924
# Epoch 43/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 778us/step - loss: 4.1696 - mae: 1.5111 - mean_absolute_percentage_error: 19.9793 - mse: 4.0960 - val_loss: 3.9164 - val_mae: 1.4575 - val_mean_absolute_percentage_error: 19.2817 - val_mse: 3.8424
# Epoch 44/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 773us/step - loss: 4.1902 - mae: 1.5147 - mean_absolute_percentage_error: 20.0217 - mse: 4.1172 - val_loss: 3.9985 - val_mae: 1.4692 - val_mean_absolute_percentage_error: 19.6542 - val_mse: 3.9241
# Epoch 45/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 798us/step - loss: 4.1701 - mae: 1.5131 - mean_absolute_percentage_error: 20.0192 - mse: 4.0958 - val_loss: 4.0538 - val_mae: 1.4714 - val_mean_absolute_percentage_error: 18.8950 - val_mse: 3.9803
# Epoch 46/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 784us/step - loss: 4.1800 - mae: 1.5117 - mean_absolute_percentage_error: 20.0031 - mse: 4.1063 - val_loss: 3.9827 - val_mae: 1.4637 - val_mean_absolute_percentage_error: 19.4527 - val_mse: 3.9067
# Epoch 47/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 832us/step - loss: 4.1446 - mae: 1.5061 - mean_absolute_percentage_error: 19.8461 - mse: 4.0684 - val_loss: 3.9302 - val_mae: 1.4543 - val_mean_absolute_percentage_error: 19.1887 - val_mse: 3.8578
# Epoch 48/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 836us/step - loss: 4.1197 - mae: 1.5028 - mean_absolute_percentage_error: 19.8701 - mse: 4.0453 - val_loss: 3.9563 - val_mae: 1.4525 - val_mean_absolute_percentage_error: 19.1062 - val_mse: 3.8806
# Epoch 49/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 783us/step - loss: 4.1368 - mae: 1.5044 - mean_absolute_percentage_error: 19.8531 - mse: 4.0611 - val_loss: 3.9750 - val_mae: 1.4706 - val_mean_absolute_percentage_error: 19.9102 - val_mse: 3.9001
# Epoch 50/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 835us/step - loss: 4.1392 - mae: 1.5015 - mean_absolute_percentage_error: 19.8478 - mse: 4.0618 - val_loss: 3.9163 - val_mae: 1.4477 - val_mean_absolute_percentage_error: 19.0935 - val_mse: 3.8416
# Epoch 51/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 808us/step - loss: 4.1179 - mae: 1.5029 - mean_absolute_percentage_error: 19.8727 - mse: 4.0391 - val_loss: 3.9965 - val_mae: 1.4541 - val_mean_absolute_percentage_error: 18.6161 - val_mse: 3.9166
# Epoch 52/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 832us/step - loss: 4.0600 - mae: 1.4907 - mean_absolute_percentage_error: 19.7447 - mse: 3.9821 - val_loss: 3.9266 - val_mae: 1.4544 - val_mean_absolute_percentage_error: 19.0770 - val_mse: 3.8454
# Epoch 53/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 799us/step - loss: 4.0897 - mae: 1.4949 - mean_absolute_percentage_error: 19.8043 - mse: 4.0105 - val_loss: 3.9604 - val_mae: 1.4660 - val_mean_absolute_percentage_error: 19.3681 - val_mse: 3.8816
# Epoch 54/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 850us/step - loss: 4.1080 - mae: 1.4999 - mean_absolute_percentage_error: 19.8497 - mse: 4.0274 - val_loss: 3.9300 - val_mae: 1.4661 - val_mean_absolute_percentage_error: 19.6190 - val_mse: 3.8510
# Epoch 55/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 803us/step - loss: 4.0997 - mae: 1.4980 - mean_absolute_percentage_error: 19.7891 - mse: 4.0206 - val_loss: 4.0175 - val_mae: 1.4501 - val_mean_absolute_percentage_error: 18.5617 - val_mse: 3.9235
# Epoch 56/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 823us/step - loss: 4.1348 - mae: 1.5032 - mean_absolute_percentage_error: 19.8925 - mse: 4.0481 - val_loss: 3.9185 - val_mae: 1.4547 - val_mean_absolute_percentage_error: 19.3873 - val_mse: 3.8280
# Epoch 57/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 804us/step - loss: 4.1289 - mae: 1.5029 - mean_absolute_percentage_error: 19.8283 - mse: 4.0452 - val_loss: 3.9092 - val_mae: 1.4476 - val_mean_absolute_percentage_error: 19.3025 - val_mse: 3.8142
# Epoch 58/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 840us/step - loss: 4.0597 - mae: 1.4912 - mean_absolute_percentage_error: 19.7425 - mse: 3.9774 - val_loss: 3.9667 - val_mae: 1.4628 - val_mean_absolute_percentage_error: 19.2748 - val_mse: 3.8875
# Epoch 59/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 802us/step - loss: 4.0431 - mae: 1.4872 - mean_absolute_percentage_error: 19.7059 - mse: 3.9620 - val_loss: 3.9406 - val_mae: 1.4707 - val_mean_absolute_percentage_error: 19.6921 - val_mse: 3.8566
# Epoch 60/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 854us/step - loss: 4.0422 - mae: 1.4862 - mean_absolute_percentage_error: 19.7140 - mse: 3.9606 - val_loss: 3.9566 - val_mae: 1.4676 - val_mean_absolute_percentage_error: 19.8239 - val_mse: 3.8753
# Epoch 61/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 855us/step - loss: 4.0978 - mae: 1.4981 - mean_absolute_percentage_error: 19.7825 - mse: 4.0161 - val_loss: 4.0327 - val_mae: 1.4758 - val_mean_absolute_percentage_error: 19.9810 - val_mse: 3.9553
# Epoch 62/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 823us/step - loss: 4.0945 - mae: 1.4962 - mean_absolute_percentage_error: 19.7942 - mse: 4.0135 - val_loss: 3.9062 - val_mae: 1.4460 - val_mean_absolute_percentage_error: 19.0145 - val_mse: 3.8253
# Epoch 63/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 822us/step - loss: 4.0528 - mae: 1.4896 - mean_absolute_percentage_error: 19.7031 - mse: 3.9701 - val_loss: 3.8840 - val_mae: 1.4434 - val_mean_absolute_percentage_error: 19.2373 - val_mse: 3.8019
# Epoch 64/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 780us/step - loss: 4.0842 - mae: 1.4947 - mean_absolute_percentage_error: 19.8214 - mse: 4.0021 - val_loss: 3.9310 - val_mae: 1.4448 - val_mean_absolute_percentage_error: 19.0194 - val_mse: 3.8491
# Epoch 65/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 809us/step - loss: 4.0856 - mae: 1.4983 - mean_absolute_percentage_error: 19.7988 - mse: 4.0001 - val_loss: 3.8989 - val_mae: 1.4439 - val_mean_absolute_percentage_error: 18.9439 - val_mse: 3.8128
# Epoch 66/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 778us/step - loss: 4.0587 - mae: 1.4898 - mean_absolute_percentage_error: 19.7144 - mse: 3.9730 - val_loss: 3.8988 - val_mae: 1.4509 - val_mean_absolute_percentage_error: 19.3559 - val_mse: 3.8172
# Epoch 67/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 792us/step - loss: 4.0164 - mae: 1.4819 - mean_absolute_percentage_error: 19.6213 - mse: 3.9302 - val_loss: 3.9336 - val_mae: 1.4464 - val_mean_absolute_percentage_error: 18.7064 - val_mse: 3.8462
# Epoch 68/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 809us/step - loss: 4.0235 - mae: 1.4824 - mean_absolute_percentage_error: 19.6383 - mse: 3.9387 - val_loss: 3.9391 - val_mae: 1.4435 - val_mean_absolute_percentage_error: 18.6850 - val_mse: 3.8559
# Epoch 69/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 801us/step - loss: 4.0162 - mae: 1.4814 - mean_absolute_percentage_error: 19.5971 - mse: 3.9305 - val_loss: 3.8859 - val_mae: 1.4346 - val_mean_absolute_percentage_error: 18.7625 - val_mse: 3.7985
# Epoch 70/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 826us/step - loss: 4.0151 - mae: 1.4804 - mean_absolute_percentage_error: 19.5791 - mse: 3.9277 - val_loss: 3.8796 - val_mae: 1.4554 - val_mean_absolute_percentage_error: 19.8190 - val_mse: 3.7876
# Epoch 71/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 801us/step - loss: 4.0076 - mae: 1.4818 - mean_absolute_percentage_error: 19.6241 - mse: 3.9198 - val_loss: 3.9530 - val_mae: 1.4702 - val_mean_absolute_percentage_error: 20.1339 - val_mse: 3.8606
# Epoch 72/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 805us/step - loss: 3.9841 - mae: 1.4760 - mean_absolute_percentage_error: 19.5658 - mse: 3.8949 - val_loss: 3.9014 - val_mae: 1.4439 - val_mean_absolute_percentage_error: 18.9624 - val_mse: 3.8150
# Epoch 73/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 789us/step - loss: 3.9682 - mae: 1.4712 - mean_absolute_percentage_error: 19.4833 - mse: 3.8808 - val_loss: 3.8923 - val_mae: 1.4311 - val_mean_absolute_percentage_error: 18.5295 - val_mse: 3.8037
# Epoch 74/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 825us/step - loss: 3.9983 - mae: 1.4769 - mean_absolute_percentage_error: 19.4964 - mse: 3.9099 - val_loss: 3.9072 - val_mae: 1.4507 - val_mean_absolute_percentage_error: 19.4221 - val_mse: 3.8223
# Epoch 75/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 803us/step - loss: 3.9424 - mae: 1.4716 - mean_absolute_percentage_error: 19.5035 - mse: 3.8548 - val_loss: 3.8683 - val_mae: 1.4459 - val_mean_absolute_percentage_error: 19.2454 - val_mse: 3.7809
# Epoch 76/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 816us/step - loss: 4.0012 - mae: 1.4780 - mean_absolute_percentage_error: 19.5259 - mse: 3.9130 - val_loss: 3.8764 - val_mae: 1.4332 - val_mean_absolute_percentage_error: 18.8505 - val_mse: 3.7704
# Epoch 77/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 841us/step - loss: 3.9568 - mae: 1.4698 - mean_absolute_percentage_error: 19.4830 - mse: 3.8653 - val_loss: 3.9161 - val_mae: 1.4388 - val_mean_absolute_percentage_error: 18.7072 - val_mse: 3.8212
# Epoch 78/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 795us/step - loss: 3.9748 - mae: 1.4709 - mean_absolute_percentage_error: 19.4565 - mse: 3.8830 - val_loss: 3.9016 - val_mae: 1.4603 - val_mean_absolute_percentage_error: 19.7096 - val_mse: 3.8086
# Epoch 79/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 788us/step - loss: 3.9728 - mae: 1.4706 - mean_absolute_percentage_error: 19.4789 - mse: 3.8813 - val_loss: 3.8725 - val_mae: 1.4413 - val_mean_absolute_percentage_error: 19.1694 - val_mse: 3.7843
# Epoch 80/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 798us/step - loss: 3.9235 - mae: 1.4662 - mean_absolute_percentage_error: 19.4304 - mse: 3.8330 - val_loss: 3.8845 - val_mae: 1.4397 - val_mean_absolute_percentage_error: 19.0627 - val_mse: 3.7894
# Epoch 81/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 794us/step - loss: 3.9534 - mae: 1.4662 - mean_absolute_percentage_error: 19.4209 - mse: 3.8605 - val_loss: 3.8320 - val_mae: 1.4432 - val_mean_absolute_percentage_error: 19.4045 - val_mse: 3.7421
# Epoch 82/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 799us/step - loss: 3.9056 - mae: 1.4651 - mean_absolute_percentage_error: 19.3575 - mse: 3.8131 - val_loss: 3.9046 - val_mae: 1.4584 - val_mean_absolute_percentage_error: 19.6457 - val_mse: 3.8125
# Epoch 83/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 815us/step - loss: 3.8928 - mae: 1.4547 - mean_absolute_percentage_error: 19.3281 - mse: 3.8001 - val_loss: 3.9010 - val_mae: 1.4485 - val_mean_absolute_percentage_error: 18.9947 - val_mse: 3.8120
# Epoch 84/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 817us/step - loss: 3.9336 - mae: 1.4642 - mean_absolute_percentage_error: 19.3543 - mse: 3.8415 - val_loss: 3.8874 - val_mae: 1.4412 - val_mean_absolute_percentage_error: 18.9314 - val_mse: 3.7972
# Epoch 85/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 795us/step - loss: 3.9226 - mae: 1.4640 - mean_absolute_percentage_error: 19.4370 - mse: 3.8306 - val_loss: 3.8988 - val_mae: 1.4482 - val_mean_absolute_percentage_error: 19.0576 - val_mse: 3.8021
# Epoch 86/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 779us/step - loss: 3.9225 - mae: 1.4649 - mean_absolute_percentage_error: 19.4226 - mse: 3.8278 - val_loss: 3.8895 - val_mae: 1.4535 - val_mean_absolute_percentage_error: 19.3727 - val_mse: 3.7944
# Epoch 87/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 814us/step - loss: 3.8890 - mae: 1.4567 - mean_absolute_percentage_error: 19.3221 - mse: 3.7953 - val_loss: 3.8332 - val_mae: 1.4285 - val_mean_absolute_percentage_error: 18.8040 - val_mse: 3.7424
# Epoch 88/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 800us/step - loss: 3.8522 - mae: 1.4529 - mean_absolute_percentage_error: 19.2104 - mse: 3.7587 - val_loss: 3.8456 - val_mae: 1.4457 - val_mean_absolute_percentage_error: 19.4046 - val_mse: 3.7509
# Epoch 89/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 818us/step - loss: 3.9445 - mae: 1.4665 - mean_absolute_percentage_error: 19.4334 - mse: 3.8494 - val_loss: 3.9185 - val_mae: 1.4570 - val_mean_absolute_percentage_error: 19.6180 - val_mse: 3.8260
# Epoch 90/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 813us/step - loss: 3.9253 - mae: 1.4615 - mean_absolute_percentage_error: 19.3539 - mse: 3.8316 - val_loss: 3.8625 - val_mae: 1.4348 - val_mean_absolute_percentage_error: 19.0906 - val_mse: 3.7633
# Epoch 91/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 810us/step - loss: 3.9483 - mae: 1.4645 - mean_absolute_percentage_error: 19.3424 - mse: 3.8531 - val_loss: 3.8533 - val_mae: 1.4270 - val_mean_absolute_percentage_error: 18.5894 - val_mse: 3.7550
# Epoch 92/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 829us/step - loss: 3.9114 - mae: 1.4599 - mean_absolute_percentage_error: 19.2995 - mse: 3.8167 - val_loss: 3.8559 - val_mae: 1.4227 - val_mean_absolute_percentage_error: 18.5349 - val_mse: 3.7575
# Epoch 93/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 813us/step - loss: 3.8623 - mae: 1.4509 - mean_absolute_percentage_error: 19.1944 - mse: 3.7653 - val_loss: 3.8197 - val_mae: 1.4303 - val_mean_absolute_percentage_error: 18.8924 - val_mse: 3.7241
# Epoch 94/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 820us/step - loss: 3.8289 - mae: 1.4471 - mean_absolute_percentage_error: 19.2044 - mse: 3.7326 - val_loss: 3.8723 - val_mae: 1.4369 - val_mean_absolute_percentage_error: 19.0701 - val_mse: 3.7765
# Epoch 95/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 793us/step - loss: 3.8516 - mae: 1.4493 - mean_absolute_percentage_error: 19.1933 - mse: 3.7547 - val_loss: 3.8513 - val_mae: 1.4349 - val_mean_absolute_percentage_error: 19.0643 - val_mse: 3.7583
# Epoch 96/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 802us/step - loss: 3.8687 - mae: 1.4526 - mean_absolute_percentage_error: 19.2571 - mse: 3.7724 - val_loss: 3.8291 - val_mae: 1.4263 - val_mean_absolute_percentage_error: 18.6492 - val_mse: 3.7332
# Epoch 97/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 790us/step - loss: 3.8862 - mae: 1.4568 - mean_absolute_percentage_error: 19.3537 - mse: 3.7886 - val_loss: 3.8222 - val_mae: 1.4289 - val_mean_absolute_percentage_error: 18.7775 - val_mse: 3.7231
# Epoch 98/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 807us/step - loss: 3.8000 - mae: 1.4413 - mean_absolute_percentage_error: 19.0648 - mse: 3.7013 - val_loss: 3.8291 - val_mae: 1.4227 - val_mean_absolute_percentage_error: 18.7219 - val_mse: 3.7308
# Epoch 99/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 832us/step - loss: 3.8301 - mae: 1.4411 - mean_absolute_percentage_error: 19.0608 - mse: 3.7317 - val_loss: 4.1653 - val_mae: 1.5087 - val_mean_absolute_percentage_error: 20.3109 - val_mse: 4.0653
# Epoch 100/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 809us/step - loss: 3.7906 - mae: 1.4397 - mean_absolute_percentage_error: 19.0592 - mse: 3.6922 - val_loss: 3.9292 - val_mae: 1.4371 - val_mean_absolute_percentage_error: 18.5139 - val_mse: 3.8237
# Epoch 101/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 819us/step - loss: 3.8691 - mae: 1.4528 - mean_absolute_percentage_error: 19.2273 - mse: 3.7673 - val_loss: 3.8794 - val_mae: 1.4384 - val_mean_absolute_percentage_error: 19.0326 - val_mse: 3.7809
# Epoch 102/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 830us/step - loss: 3.8291 - mae: 1.4393 - mean_absolute_percentage_error: 19.0475 - mse: 3.7302 - val_loss: 3.8148 - val_mae: 1.4386 - val_mean_absolute_percentage_error: 19.3590 - val_mse: 3.7152
# Epoch 103/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 844us/step - loss: 3.8063 - mae: 1.4397 - mean_absolute_percentage_error: 19.0654 - mse: 3.7070 - val_loss: 3.8485 - val_mae: 1.4534 - val_mean_absolute_percentage_error: 19.8210 - val_mse: 3.7526
# Epoch 104/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 827us/step - loss: 3.8191 - mae: 1.4464 - mean_absolute_percentage_error: 19.1635 - mse: 3.7189 - val_loss: 3.8489 - val_mae: 1.4308 - val_mean_absolute_percentage_error: 18.8826 - val_mse: 3.7472
# Epoch 105/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 824us/step - loss: 3.8288 - mae: 1.4475 - mean_absolute_percentage_error: 19.1254 - mse: 3.7289 - val_loss: 3.8404 - val_mae: 1.4337 - val_mean_absolute_percentage_error: 19.1014 - val_mse: 3.7381
# Epoch 106/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 816us/step - loss: 3.8047 - mae: 1.4399 - mean_absolute_percentage_error: 19.0314 - mse: 3.7027 - val_loss: 3.8494 - val_mae: 1.4322 - val_mean_absolute_percentage_error: 18.9699 - val_mse: 3.7517
# Epoch 107/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 824us/step - loss: 3.7852 - mae: 1.4386 - mean_absolute_percentage_error: 19.0393 - mse: 3.6856 - val_loss: 3.8446 - val_mae: 1.4339 - val_mean_absolute_percentage_error: 18.9921 - val_mse: 3.7404
# Epoch 108/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 835us/step - loss: 3.8184 - mae: 1.4399 - mean_absolute_percentage_error: 19.0499 - mse: 3.7169 - val_loss: 3.8705 - val_mae: 1.4221 - val_mean_absolute_percentage_error: 18.5378 - val_mse: 3.7701
# Epoch 109/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 825us/step - loss: 3.7594 - mae: 1.4283 - mean_absolute_percentage_error: 18.9238 - mse: 3.6593 - val_loss: 3.8423 - val_mae: 1.4318 - val_mean_absolute_percentage_error: 18.7571 - val_mse: 3.7390
# Epoch 110/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 810us/step - loss: 3.7980 - mae: 1.4367 - mean_absolute_percentage_error: 19.0493 - mse: 3.6938 - val_loss: 3.8472 - val_mae: 1.4451 - val_mean_absolute_percentage_error: 19.5788 - val_mse: 3.7468
# Epoch 111/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 868us/step - loss: 3.8228 - mae: 1.4463 - mean_absolute_percentage_error: 19.1596 - mse: 3.7215 - val_loss: 3.7839 - val_mae: 1.4176 - val_mean_absolute_percentage_error: 18.8286 - val_mse: 3.6790
# Epoch 112/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 831us/step - loss: 3.7798 - mae: 1.4376 - mean_absolute_percentage_error: 18.9782 - mse: 3.6777 - val_loss: 3.7993 - val_mae: 1.4296 - val_mean_absolute_percentage_error: 19.0857 - val_mse: 3.6949
# Epoch 113/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 850us/step - loss: 3.7314 - mae: 1.4282 - mean_absolute_percentage_error: 18.9408 - mse: 3.6293 - val_loss: 3.8771 - val_mae: 1.4513 - val_mean_absolute_percentage_error: 19.6704 - val_mse: 3.7710
# Epoch 114/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 847us/step - loss: 3.7472 - mae: 1.4284 - mean_absolute_percentage_error: 18.9015 - mse: 3.6434 - val_loss: 3.8231 - val_mae: 1.4237 - val_mean_absolute_percentage_error: 18.8230 - val_mse: 3.7190
# Epoch 115/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 824us/step - loss: 3.7081 - mae: 1.4252 - mean_absolute_percentage_error: 18.8680 - mse: 3.6041 - val_loss: 3.8036 - val_mae: 1.4285 - val_mean_absolute_percentage_error: 19.0162 - val_mse: 3.6975
# Epoch 116/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 820us/step - loss: 3.7248 - mae: 1.4233 - mean_absolute_percentage_error: 18.8410 - mse: 3.6210 - val_loss: 3.7928 - val_mae: 1.4303 - val_mean_absolute_percentage_error: 19.1871 - val_mse: 3.6919
# Epoch 117/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 835us/step - loss: 3.7362 - mae: 1.4256 - mean_absolute_percentage_error: 18.8845 - mse: 3.6345 - val_loss: 3.8227 - val_mae: 1.4247 - val_mean_absolute_percentage_error: 18.7947 - val_mse: 3.7189
# Epoch 118/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 829us/step - loss: 3.7173 - mae: 1.4265 - mean_absolute_percentage_error: 18.9253 - mse: 3.6138 - val_loss: 3.8677 - val_mae: 1.4330 - val_mean_absolute_percentage_error: 18.9575 - val_mse: 3.7661
# Epoch 119/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 846us/step - loss: 3.7569 - mae: 1.4260 - mean_absolute_percentage_error: 18.8512 - mse: 3.6520 - val_loss: 3.8635 - val_mae: 1.4250 - val_mean_absolute_percentage_error: 18.4627 - val_mse: 3.7623
# Epoch 120/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 813us/step - loss: 3.7204 - mae: 1.4227 - mean_absolute_percentage_error: 18.8012 - mse: 3.6153 - val_loss: 3.8047 - val_mae: 1.4206 - val_mean_absolute_percentage_error: 18.6976 - val_mse: 3.7017
# Epoch 121/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 834us/step - loss: 3.7490 - mae: 1.4257 - mean_absolute_percentage_error: 18.9223 - mse: 3.6441 - val_loss: 3.8157 - val_mae: 1.4214 - val_mean_absolute_percentage_error: 18.7930 - val_mse: 3.7114
# Epoch 122/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 853us/step - loss: 3.6863 - mae: 1.4145 - mean_absolute_percentage_error: 18.7333 - mse: 3.5800 - val_loss: 3.7999 - val_mae: 1.4159 - val_mean_absolute_percentage_error: 18.5186 - val_mse: 3.6919
# Epoch 123/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 854us/step - loss: 3.7297 - mae: 1.4252 - mean_absolute_percentage_error: 18.9171 - mse: 3.6233 - val_loss: 3.8396 - val_mae: 1.4231 - val_mean_absolute_percentage_error: 18.5624 - val_mse: 3.7296
# Epoch 124/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 847us/step - loss: 3.6909 - mae: 1.4176 - mean_absolute_percentage_error: 18.7366 - mse: 3.5845 - val_loss: 3.8193 - val_mae: 1.4250 - val_mean_absolute_percentage_error: 18.7682 - val_mse: 3.7105
# Epoch 125/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 874us/step - loss: 3.6983 - mae: 1.4167 - mean_absolute_percentage_error: 18.7206 - mse: 3.5913 - val_loss: 3.9427 - val_mae: 1.4405 - val_mean_absolute_percentage_error: 18.4507 - val_mse: 3.8347
# Epoch 126/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 864us/step - loss: 3.6906 - mae: 1.4199 - mean_absolute_percentage_error: 18.8117 - mse: 3.5840 - val_loss: 3.7954 - val_mae: 1.4180 - val_mean_absolute_percentage_error: 18.7239 - val_mse: 3.6870
# Epoch 127/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 952us/step - loss: 3.7428 - mae: 1.4264 - mean_absolute_percentage_error: 18.8593 - mse: 3.6351 - val_loss: 3.8069 - val_mae: 1.4201 - val_mean_absolute_percentage_error: 18.6944 - val_mse: 3.7023
# Epoch 128/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 855us/step - loss: 3.7219 - mae: 1.4254 - mean_absolute_percentage_error: 18.8870 - mse: 3.6160 - val_loss: 3.8287 - val_mae: 1.4375 - val_mean_absolute_percentage_error: 19.3123 - val_mse: 3.7221
# Epoch 129/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 843us/step - loss: 3.6875 - mae: 1.4165 - mean_absolute_percentage_error: 18.7510 - mse: 3.5812 - val_loss: 3.7788 - val_mae: 1.4183 - val_mean_absolute_percentage_error: 18.8253 - val_mse: 3.6739
# Epoch 130/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 821us/step - loss: 3.6747 - mae: 1.4115 - mean_absolute_percentage_error: 18.7041 - mse: 3.5664 - val_loss: 3.7717 - val_mae: 1.4297 - val_mean_absolute_percentage_error: 19.1918 - val_mse: 3.6620
# Epoch 131/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 856us/step - loss: 3.7230 - mae: 1.4228 - mean_absolute_percentage_error: 18.8047 - mse: 3.6134 - val_loss: 3.8286 - val_mae: 1.4280 - val_mean_absolute_percentage_error: 18.6816 - val_mse: 3.7222
# Epoch 132/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 836us/step - loss: 3.6659 - mae: 1.4133 - mean_absolute_percentage_error: 18.6744 - mse: 3.5576 - val_loss: 3.8524 - val_mae: 1.4542 - val_mean_absolute_percentage_error: 19.8665 - val_mse: 3.7431
# Epoch 133/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 836us/step - loss: 3.6738 - mae: 1.4126 - mean_absolute_percentage_error: 18.7394 - mse: 3.5670 - val_loss: 3.7926 - val_mae: 1.4188 - val_mean_absolute_percentage_error: 18.8780 - val_mse: 3.6794
# Epoch 134/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 834us/step - loss: 3.6536 - mae: 1.4120 - mean_absolute_percentage_error: 18.7157 - mse: 3.5449 - val_loss: 3.8044 - val_mae: 1.4187 - val_mean_absolute_percentage_error: 18.5685 - val_mse: 3.6984
# Epoch 135/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 852us/step - loss: 3.6816 - mae: 1.4166 - mean_absolute_percentage_error: 18.7941 - mse: 3.5738 - val_loss: 3.8498 - val_mae: 1.4308 - val_mean_absolute_percentage_error: 18.8614 - val_mse: 3.7396
# Epoch 136/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 838us/step - loss: 3.6796 - mae: 1.4149 - mean_absolute_percentage_error: 18.7113 - mse: 3.5692 - val_loss: 3.7800 - val_mae: 1.4254 - val_mean_absolute_percentage_error: 18.9985 - val_mse: 3.6708
# Epoch 137/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 851us/step - loss: 3.6904 - mae: 1.4169 - mean_absolute_percentage_error: 18.7957 - mse: 3.5818 - val_loss: 3.8061 - val_mae: 1.4193 - val_mean_absolute_percentage_error: 18.5224 - val_mse: 3.6983
# Epoch 138/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 874us/step - loss: 3.7056 - mae: 1.4211 - mean_absolute_percentage_error: 18.7828 - mse: 3.5967 - val_loss: 3.7702 - val_mae: 1.4104 - val_mean_absolute_percentage_error: 18.4739 - val_mse: 3.6593
# Epoch 139/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 823us/step - loss: 3.7071 - mae: 1.4166 - mean_absolute_percentage_error: 18.7466 - mse: 3.5970 - val_loss: 3.7898 - val_mae: 1.4203 - val_mean_absolute_percentage_error: 18.8592 - val_mse: 3.6825
# Epoch 140/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 848us/step - loss: 3.6679 - mae: 1.4110 - mean_absolute_percentage_error: 18.6990 - mse: 3.5591 - val_loss: 3.7911 - val_mae: 1.4276 - val_mean_absolute_percentage_error: 19.0650 - val_mse: 3.6847
# Epoch 141/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 993us/step - loss: 3.6300 - mae: 1.4032 - mean_absolute_percentage_error: 18.5378 - mse: 3.5205 - val_loss: 3.7587 - val_mae: 1.4224 - val_mean_absolute_percentage_error: 19.1682 - val_mse: 3.6524
# Epoch 142/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 939us/step - loss: 3.6583 - mae: 1.4127 - mean_absolute_percentage_error: 18.7243 - mse: 3.5481 - val_loss: 3.8121 - val_mae: 1.4239 - val_mean_absolute_percentage_error: 18.7143 - val_mse: 3.7010
# Epoch 143/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 993us/step - loss: 3.6361 - mae: 1.4041 - mean_absolute_percentage_error: 18.6076 - mse: 3.5257 - val_loss: 3.7643 - val_mae: 1.4105 - val_mean_absolute_percentage_error: 18.6128 - val_mse: 3.6555
# Epoch 144/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 988us/step - loss: 3.5753 - mae: 1.3976 - mean_absolute_percentage_error: 18.4809 - mse: 3.4664 - val_loss: 3.7897 - val_mae: 1.4227 - val_mean_absolute_percentage_error: 18.8061 - val_mse: 3.6738
# Epoch 145/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 3.6481 - mae: 1.4069 - mean_absolute_percentage_error: 18.6444 - mse: 3.5342 - val_loss: 3.8693 - val_mae: 1.4227 - val_mean_absolute_percentage_error: 18.1272 - val_mse: 3.7601
# Epoch 146/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 965us/step - loss: 3.5861 - mae: 1.3975 - mean_absolute_percentage_error: 18.5062 - mse: 3.4766 - val_loss: 3.9014 - val_mae: 1.4379 - val_mean_absolute_percentage_error: 19.0353 - val_mse: 3.7909
# Epoch 147/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 955us/step - loss: 3.6244 - mae: 1.4027 - mean_absolute_percentage_error: 18.5468 - mse: 3.5121 - val_loss: 3.7989 - val_mae: 1.4354 - val_mean_absolute_percentage_error: 19.2297 - val_mse: 3.6902
# Epoch 148/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 984us/step - loss: 3.6111 - mae: 1.3997 - mean_absolute_percentage_error: 18.5457 - mse: 3.5008 - val_loss: 3.7716 - val_mae: 1.4272 - val_mean_absolute_percentage_error: 19.2644 - val_mse: 3.6606
# Epoch 149/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 3.6357 - mae: 1.4032 - mean_absolute_percentage_error: 18.5904 - mse: 3.5237 - val_loss: 3.7931 - val_mae: 1.4207 - val_mean_absolute_percentage_error: 18.6464 - val_mse: 3.6846
# Epoch 150/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 968us/step - loss: 3.5724 - mae: 1.3905 - mean_absolute_percentage_error: 18.4400 - mse: 3.4620 - val_loss: 3.8988 - val_mae: 1.4474 - val_mean_absolute_percentage_error: 19.4092 - val_mse: 3.7891
# Epoch 151/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 935us/step - loss: 3.6365 - mae: 1.4072 - mean_absolute_percentage_error: 18.5766 - mse: 3.5247 - val_loss: 3.7434 - val_mae: 1.4103 - val_mean_absolute_percentage_error: 18.5267 - val_mse: 3.6307
# Epoch 152/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 887us/step - loss: 3.6296 - mae: 1.4057 - mean_absolute_percentage_error: 18.6252 - mse: 3.5164 - val_loss: 3.7812 - val_mae: 1.4230 - val_mean_absolute_percentage_error: 18.9537 - val_mse: 3.6699
# Epoch 153/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 894us/step - loss: 3.6072 - mae: 1.3982 - mean_absolute_percentage_error: 18.4927 - mse: 3.4931 - val_loss: 3.7752 - val_mae: 1.4114 - val_mean_absolute_percentage_error: 18.4929 - val_mse: 3.6628
# Epoch 154/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 952us/step - loss: 3.6036 - mae: 1.3965 - mean_absolute_percentage_error: 18.5014 - mse: 3.4904 - val_loss: 3.8091 - val_mae: 1.4288 - val_mean_absolute_percentage_error: 19.1824 - val_mse: 3.6788
# Epoch 155/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 972us/step - loss: 3.5964 - mae: 1.3966 - mean_absolute_percentage_error: 18.5147 - mse: 3.4786 - val_loss: 3.7263 - val_mae: 1.4110 - val_mean_absolute_percentage_error: 18.8241 - val_mse: 3.6167
# Epoch 156/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 886us/step - loss: 3.6331 - mae: 1.4060 - mean_absolute_percentage_error: 18.6641 - mse: 3.5200 - val_loss: 3.7471 - val_mae: 1.4025 - val_mean_absolute_percentage_error: 18.4088 - val_mse: 3.6361
# Epoch 157/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 927us/step - loss: 3.6053 - mae: 1.3981 - mean_absolute_percentage_error: 18.5000 - mse: 3.4932 - val_loss: 3.7876 - val_mae: 1.4104 - val_mean_absolute_percentage_error: 18.2830 - val_mse: 3.6710
# Epoch 158/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 891us/step - loss: 3.5887 - mae: 1.3952 - mean_absolute_percentage_error: 18.4575 - mse: 3.4740 - val_loss: 3.7663 - val_mae: 1.4110 - val_mean_absolute_percentage_error: 18.5499 - val_mse: 3.6458
# Epoch 159/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 899us/step - loss: 3.5647 - mae: 1.3931 - mean_absolute_percentage_error: 18.5113 - mse: 3.4490 - val_loss: 3.7796 - val_mae: 1.4106 - val_mean_absolute_percentage_error: 18.2799 - val_mse: 3.6652
# Epoch 160/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 917us/step - loss: 3.5767 - mae: 1.3919 - mean_absolute_percentage_error: 18.4707 - mse: 3.4632 - val_loss: 3.7731 - val_mae: 1.4194 - val_mean_absolute_percentage_error: 18.9410 - val_mse: 3.6598
# Epoch 161/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 931us/step - loss: 3.5860 - mae: 1.3953 - mean_absolute_percentage_error: 18.4891 - mse: 3.4716 - val_loss: 3.7646 - val_mae: 1.4222 - val_mean_absolute_percentage_error: 19.1114 - val_mse: 3.6479
# Epoch 162/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 854us/step - loss: 3.6719 - mae: 1.4011 - mean_absolute_percentage_error: 18.6023 - mse: 3.5468 - val_loss: 3.8032 - val_mae: 1.4101 - val_mean_absolute_percentage_error: 18.3701 - val_mse: 3.6820
# Epoch 163/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 3.5759 - mae: 1.3912 - mean_absolute_percentage_error: 18.4508 - mse: 3.4573 - val_loss: 3.7793 - val_mae: 1.4262 - val_mean_absolute_percentage_error: 19.1103 - val_mse: 3.6641
# Epoch 164/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 946us/step - loss: 3.6137 - mae: 1.3976 - mean_absolute_percentage_error: 18.4880 - mse: 3.4970 - val_loss: 3.7426 - val_mae: 1.4147 - val_mean_absolute_percentage_error: 18.9082 - val_mse: 3.6284
# Epoch 165/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 917us/step - loss: 3.5756 - mae: 1.3944 - mean_absolute_percentage_error: 18.4541 - mse: 3.4615 - val_loss: 3.7824 - val_mae: 1.4122 - val_mean_absolute_percentage_error: 18.6960 - val_mse: 3.6663
# Epoch 166/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 873us/step - loss: 3.5656 - mae: 1.3926 - mean_absolute_percentage_error: 18.4566 - mse: 3.4492 - val_loss: 3.7478 - val_mae: 1.4128 - val_mean_absolute_percentage_error: 18.9128 - val_mse: 3.6337
# Epoch 167/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 960us/step - loss: 3.5523 - mae: 1.3889 - mean_absolute_percentage_error: 18.4753 - mse: 3.4357 - val_loss: 3.7831 - val_mae: 1.4143 - val_mean_absolute_percentage_error: 18.4835 - val_mse: 3.6720
# Epoch 168/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 918us/step - loss: 3.5853 - mae: 1.3974 - mean_absolute_percentage_error: 18.4910 - mse: 3.4713 - val_loss: 3.7875 - val_mae: 1.4244 - val_mean_absolute_percentage_error: 18.9576 - val_mse: 3.6703
# Epoch 169/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 890us/step - loss: 3.5968 - mae: 1.3940 - mean_absolute_percentage_error: 18.5414 - mse: 3.4765 - val_loss: 3.7581 - val_mae: 1.4065 - val_mean_absolute_percentage_error: 18.4692 - val_mse: 3.6412
# Epoch 170/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 950us/step - loss: 3.5643 - mae: 1.3907 - mean_absolute_percentage_error: 18.4226 - mse: 3.4488 - val_loss: 3.9401 - val_mae: 1.4481 - val_mean_absolute_percentage_error: 19.3087 - val_mse: 3.8223
# Epoch 171/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 959us/step - loss: 3.5909 - mae: 1.3952 - mean_absolute_percentage_error: 18.5103 - mse: 3.4731 - val_loss: 3.7395 - val_mae: 1.4016 - val_mean_absolute_percentage_error: 18.4188 - val_mse: 3.6215
# Epoch 172/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 971us/step - loss: 3.5170 - mae: 1.3780 - mean_absolute_percentage_error: 18.2707 - mse: 3.4013 - val_loss: 3.7347 - val_mae: 1.4065 - val_mean_absolute_percentage_error: 18.4537 - val_mse: 3.6203
# Epoch 173/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 918us/step - loss: 3.5175 - mae: 1.3773 - mean_absolute_percentage_error: 18.2271 - mse: 3.4006 - val_loss: 3.8195 - val_mae: 1.4152 - val_mean_absolute_percentage_error: 18.3476 - val_mse: 3.7026
# Epoch 174/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 994us/step - loss: 3.6389 - mae: 1.4019 - mean_absolute_percentage_error: 18.5261 - mse: 3.5096 - val_loss: 3.7972 - val_mae: 1.4102 - val_mean_absolute_percentage_error: 18.3045 - val_mse: 3.6805
# Epoch 175/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 943us/step - loss: 3.5828 - mae: 1.3930 - mean_absolute_percentage_error: 18.4597 - mse: 3.4645 - val_loss: 3.7487 - val_mae: 1.3988 - val_mean_absolute_percentage_error: 18.1713 - val_mse: 3.6323

# %% [markdown]
# ### Analysing error metrics

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist['rmse'] = np.sqrt(hist['mse'])
hist['val_rmse'] = np.sqrt(hist['val_mse'])
hist.tail()
# Out:
#          loss       mae  mean_absolute_percentage_error       mse  val_loss  \
# 170  3.601321  1.396944                       18.501326  3.483650  3.739547
# 171  3.545265  1.385508                       18.365471  3.429155  3.734654
# 172  3.563597  1.389253                       18.409838  3.446154  3.819517
# 173  3.588667  1.394220                       18.456661  3.462795  3.797151
# 174  3.575010  1.390731                       18.434595  3.457366  3.748739
#
#       val_mae  val_mean_absolute_percentage_error   val_mse  epoch      rmse  \
# 170  1.401581                           18.418850  3.621538    170  1.866454
# 171  1.406485                           18.453705  3.620269    171  1.851798
# 172  1.415220                           18.347565  3.702551    172  1.856382
# 173  1.410185                           18.304470  3.680497    173  1.860859
# 174  1.398802                           18.171333  3.632271    174  1.859399
#
#      val_rmse
# 170  1.903034
# 171  1.902700
# 172  1.924201
# 173  1.918462
# 174  1.905852

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.title("Evolução das funções de perda durante o treinamento da rede")
plt.xlabel('Rodada')
plt.ylabel('Root Mean Square Error')
plt.plot(hist['epoch'], hist['rmse'], label='RMSE Treino')
plt.plot(hist['epoch'], hist['val_rmse'], label = 'RMSE Validação')
plt.legend()

plt.figure()
plt.xlabel('Rodada')
plt.ylabel('Mean Absolute Error')
plt.plot(hist['epoch'], hist['mae'], label='MAE Treino')
plt.plot(hist['epoch'], hist['val_mae'], label = 'MAE Validação')
plt.legend()

plt.show()

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# ### Preparing test dataframe

# %%
x_test = test
y_test = test.pop('bg+1:00')
print(x_test.shape)
x_test.head(5)
# Out:
# (44256, 30)
#     bg-0:00   bg-0:05  bg-0:10    bg-0:15   bg-0:20   bg-0:25    bg-0:30  \
# 2      13.9  8.246322  8.33178  14.400000  8.258647  8.430463  15.100000
# 10     11.9  8.246322  8.33178  11.400000  8.258647  8.430463  12.700000
# 21      5.8  8.246322  8.33178   6.600000  8.258647  8.430463   8.600000
# 27      7.8  7.100000  8.33178   7.366667  5.200000  8.430463   7.228571
# 30     12.3  7.933333  8.33178  11.066667  8.000000  8.430463  10.271429
#
#      bg-0:35   bg-0:40  bg-0:45  ...    hr-0:25    hr-0:30  steps-0:00  \
# 2   8.268978  8.412561  16.2000  ...  81.177985  81.189919   44.927039
# 10  8.268978  8.412561  14.8000  ...  81.177985  81.189919   44.927039
# 21  8.268978  8.412561  11.2000  ...  81.177985  81.189919   44.927039
# 27  4.800000  8.412561   7.1250  ...  81.177985  81.189919   44.927039
# 30  7.400000  8.412561   9.7125  ...  81.177985  81.189919   44.927039
#
#     steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  \
# 2    43.967174    43.96972   45.359472   8.130857   8.147582  2.984808
# 10   43.967174    43.96972   45.359472   8.130857   8.147582  2.766044
# 21   43.967174    43.96972   45.359472   8.130857   8.147582  2.152123
# 27   43.967174    43.96972   45.359472   8.130857   8.147582  1.741181
# 30   43.967174    43.96972   45.359472   8.130857   8.147582  1.557711
#
#     time_cos
# 2   1.826352
# 10  1.357212
# 21  1.011638
# 27  1.034074
# 30  1.103127
#
# [5 rows x 30 columns]

# %%
y_test.head(5)
# Out:
# 2     15.5
# 10    17.4
# 21     4.8
# 27    13.1
# 30     8.3
# Name: bg+1:00, dtype: float64

# %%
x_test.to_csv("x_t.csv", index=False)
y_test.to_csv("y_t.csv", index=False)

# %% [markdown]
# ### Running prediction

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# 1383/1383 ━━━━━━━━━━━━━━━━━━━━ 1s 511us/step
# [[12.865048 ]
#  [10.457526 ]
#  [ 5.9310637]
#  ...
#  [ 7.4937963]
#  [ 9.799721 ]
#  [10.735626 ]]

# %% [markdown]
# ### Calculating error metrics

# %%
mse = tf.keras.losses.MSE(y_test, y_pred).numpy().mean()
mae = tf.keras.losses.MAE(y_test, y_pred).numpy().mean()
rmse = np.sqrt(mse)

# %%
print(f"RMSE Test: {rmse}")
print(f"MSE Test: {mse}")
print(f"MAE Test: {mae}")
# Out:
# RMSE Test: 1.9015274047851562
# MSE Test: 3.6158063411712646
# MAE Test: 1.4029291868209839

# %% [markdown]
# ## Saving the model

# %%
model.save("brist1d_v8.keras")

# %% [markdown]
# ## Loading and processing submission dataframe

# %%
df_submission = pd.read_csv('dataset/test.csv', header=0)
print(df_submission.shape)
df_submission.head(5)
# Out:
# (3644, 507)
#          id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_8459   p01  06:45:00      NaN      9.2      NaN      NaN     10.2
# 1  p01_8460   p01  11:25:00      NaN      NaN      9.9      NaN      NaN
# 2  p01_8461   p01  14:45:00      NaN      5.5      NaN      NaN      5.5
# 3  p01_8462   p01  04:30:00      NaN      3.4      NaN      NaN      3.9
# 4  p01_8463   p01  04:20:00      NaN      NaN      8.3      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:45  activity-0:40  activity-0:35  \
# 0      NaN      NaN  ...            NaN            NaN            NaN
# 1      9.4      NaN  ...            NaN            NaN            NaN
# 2      NaN      NaN  ...            NaN            NaN            NaN
# 3      NaN      NaN  ...            NaN            NaN            NaN
# 4     10.0      NaN  ...            NaN            NaN            NaN
#
#    activity-0:30  activity-0:25  activity-0:20  activity-0:15  activity-0:10  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN           Walk
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    activity-0:05  activity-0:00
# 0            NaN            NaN
# 1           Walk           Walk
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
# [5 rows x 507 columns]

# %%
df_submission = filter_desired_columns(df_submission, False)
df_submission.head(5)
# Out:
#          id p_num      time  bg-0:00  bg-0:05  bg-0:10  bg-0:15  bg-0:20  \
# 0  p01_8459   p01  06:45:00      9.6      NaN      NaN      9.4      NaN
# 1  p01_8460   p01  11:25:00      4.6      NaN      NaN      6.3      NaN
# 2  p01_8461   p01  14:45:00      8.0      NaN      NaN      8.3      NaN
# 3  p01_8462   p01  04:30:00      9.9      NaN      NaN      8.5      NaN
# 4  p01_8463   p01  04:20:00      5.3      NaN      NaN      3.7      NaN
#
#    bg-0:25  bg-0:30  ...  hr-0:15  hr-0:20  hr-0:25  hr-0:30  steps-0:00  \
# 0      NaN      NaN  ...     55.6     53.2     54.4     55.8         NaN
# 1      NaN      6.4  ...     95.6     91.6     93.5     91.1       532.0
# 2      NaN      8.1  ...     75.7     81.1     87.9     92.1        69.0
# 3      NaN      7.8  ...     59.5     58.5     61.2     60.7         0.0
# 4      NaN      3.2  ...     58.9     57.6     55.1     56.2         NaN
#
#    steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05
# 0         NaN         NaN         0.0       6.06       4.90
# 1       377.0       547.0       411.0      32.43      24.57
# 2       283.0        27.0        10.0      10.16      19.76
# 3         NaN         NaN        14.0       4.80       4.90
# 4         NaN         NaN         NaN       4.80       4.80
#
# [5 rows x 31 columns]

# %%
df_submission[columns_to_fill] = df_submission[columns_to_fill].interpolate()
df_submission[columns_to_fill] = imputer.transform(df_submission[columns_to_fill])

# %%
df_submission['minutes_since_start'] = pd.to_datetime(df_submission['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(df_submission['time'], format="%H:%M:%S").dt.minute
df_submission = df_submission.drop(columns=['time'])
df_submission["time_sin"] = np.sin(2 * np.pi / 1440 * df_submission['minutes_since_start']) + 2
df_submission["time_cos"] = np.cos(2 * np.pi / 1440 * df_submission['minutes_since_start']) + 2
df_submission = df_submission.drop(columns=['minutes_since_start'])
df_submission.head(5)
# Out:
#          id p_num  bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  \
# 0  p01_8459   p01      9.6  8.246322  8.33178      9.4  8.258647  8.430463
# 1  p01_8460   p01      4.6  8.246322  8.33178      6.3  8.258647  8.430463
# 2  p01_8461   p01      8.0  8.246322  8.33178      8.3  8.258647  8.430463
# 3  p01_8462   p01      9.9  8.246322  8.33178      8.5  8.258647  8.430463
# 4  p01_8463   p01      5.3  8.246322  8.33178      3.7  8.258647  8.430463
#
#     bg-0:30  bg-0:35  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.282302     10.5  ...     54.4     55.8   44.927039   43.967174
# 1  6.400000     10.2  ...     93.5     91.1  532.000000  377.000000
# 2  8.100000      9.9  ...     87.9     92.1   69.000000  283.000000
# 3  7.800000      9.6  ...     61.2     60.7    0.000000  205.333333
# 4  3.200000      9.3  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 32 columns]

# %%
identifiers_submission = df_submission[cols_to_pop].copy()
df_submission = df_submission.drop(columns=cols_to_pop)
df_submission.head(5)
# Out:
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25   bg-0:30  bg-0:35  \
# 0      9.6  8.246322  8.33178      9.4  8.258647  8.430463  8.282302     10.5
# 1      4.6  8.246322  8.33178      6.3  8.258647  8.430463  6.400000     10.2
# 2      8.0  8.246322  8.33178      8.3  8.258647  8.430463  8.100000      9.9
# 3      9.9  8.246322  8.33178      8.5  8.258647  8.430463  7.800000      9.6
# 4      5.3  8.246322  8.33178      3.7  8.258647  8.430463  3.200000      9.3
#
#     bg-0:40   bg-0:45  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.412561  8.283803  ...     54.4     55.8   44.927039   43.967174
# 1  8.412561  4.500000  ...     93.5     91.1  532.000000  377.000000
# 2  8.412561  6.600000  ...     87.9     92.1   69.000000  283.000000
# 3  8.412561  7.500000  ...     61.2     60.7    0.000000  205.333333
# 4  8.412561  3.400000  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 30 columns]

# %%
print(df_submission.shape)
df_submission.head(5)
# Out:
# (3644, 30)
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25   bg-0:30  bg-0:35  \
# 0      9.6  8.246322  8.33178      9.4  8.258647  8.430463  8.282302     10.5
# 1      4.6  8.246322  8.33178      6.3  8.258647  8.430463  6.400000     10.2
# 2      8.0  8.246322  8.33178      8.3  8.258647  8.430463  8.100000      9.9
# 3      9.9  8.246322  8.33178      8.5  8.258647  8.430463  7.800000      9.6
# 4      5.3  8.246322  8.33178      3.7  8.258647  8.430463  3.200000      9.3
#
#     bg-0:40   bg-0:45  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.412561  8.283803  ...     54.4     55.8   44.927039   43.967174
# 1  8.412561  4.500000  ...     93.5     91.1  532.000000  377.000000
# 2  8.412561  6.600000  ...     87.9     92.1   69.000000  283.000000
# 3  8.412561  7.500000  ...     61.2     60.7    0.000000  205.333333
# 4  8.412561  3.400000  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Predicting submission dataset

# %%
# model = tf.keras.models.load_model("brist1d.keras")

# %%
y_submission = model.predict(df_submission)
df_pred_submission = pd.DataFrame(y_submission, columns=['bg+1:00'])
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %% [markdown]
# ### Joining identifiers

# %%
df_pred_submission = pd.concat([identifiers_submission, df_pred_submission], axis=1)
df_pred_submission.pop('p_num')
df_pred_submission.head(5)
# Out:
#          id    bg+1:00
# 0  p01_8459   9.315093
# 1  p01_8460   5.163402
# 2  p01_8461   7.043850
# 3  p01_8462  10.359314
# 4  p01_8463   7.163373

# %% [markdown]
# ### Exporting submission results

# %%
df_pred_submission.to_csv("dataset/predictions.csv", index=False)
