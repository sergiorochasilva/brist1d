# %% [markdown]
# # Trabalhando os dados

# %% [markdown]
# ## Carregando o dataset

# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_csv('dataset/train_corrigido.csv', header=0)
print(ds.shape)
ds.head(5)
# Out:
# /tmp/ipykernel_30602/1130610560.py:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   ds = pd.read_csv('dataset/train_corrigido.csv', header=0)
# (177024, 509)
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:35  activity-0:30  activity-0:25  \
# 0      9.7      NaN  ...            NaN            NaN            NaN
# 1      9.2      NaN  ...            NaN            NaN            NaN
# 2      8.7      NaN  ...            NaN            NaN            NaN
# 3      8.4      NaN  ...            NaN            NaN            NaN
# 4      8.1      NaN  ...            NaN            NaN            NaN
#
#    activity-0:20  activity-0:15  activity-0:10  activity-0:05  activity-0:00  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    bg+1:00  id_num
# 0     13.4       0
# 1     12.8       1
# 2     15.5       2
# 3     14.8       3
# 4     12.7       4
#
# [5 rows x 509 columns]

# %% [markdown]
# ## Preenchendo os nulos com zero (com exceção das colunas de Atividade Física)

# %%
for prefix in ['bg-', 'insulin-', 'carbs-', 'hr-', 'steps-', 'cals-']:
    cols_to_fill = [col for col in ds.columns if col.startswith(prefix)]

    ds.loc[:, cols_to_fill] = ds.loc[:, cols_to_fill].fillna(0.0)

ds.head(5)
# Out:
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      0.0      0.0      9.6      0.0      0.0
# 1  p01_1   p01  06:25:00      0.0      0.0      9.7      0.0      0.0
# 2  p01_2   p01  06:40:00      0.0      0.0      9.2      0.0      0.0
# 3  p01_3   p01  06:55:00      0.0      0.0      8.7      0.0      0.0
# 4  p01_4   p01  07:10:00      0.0      0.0      8.4      0.0      0.0
#
#    bg-5:30  bg-5:25  ...  activity-0:35  activity-0:30  activity-0:25  \
# 0      9.7      0.0  ...            NaN            NaN            NaN
# 1      9.2      0.0  ...            NaN            NaN            NaN
# 2      8.7      0.0  ...            NaN            NaN            NaN
# 3      8.4      0.0  ...            NaN            NaN            NaN
# 4      8.1      0.0  ...            NaN            NaN            NaN
#
#    activity-0:20  activity-0:15  activity-0:10  activity-0:05  activity-0:00  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    bg+1:00  id_num
# 0     13.4       0
# 1     12.8       1
# 2     15.5       2
# 3     14.8       3
# 4     12.7       4
#
# [5 rows x 509 columns]

# %% [markdown]
# ## Preencher com "other" as ativiades físicas nulas

# %%
cols_to_fill = [col for col in ds.columns if col.startswith('activity-')]

ds.loc[:, cols_to_fill] = ds.loc[:, cols_to_fill].fillna('other')

# %% [markdown]
# ## Convertendo o time num inteiro crescente

# %%
ds['minutes_since_start'] = pd.to_datetime(ds['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(ds['time'], format="%H:%M:%S").dt.minute
ds = ds.drop(columns=['time'])
ds.head(5)
# Out:
#       id p_num  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  bg-5:25  \
# 0  p01_0   p01      0.0      0.0      9.6      0.0      0.0      9.7      0.0
# 1  p01_1   p01      0.0      0.0      9.7      0.0      0.0      9.2      0.0
# 2  p01_2   p01      0.0      0.0      9.2      0.0      0.0      8.7      0.0
# 3  p01_3   p01      0.0      0.0      8.7      0.0      0.0      8.4      0.0
# 4  p01_4   p01      0.0      0.0      8.4      0.0      0.0      8.1      0.0
#
#    bg-5:20  ...  activity-0:30  activity-0:25  activity-0:20  activity-0:15  \
# 0      0.0  ...          other          other          other          other
# 1      0.0  ...          other          other          other          other
# 2      0.0  ...          other          other          other          other
# 3      0.0  ...          other          other          other          other
# 4      0.0  ...          other          other          other          other
#
#    activity-0:10  activity-0:05  activity-0:00  bg+1:00  id_num  \
# 0          other          other          other     13.4       0
# 1          other          other          other     12.8       1
# 2          other          other          other     15.5       2
# 3          other          other          other     14.8       3
# 4          other          other          other     12.7       4
#
#    minutes_since_start
# 0                  370
# 1                  385
# 2                  400
# 3                  415
# 4                  430
#
# [5 rows x 509 columns]

# %% [markdown]
# ## Removendo as colunas de identificação

# %%
cols_to_pop = ['id', 'p_num']
identificadores = ds[cols_to_pop].copy()
ds = ds.drop(columns=cols_to_pop)
ds.head(5)
# Out:
#    bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  bg-5:25  bg-5:20  \
# 0      0.0      0.0      9.6      0.0      0.0      9.7      0.0      0.0
# 1      0.0      0.0      9.7      0.0      0.0      9.2      0.0      0.0
# 2      0.0      0.0      9.2      0.0      0.0      8.7      0.0      0.0
# 3      0.0      0.0      8.7      0.0      0.0      8.4      0.0      0.0
# 4      0.0      0.0      8.4      0.0      0.0      8.1      0.0      0.0
#
#    bg-5:15  bg-5:10  ...  activity-0:30  activity-0:25  activity-0:20  \
# 0      9.2      0.0  ...          other          other          other
# 1      8.7      0.0  ...          other          other          other
# 2      8.4      0.0  ...          other          other          other
# 3      8.1      0.0  ...          other          other          other
# 4      8.3      0.0  ...          other          other          other
#
#    activity-0:15  activity-0:10  activity-0:05  activity-0:00  bg+1:00  \
# 0          other          other          other          other     13.4
# 1          other          other          other          other     12.8
# 2          other          other          other          other     15.5
# 3          other          other          other          other     14.8
# 4          other          other          other          other     12.7
#
#    id_num  minutes_since_start
# 0       0                  370
# 1       1                  385
# 2       2                  400
# 3       3                  415
# 4       4                  430
#
# [5 rows x 507 columns]

# %% [markdown]
# ## Trocando as colunas de atividade por um valor inteiro

# %%
# ds['activity-0:00'].unique()
mapeamento = {
    'other': 0, 'Walk': 1, 'Indoor climbing': 2, 'Yoga': 3, 'Zumba': 4, 'HIIT': 5,
    'Dancing': 6, 'Swim': 7, 'Outdoor Bike': 8, 'Aerobic Workout': 9, 'Sport': 10,
    'Walking': 11, 'Running': 12, 'Swimming': 13, 'Run': 14, 'Weights': 15, 'Workout': 16,
    'Tennis': 17, 'Strength training': 18, 'Stairclimber': 19, 'Spinning': 20, 'Hike': 21,
    'Bike':21
}

prefix = 'activity-'
cols_to_map = [col for col in ds.columns if col.startswith(prefix)]
ds[cols_to_map] = ds[cols_to_map].apply(lambda col: col.map(mapeamento))

ds.head(5)
# Out:
#    bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  bg-5:25  bg-5:20  \
# 0      0.0      0.0      9.6      0.0      0.0      9.7      0.0      0.0
# 1      0.0      0.0      9.7      0.0      0.0      9.2      0.0      0.0
# 2      0.0      0.0      9.2      0.0      0.0      8.7      0.0      0.0
# 3      0.0      0.0      8.7      0.0      0.0      8.4      0.0      0.0
# 4      0.0      0.0      8.4      0.0      0.0      8.1      0.0      0.0
#
#    bg-5:15  bg-5:10  ...  activity-0:30  activity-0:25  activity-0:20  \
# 0      9.2      0.0  ...              0              0              0
# 1      8.7      0.0  ...              0              0              0
# 2      8.4      0.0  ...              0              0              0
# 3      8.1      0.0  ...              0              0              0
# 4      8.3      0.0  ...              0              0              0
#
#    activity-0:15  activity-0:10  activity-0:05  activity-0:00  bg+1:00  \
# 0              0              0              0              0     13.4
# 1              0              0              0              0     12.8
# 2              0              0              0              0     15.5
# 3              0              0              0              0     14.8
# 4              0              0              0              0     12.7
#
#    id_num  minutes_since_start
# 0       0                  370
# 1       1                  385
# 2       2                  400
# 3       3                  415
# 4       4                  430
#
# [5 rows x 507 columns]

# %% [markdown]
# # Montando o modelo

# %% [markdown]
# ## Separando treino e teste

# %%
train = ds
# test = ds.drop(train.index)

# %%
x_train = train
y_train = train.pop('bg+1:00')

# %%
print(x_train.shape)
x_train.head(5)
# Out:
# (132768, 506)
#        bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  bg-5:25  bg-5:20  \
# 91143      0.0      0.0      4.9      0.0      0.0      5.2      0.0      0.0
# 35758     11.0     11.0     11.4     11.7     12.4     12.6     13.0     13.6
# 65296      9.5      9.4      9.9     10.0     10.3     10.2     10.2      9.8
# 14652      7.7      7.7      8.0      8.2      8.7      9.8     10.5     10.8
# 54561      9.3      9.5      9.2      8.7      8.4      7.9      7.3      6.9
#
#        bg-5:15  bg-5:10  ...  activity-0:35  activity-0:30  activity-0:25  \
# 91143      6.7      0.0  ...              0              0              0
# 35758     13.8     14.5  ...              0              0              0
# 65296      9.4      9.3  ...              0              0              0
# 14652     10.7     10.7  ...              0              0              0
# 54561      6.5      6.2  ...              0              0              0
#
#        activity-0:20  activity-0:15  activity-0:10  activity-0:05  \
# 91143              0              0              0              1
# 35758              0              0              0              0
# 65296              0              0              0              0
# 14652              0              0              0              0
# 54561              0              0              0              0
#
#        activity-0:00  id_num  minutes_since_start
# 91143              1    6098                 1280
# 35758              0    1427                  300
# 65296              0    4937                  965
# 14652              0    6193                  100
# 54561              0   20230                  440
#
# [5 rows x 506 columns]

# %%
print(y_train.shape)
y_train.head(5)
# Out:
# (132768,)
# 91143    7.6
# 35758    7.6
# 65296    6.2
# 14652    9.0
# 54561    5.7
# Name: bg+1:00, dtype: float64

# %% [markdown]
# ## Construindo o modelo

# %%
from keras.layers import TimeDistributed, Dense, Input, Lambda, BatchNormalization, Concatenate, Conv1D, ZeroPadding1D
from keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.callbacks import EarlyStopping
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Configurando para não alocar diretamente toda a memória da GPU (alocar conforme necessário)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)  # Aloca memória conforme necessário
    except RuntimeError as e:
        print(e)
# Out:
# 2024-11-13 00:30:13.741500: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-13 00:30:13.750576: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1731468613.760774   30602 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1731468613.763602   30602 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-13 00:30:13.774701: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available:  1

# %%
def extrator_features(input_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims), activation=activation, use_bias=bias, kernel_regularizer="l2")(input_layer)
  x_1 = tf.keras.layers.Dropout(0.2)(x_0)
  x_2 = Dense(int(input_dims/4), activation=activation, use_bias=bias)(x_1)
  x_3 = Dense(int(input_dims/8), activation=activation, use_bias=bias)(x_2)
  x_4 = Dense(int(input_dims/16), activation=activation, use_bias=bias)(x_3)
  x_bottleneck = Dense(int(input_dims/16), activation=activation, name='encoder', use_bias=True, kernel_regularizer="l1")(x_4)

  return Model(input_layer, x_bottleneck, name="features")

def regressor(input_dims, output_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims/2), activation=activation, use_bias=bias)(input_layer)
  x_2 = Dense(int(input_dims/4), activation=activation, use_bias=bias)(x_0)
  saidas = Dense(output_dims, activation=None, name='regressor_saidas', use_bias=bias)(x_2)

  return Model(input_layer, saidas, name="regressor")

def build_models(input_dims, output_dims, activation, bias):
  # Camadas de entrada
  input_layer = Input(shape=[input_dims])

  x_n = BatchNormalization()(input_layer)

  # Kernels
  extrator = extrator_features(input_dims, activation, bias)

  # Features
  features = extrator(x_n)

  # Regressão
  regressao = regressor(features.shape[1], output_dims, activation, bias)

  saida = regressao(features)
  
  return (
      Model(input_layer, saida, name="regressao"),
      Model(input_layer, features, name="projecao")
  )

model, features = build_models(x_train.shape[1], 1, 'relu', False)
model.compile(optimizer='adam', loss='mse', metrics=['mae', 'mse', 'mean_absolute_percentage_error'])
plot_model(model, show_shapes=True, expand_nested=True)
# Out:
# I0000 00:00:1731468615.209239   30602 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2609 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# ## Treinando o modelo

# %%
# Callback para recuperar o melhor peso, e parar quando ficar três épocas sem melhora
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20, restore_best_weights=True)

# Treinando o modelo
history = model.fit(x_train, y_train, epochs=200, callbacks=[callback])
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731468617.537690   30690 service.cc:148] XLA service 0x78b09c017130 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731468617.537711   30690 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2024-11-13 00:30:17.574947: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1731468617.713456   30690 cuda_dnn.cc:529] Loaded cuDNN version 90501
#  234/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 765us/step - loss: 23.2085 - mae: 3.0682 - mean_absolute_percentage_error: 38.6402 - mse: 17.1324
# I0000 00:00:1731468619.494491   30690 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 10.9105 - mae: 2.0361 - mean_absolute_percentage_error: 26.3714 - mse: 7.5777 - val_loss: 6.1632 - val_mae: 1.7212 - val_mean_absolute_percentage_error: 23.6060 - val_mse: 5.2911
# Epoch 2/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 806us/step - loss: 6.1549 - mae: 1.7485 - mean_absolute_percentage_error: 22.9268 - mse: 5.3806 - val_loss: 6.0073 - val_mae: 1.8078 - val_mean_absolute_percentage_error: 25.2744 - val_mse: 5.4192
# Epoch 3/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 791us/step - loss: 5.6204 - mae: 1.6937 - mean_absolute_percentage_error: 22.3103 - mse: 5.0827 - val_loss: 5.3258 - val_mae: 1.6172 - val_mean_absolute_percentage_error: 19.9778 - val_mse: 4.8917
# Epoch 4/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 782us/step - loss: 5.3126 - mae: 1.6627 - mean_absolute_percentage_error: 21.9485 - mse: 4.8972 - val_loss: 4.8286 - val_mae: 1.5628 - val_mean_absolute_percentage_error: 20.8671 - val_mse: 4.4349
# Epoch 5/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 793us/step - loss: 5.1462 - mae: 1.6356 - mean_absolute_percentage_error: 21.6165 - mse: 4.7574 - val_loss: 4.8722 - val_mae: 1.5917 - val_mean_absolute_percentage_error: 21.7429 - val_mse: 4.4879
# Epoch 6/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 787us/step - loss: 5.0255 - mae: 1.6149 - mean_absolute_percentage_error: 21.4132 - mse: 4.6498 - val_loss: 4.6256 - val_mae: 1.5297 - val_mean_absolute_percentage_error: 20.6059 - val_mse: 4.2515
# Epoch 7/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 797us/step - loss: 4.9647 - mae: 1.6012 - mean_absolute_percentage_error: 21.2764 - mse: 4.5852 - val_loss: 4.6032 - val_mae: 1.5380 - val_mean_absolute_percentage_error: 20.7082 - val_mse: 4.2291
# Epoch 8/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 796us/step - loss: 4.8497 - mae: 1.5790 - mean_absolute_percentage_error: 20.9416 - mse: 4.4781 - val_loss: 4.4954 - val_mae: 1.5104 - val_mean_absolute_percentage_error: 20.2246 - val_mse: 4.1311
# Epoch 9/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 793us/step - loss: 4.7983 - mae: 1.5711 - mean_absolute_percentage_error: 20.7948 - mse: 4.4314 - val_loss: 4.4789 - val_mae: 1.4974 - val_mean_absolute_percentage_error: 19.7005 - val_mse: 4.1452
# Epoch 10/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 785us/step - loss: 4.8185 - mae: 1.5767 - mean_absolute_percentage_error: 20.8686 - mse: 4.4758 - val_loss: 4.6692 - val_mae: 1.5490 - val_mean_absolute_percentage_error: 20.4747 - val_mse: 4.2987
# Epoch 11/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 796us/step - loss: 4.7506 - mae: 1.5666 - mean_absolute_percentage_error: 20.7764 - mse: 4.4122 - val_loss: 4.8035 - val_mae: 1.5523 - val_mean_absolute_percentage_error: 19.5928 - val_mse: 4.4755
# Epoch 12/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 786us/step - loss: 4.7404 - mae: 1.5685 - mean_absolute_percentage_error: 20.7094 - mse: 4.4116 - val_loss: 4.5988 - val_mae: 1.5235 - val_mean_absolute_percentage_error: 19.6678 - val_mse: 4.2595
# Epoch 13/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 792us/step - loss: 4.7132 - mae: 1.5602 - mean_absolute_percentage_error: 20.6369 - mse: 4.3810 - val_loss: 4.7008 - val_mae: 1.5412 - val_mean_absolute_percentage_error: 19.5309 - val_mse: 4.3724
# Epoch 14/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 801us/step - loss: 4.7436 - mae: 1.5648 - mean_absolute_percentage_error: 20.6996 - mse: 4.4158 - val_loss: 4.4634 - val_mae: 1.5085 - val_mean_absolute_percentage_error: 19.8620 - val_mse: 4.1336
# Epoch 15/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 795us/step - loss: 4.6854 - mae: 1.5518 - mean_absolute_percentage_error: 20.5856 - mse: 4.3561 - val_loss: 4.3596 - val_mae: 1.4895 - val_mean_absolute_percentage_error: 19.8470 - val_mse: 4.0536
# Epoch 16/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 800us/step - loss: 4.7177 - mae: 1.5643 - mean_absolute_percentage_error: 20.6937 - mse: 4.3925 - val_loss: 4.4781 - val_mae: 1.5342 - val_mean_absolute_percentage_error: 21.0551 - val_mse: 4.1694
# Epoch 17/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 796us/step - loss: 4.6799 - mae: 1.5572 - mean_absolute_percentage_error: 20.6417 - mse: 4.3670 - val_loss: 4.3994 - val_mae: 1.5020 - val_mean_absolute_percentage_error: 20.0032 - val_mse: 4.0735
# Epoch 18/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 803us/step - loss: 4.6529 - mae: 1.5534 - mean_absolute_percentage_error: 20.5775 - mse: 4.3284 - val_loss: 4.3701 - val_mae: 1.5038 - val_mean_absolute_percentage_error: 20.3664 - val_mse: 4.0468
# Epoch 19/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 800us/step - loss: 4.6598 - mae: 1.5519 - mean_absolute_percentage_error: 20.6072 - mse: 4.3273 - val_loss: 4.3448 - val_mae: 1.5038 - val_mean_absolute_percentage_error: 20.3021 - val_mse: 4.0228
# Epoch 20/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 829us/step - loss: 4.6363 - mae: 1.5488 - mean_absolute_percentage_error: 20.4422 - mse: 4.3131 - val_loss: 4.5128 - val_mae: 1.5184 - val_mean_absolute_percentage_error: 20.5416 - val_mse: 4.1876
# Epoch 21/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 915us/step - loss: 4.7304 - mae: 1.5609 - mean_absolute_percentage_error: 20.6800 - mse: 4.3913 - val_loss: 4.4391 - val_mae: 1.5239 - val_mean_absolute_percentage_error: 20.8120 - val_mse: 4.1392
# Epoch 22/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 914us/step - loss: 4.6302 - mae: 1.5488 - mean_absolute_percentage_error: 20.5015 - mse: 4.3008 - val_loss: 4.3746 - val_mae: 1.5030 - val_mean_absolute_percentage_error: 20.2841 - val_mse: 4.0636
# Epoch 23/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 872us/step - loss: 4.6439 - mae: 1.5507 - mean_absolute_percentage_error: 20.4929 - mse: 4.3213 - val_loss: 4.3807 - val_mae: 1.5058 - val_mean_absolute_percentage_error: 20.4676 - val_mse: 4.0688
# Epoch 24/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 874us/step - loss: 4.6155 - mae: 1.5434 - mean_absolute_percentage_error: 20.4795 - mse: 4.2902 - val_loss: 4.3643 - val_mae: 1.5015 - val_mean_absolute_percentage_error: 20.4654 - val_mse: 4.0428
# Epoch 25/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 881us/step - loss: 4.6009 - mae: 1.5414 - mean_absolute_percentage_error: 20.4232 - mse: 4.2635 - val_loss: 4.3695 - val_mae: 1.5146 - val_mean_absolute_percentage_error: 20.7971 - val_mse: 4.0424
# Epoch 26/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 859us/step - loss: 4.6130 - mae: 1.5444 - mean_absolute_percentage_error: 20.4370 - mse: 4.2765 - val_loss: 4.3808 - val_mae: 1.5178 - val_mean_absolute_percentage_error: 20.9476 - val_mse: 4.0543
# Epoch 27/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 854us/step - loss: 4.6390 - mae: 1.5454 - mean_absolute_percentage_error: 20.4898 - mse: 4.3055 - val_loss: 4.3550 - val_mae: 1.4995 - val_mean_absolute_percentage_error: 20.2023 - val_mse: 4.0125
# Epoch 28/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 857us/step - loss: 4.6048 - mae: 1.5405 - mean_absolute_percentage_error: 20.4192 - mse: 4.2637 - val_loss: 4.4146 - val_mae: 1.5147 - val_mean_absolute_percentage_error: 20.7206 - val_mse: 4.0831
# Epoch 29/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 837us/step - loss: 4.6284 - mae: 1.5441 - mean_absolute_percentage_error: 20.4375 - mse: 4.2898 - val_loss: 4.3744 - val_mae: 1.5098 - val_mean_absolute_percentage_error: 20.3400 - val_mse: 4.0353
# Epoch 30/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 840us/step - loss: 4.5728 - mae: 1.5378 - mean_absolute_percentage_error: 20.4043 - mse: 4.2290 - val_loss: 4.7857 - val_mae: 1.5875 - val_mean_absolute_percentage_error: 22.0578 - val_mse: 4.4498
# Epoch 31/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 865us/step - loss: 4.6447 - mae: 1.5457 - mean_absolute_percentage_error: 20.4800 - mse: 4.3032 - val_loss: 4.3347 - val_mae: 1.5090 - val_mean_absolute_percentage_error: 20.7864 - val_mse: 4.0105
# Epoch 32/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 859us/step - loss: 4.5576 - mae: 1.5323 - mean_absolute_percentage_error: 20.3520 - mse: 4.2263 - val_loss: 4.3965 - val_mae: 1.5046 - val_mean_absolute_percentage_error: 19.9933 - val_mse: 4.0685
# Epoch 33/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 857us/step - loss: 4.5869 - mae: 1.5360 - mean_absolute_percentage_error: 20.3431 - mse: 4.2445 - val_loss: 4.4832 - val_mae: 1.5341 - val_mean_absolute_percentage_error: 21.1861 - val_mse: 4.1581
# Epoch 34/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 900us/step - loss: 4.5551 - mae: 1.5320 - mean_absolute_percentage_error: 20.2992 - mse: 4.2157 - val_loss: 4.3628 - val_mae: 1.4846 - val_mean_absolute_percentage_error: 19.6147 - val_mse: 4.0304
# Epoch 35/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 914us/step - loss: 4.5963 - mae: 1.5395 - mean_absolute_percentage_error: 20.4392 - mse: 4.2510 - val_loss: 4.2917 - val_mae: 1.4803 - val_mean_absolute_percentage_error: 19.7432 - val_mse: 3.9719
# Epoch 36/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 997us/step - loss: 4.5552 - mae: 1.5327 - mean_absolute_percentage_error: 20.3499 - mse: 4.2167 - val_loss: 4.3952 - val_mae: 1.4839 - val_mean_absolute_percentage_error: 19.2377 - val_mse: 4.0520
# Epoch 37/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 826us/step - loss: 4.5916 - mae: 1.5362 - mean_absolute_percentage_error: 20.3279 - mse: 4.2401 - val_loss: 4.4400 - val_mae: 1.5246 - val_mean_absolute_percentage_error: 21.0776 - val_mse: 4.0911
# Epoch 38/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 870us/step - loss: 4.6461 - mae: 1.5460 - mean_absolute_percentage_error: 20.5002 - mse: 4.2867 - val_loss: 4.2990 - val_mae: 1.4733 - val_mean_absolute_percentage_error: 19.6096 - val_mse: 3.9676
# Epoch 39/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 841us/step - loss: 4.5792 - mae: 1.5403 - mean_absolute_percentage_error: 20.4352 - mse: 4.2384 - val_loss: 4.3515 - val_mae: 1.4980 - val_mean_absolute_percentage_error: 20.3625 - val_mse: 4.0028
# Epoch 40/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 911us/step - loss: 4.5295 - mae: 1.5282 - mean_absolute_percentage_error: 20.2920 - mse: 4.1844 - val_loss: 4.3497 - val_mae: 1.4825 - val_mean_absolute_percentage_error: 19.5594 - val_mse: 4.0099
# Epoch 41/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 874us/step - loss: 4.6032 - mae: 1.5381 - mean_absolute_percentage_error: 20.3445 - mse: 4.2547 - val_loss: 4.4404 - val_mae: 1.4878 - val_mean_absolute_percentage_error: 19.2115 - val_mse: 4.0842
# Epoch 42/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 856us/step - loss: 4.6023 - mae: 1.5413 - mean_absolute_percentage_error: 20.4355 - mse: 4.2428 - val_loss: 4.2659 - val_mae: 1.4688 - val_mean_absolute_percentage_error: 19.5517 - val_mse: 3.9345
# Epoch 43/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 876us/step - loss: 4.5722 - mae: 1.5342 - mean_absolute_percentage_error: 20.3206 - mse: 4.2279 - val_loss: 4.4022 - val_mae: 1.5130 - val_mean_absolute_percentage_error: 20.6794 - val_mse: 4.0606
# Epoch 44/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 866us/step - loss: 4.6327 - mae: 1.5449 - mean_absolute_percentage_error: 20.4267 - mse: 4.2823 - val_loss: 4.3043 - val_mae: 1.4874 - val_mean_absolute_percentage_error: 20.1604 - val_mse: 3.9656
# Epoch 45/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 848us/step - loss: 4.5798 - mae: 1.5309 - mean_absolute_percentage_error: 20.3230 - mse: 4.2260 - val_loss: 4.3729 - val_mae: 1.4893 - val_mean_absolute_percentage_error: 20.1340 - val_mse: 4.0343
# Epoch 46/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 849us/step - loss: 4.5510 - mae: 1.5273 - mean_absolute_percentage_error: 20.2561 - mse: 4.2002 - val_loss: 4.3391 - val_mae: 1.4882 - val_mean_absolute_percentage_error: 19.9502 - val_mse: 3.9837
# Epoch 47/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 907us/step - loss: 4.5901 - mae: 1.5346 - mean_absolute_percentage_error: 20.3087 - mse: 4.2316 - val_loss: 4.3641 - val_mae: 1.4802 - val_mean_absolute_percentage_error: 19.5999 - val_mse: 4.0069
# Epoch 48/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 870us/step - loss: 4.5394 - mae: 1.5255 - mean_absolute_percentage_error: 20.1762 - mse: 4.1833 - val_loss: 4.3407 - val_mae: 1.4891 - val_mean_absolute_percentage_error: 20.2189 - val_mse: 3.9765
# Epoch 49/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 904us/step - loss: 4.5231 - mae: 1.5233 - mean_absolute_percentage_error: 20.2038 - mse: 4.1681 - val_loss: 4.3355 - val_mae: 1.4852 - val_mean_absolute_percentage_error: 19.7543 - val_mse: 3.9821
# Epoch 50/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 860us/step - loss: 4.5855 - mae: 1.5341 - mean_absolute_percentage_error: 20.3287 - mse: 4.2340 - val_loss: 4.3426 - val_mae: 1.4704 - val_mean_absolute_percentage_error: 19.1911 - val_mse: 3.9987
# Epoch 51/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 885us/step - loss: 4.5550 - mae: 1.5286 - mean_absolute_percentage_error: 20.2510 - mse: 4.1960 - val_loss: 4.2868 - val_mae: 1.4680 - val_mean_absolute_percentage_error: 19.5170 - val_mse: 3.9353
# Epoch 52/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 844us/step - loss: 4.5792 - mae: 1.5325 - mean_absolute_percentage_error: 20.2728 - mse: 4.2229 - val_loss: 4.3308 - val_mae: 1.4760 - val_mean_absolute_percentage_error: 19.4713 - val_mse: 3.9731
# Epoch 53/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 852us/step - loss: 4.5319 - mae: 1.5236 - mean_absolute_percentage_error: 20.1554 - mse: 4.1699 - val_loss: 4.3382 - val_mae: 1.4830 - val_mean_absolute_percentage_error: 19.9519 - val_mse: 3.9643
# Epoch 54/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 843us/step - loss: 4.5663 - mae: 1.5313 - mean_absolute_percentage_error: 20.3177 - mse: 4.2004 - val_loss: 4.3487 - val_mae: 1.4988 - val_mean_absolute_percentage_error: 20.2671 - val_mse: 4.0108
# Epoch 55/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 851us/step - loss: 4.5772 - mae: 1.5322 - mean_absolute_percentage_error: 20.3363 - mse: 4.2201 - val_loss: 4.2981 - val_mae: 1.4750 - val_mean_absolute_percentage_error: 19.7247 - val_mse: 3.9442
# Epoch 56/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 891us/step - loss: 4.5735 - mae: 1.5310 - mean_absolute_percentage_error: 20.3315 - mse: 4.2214 - val_loss: 4.3153 - val_mae: 1.4719 - val_mean_absolute_percentage_error: 19.4123 - val_mse: 3.9617
# Epoch 57/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 876us/step - loss: 4.6067 - mae: 1.5343 - mean_absolute_percentage_error: 20.3341 - mse: 4.2403 - val_loss: 4.3302 - val_mae: 1.4695 - val_mean_absolute_percentage_error: 19.2224 - val_mse: 3.9754
# Epoch 58/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 899us/step - loss: 4.6059 - mae: 1.5359 - mean_absolute_percentage_error: 20.2615 - mse: 4.2379 - val_loss: 4.3195 - val_mae: 1.4985 - val_mean_absolute_percentage_error: 20.2720 - val_mse: 3.9700
# Epoch 59/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 841us/step - loss: 4.5665 - mae: 1.5264 - mean_absolute_percentage_error: 20.2059 - mse: 4.2068 - val_loss: 4.4679 - val_mae: 1.5176 - val_mean_absolute_percentage_error: 20.6391 - val_mse: 4.1001
# Epoch 60/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 910us/step - loss: 4.5406 - mae: 1.5258 - mean_absolute_percentage_error: 20.1965 - mse: 4.1706 - val_loss: 4.5593 - val_mae: 1.5353 - val_mean_absolute_percentage_error: 20.8783 - val_mse: 4.1935
# Epoch 61/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.5679 - mae: 1.5295 - mean_absolute_percentage_error: 20.3125 - mse: 4.2017 - val_loss: 4.4255 - val_mae: 1.5077 - val_mean_absolute_percentage_error: 20.5811 - val_mse: 4.0789
# Epoch 62/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 937us/step - loss: 4.5722 - mae: 1.5277 - mean_absolute_percentage_error: 20.2575 - mse: 4.2037 - val_loss: 4.2618 - val_mae: 1.4653 - val_mean_absolute_percentage_error: 19.6070 - val_mse: 3.8963
# Epoch 63/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 889us/step - loss: 4.5532 - mae: 1.5285 - mean_absolute_percentage_error: 20.2598 - mse: 4.1868 - val_loss: 4.4645 - val_mae: 1.5175 - val_mean_absolute_percentage_error: 20.9991 - val_mse: 4.0937
# Epoch 64/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 994us/step - loss: 4.5840 - mae: 1.5323 - mean_absolute_percentage_error: 20.3002 - mse: 4.2152 - val_loss: 4.3126 - val_mae: 1.4696 - val_mean_absolute_percentage_error: 19.4233 - val_mse: 3.9556
# Epoch 65/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 929us/step - loss: 4.5496 - mae: 1.5273 - mean_absolute_percentage_error: 20.2885 - mse: 4.1832 - val_loss: 4.3695 - val_mae: 1.4786 - val_mean_absolute_percentage_error: 19.2781 - val_mse: 4.0106
# Epoch 66/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 915us/step - loss: 4.5286 - mae: 1.5239 - mean_absolute_percentage_error: 20.1824 - mse: 4.1629 - val_loss: 4.3797 - val_mae: 1.4847 - val_mean_absolute_percentage_error: 19.8923 - val_mse: 4.0136
# Epoch 67/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 853us/step - loss: 4.5589 - mae: 1.5252 - mean_absolute_percentage_error: 20.2675 - mse: 4.1845 - val_loss: 4.3693 - val_mae: 1.4787 - val_mean_absolute_percentage_error: 19.5311 - val_mse: 3.9834
# Epoch 68/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 921us/step - loss: 4.5429 - mae: 1.5236 - mean_absolute_percentage_error: 20.2409 - mse: 4.1627 - val_loss: 4.4567 - val_mae: 1.4901 - val_mean_absolute_percentage_error: 19.6392 - val_mse: 4.0898
# Epoch 69/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 890us/step - loss: 4.5564 - mae: 1.5249 - mean_absolute_percentage_error: 20.1559 - mse: 4.1817 - val_loss: 4.3394 - val_mae: 1.4927 - val_mean_absolute_percentage_error: 20.2259 - val_mse: 3.9796
# Epoch 70/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 884us/step - loss: 4.5835 - mae: 1.5261 - mean_absolute_percentage_error: 20.1928 - mse: 4.2053 - val_loss: 4.3420 - val_mae: 1.4889 - val_mean_absolute_percentage_error: 20.0068 - val_mse: 3.9788
# Epoch 71/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 916us/step - loss: 4.5241 - mae: 1.5208 - mean_absolute_percentage_error: 20.1827 - mse: 4.1496 - val_loss: 4.3515 - val_mae: 1.4653 - val_mean_absolute_percentage_error: 19.0241 - val_mse: 3.9868
# Epoch 72/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 898us/step - loss: 4.5294 - mae: 1.5208 - mean_absolute_percentage_error: 20.0818 - mse: 4.1502 - val_loss: 4.4284 - val_mae: 1.4822 - val_mean_absolute_percentage_error: 19.0783 - val_mse: 4.0612
# Epoch 73/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 910us/step - loss: 4.5561 - mae: 1.5252 - mean_absolute_percentage_error: 20.2320 - mse: 4.1790 - val_loss: 4.6438 - val_mae: 1.5762 - val_mean_absolute_percentage_error: 22.2111 - val_mse: 4.2662
# Epoch 74/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 892us/step - loss: 4.6077 - mae: 1.5310 - mean_absolute_percentage_error: 20.3116 - mse: 4.2270 - val_loss: 4.3293 - val_mae: 1.4656 - val_mean_absolute_percentage_error: 19.3610 - val_mse: 3.9488
# Epoch 75/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 890us/step - loss: 4.5084 - mae: 1.5171 - mean_absolute_percentage_error: 20.0974 - mse: 4.1346 - val_loss: 4.3717 - val_mae: 1.4975 - val_mean_absolute_percentage_error: 20.2454 - val_mse: 3.9973
# Epoch 76/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 876us/step - loss: 4.4962 - mae: 1.5169 - mean_absolute_percentage_error: 20.1097 - mse: 4.1181 - val_loss: 4.3833 - val_mae: 1.4887 - val_mean_absolute_percentage_error: 20.1499 - val_mse: 4.0004
# Epoch 77/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 861us/step - loss: 4.5266 - mae: 1.5198 - mean_absolute_percentage_error: 20.1369 - mse: 4.1422 - val_loss: 4.3391 - val_mae: 1.4719 - val_mean_absolute_percentage_error: 19.5283 - val_mse: 3.9693
# Epoch 78/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 883us/step - loss: 4.5430 - mae: 1.5220 - mean_absolute_percentage_error: 20.1570 - mse: 4.1648 - val_loss: 4.3687 - val_mae: 1.4820 - val_mean_absolute_percentage_error: 19.6658 - val_mse: 3.9898
# Epoch 79/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 895us/step - loss: 4.5480 - mae: 1.5250 - mean_absolute_percentage_error: 20.1948 - mse: 4.1689 - val_loss: 4.5751 - val_mae: 1.5029 - val_mean_absolute_percentage_error: 19.0718 - val_mse: 4.2016
# Epoch 80/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 875us/step - loss: 4.6145 - mae: 1.5343 - mean_absolute_percentage_error: 20.2957 - mse: 4.2267 - val_loss: 4.4779 - val_mae: 1.5225 - val_mean_absolute_percentage_error: 20.9237 - val_mse: 4.1078
# Epoch 81/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 4.5317 - mae: 1.5226 - mean_absolute_percentage_error: 20.2042 - mse: 4.1464 - val_loss: 4.3987 - val_mae: 1.5035 - val_mean_absolute_percentage_error: 20.3604 - val_mse: 4.0151
# Epoch 82/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 981us/step - loss: 4.5857 - mae: 1.5312 - mean_absolute_percentage_error: 20.3183 - mse: 4.1964 - val_loss: 4.3734 - val_mae: 1.4736 - val_mean_absolute_percentage_error: 19.3627 - val_mse: 3.9910

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist['rmse'] = np.sqrt(hist['mse'])
# hist['val_rmse'] = np.sqrt(hist['val_mse'])
hist.tail()
# Out:
#         loss       mae  mean_absolute_percentage_error       mse  val_loss  \
# 77  4.562106  1.525465                       20.204006  4.179803  4.368730
# 78  4.563299  1.526585                       20.216814  4.184484  4.575140
# 79  4.595165  1.530685                       20.275909  4.208359  4.477910
# 80  4.575130  1.527091                       20.226797  4.187167  4.398658
# 81  4.582296  1.528758                       20.245125  4.197751  4.373404
#
#      val_mae  val_mean_absolute_percentage_error   val_mse  epoch      rmse  \
# 77  1.482031                           19.665825  3.989753     77  2.044457
# 78  1.502921                           19.071833  4.201586     78  2.045601
# 79  1.522461                           20.923702  4.107775     79  2.051428
# 80  1.503463                           20.360426  4.015121     80  2.046257
# 81  1.473577                           19.362688  3.990978     81  2.048841
#
#     val_rmse
# 77  1.997437
# 78  2.049777
# 79  2.026765
# 80  2.003777
# 81  1.997743

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.title("Evolução das funções de perda durante o treinamento da rede")
plt.xlabel('Rodada')
plt.ylabel('Root Mean Square Error')
plt.plot(hist['epoch'], hist['rmse'], label='RMSE Treino')
# plt.plot(hist['epoch'], hist['val_rmse'], label = 'RMSE Validação')
plt.legend()

plt.figure()
plt.xlabel('Rodada')
plt.ylabel('Mean Absolute Error')
plt.plot(hist['epoch'], hist['mae'], label='MAE Treino')
# plt.plot(hist['epoch'], hist['val_mae'], label = 'MAE Validação')
plt.legend()

plt.show()

# %% [markdown]
# ## Avaliando o modelo nos dados de teste

# %% [markdown]
# ### Ajustando a base de teste

# %%
# x_test = test
# y_test = test.pop('bg+1:00')
# print(x_test.shape)
# x_test.head(5)
# Out:
# (44256, 506)
#     bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  bg-5:25  bg-5:20  \
# 2       0.0      0.0      9.2      0.0      0.0      8.7      0.0      0.0
# 10      0.0      0.0     12.8      0.0      0.0     13.9      0.0      0.0
# 21      0.0      0.0     17.3      0.0      0.0     16.2      0.0      0.0
# 27      0.0     13.4      0.0      0.0     12.8      0.0      0.0     15.5
# 30      0.0     14.8      0.0      0.0     12.7      0.0      0.0     11.4
#
#     bg-5:15  bg-5:10  ...  activity-0:35  activity-0:30  activity-0:25  \
# 2       8.4      0.0  ...              0              0              0
# 10     14.2      0.0  ...              0              0              0
# 21     15.1      0.0  ...              0              0              0
# 27      0.0      0.0  ...              0              0              0
# 30      0.0      0.0  ...              0              0              0
#
#     activity-0:20  activity-0:15  activity-0:10  activity-0:05  activity-0:00  \
# 2               0              0              0              0              0
# 10              0              0              0              0              0
# 21              0              0              0              0              0
# 27              0              0              0              0              0
# 30              0              0              0              0              0
#
#     id_num  minutes_since_start
# 2        2                  400
# 10      10                  520
# 21      21                  685
# 27      27                  780
# 30      30                  825
#
# [5 rows x 506 columns]

# %%
# y_test.head(5)
# Out:
# 2     15.5
# 10    17.4
# 21     4.8
# 27    13.1
# 30     8.3
# Name: bg+1:00, dtype: float64

# %% [markdown]
# ### Prevendo para a base de teste

# %%
# y_pred = model.predict(x_test)
# print(y_pred)
# Out:
# 1383/1383 ━━━━━━━━━━━━━━━━━━━━ 1s 509us/step
# [[12.604627 ]
#  [10.790003 ]
#  [ 6.474668 ]
#  ...
#  [ 7.0029993]
#  [ 9.326539 ]
#  [11.3630085]]

# %% [markdown]
# ### Calculando o erro para a base de teste

# %%
# mse = tf.keras.losses.MSE(y_test, y_pred).numpy().mean()
# mae = tf.keras.losses.MAE(y_test, y_pred).numpy().mean()
# rmse = np.sqrt(mse)

# %%
# print(f"RMSE Test: {rmse}")
# print(f"MSE Test: {mse}")
# print(f"MAE Test: {mae}")
# Out:
# RMSE Test: 1.9797496795654297
# MSE Test: 3.9194087982177734
# MAE Test: 1.4624000787734985

# %% [markdown]
# ## Salvando o modelo em arquivo

# %%
model.save("brist1d.keras")
