# %% [markdown]
# # Brist1D - Kaggle competition

# %% [markdown]
# ## Loading and hadling dataset

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('dataset/train_corrigido.csv', header=0)
print(df.shape)
df.head(5)
# Out:
# /tmp/ipykernel_47051/1091358297.py:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset/train_corrigido.csv', header=0)
# (177024, 509)
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:35  activity-0:30  activity-0:25  \
# 0      9.7      NaN  ...            NaN            NaN            NaN
# 1      9.2      NaN  ...            NaN            NaN            NaN
# 2      8.7      NaN  ...            NaN            NaN            NaN
# 3      8.4      NaN  ...            NaN            NaN            NaN
# 4      8.1      NaN  ...            NaN            NaN            NaN
#
#    activity-0:20  activity-0:15  activity-0:10  activity-0:05  activity-0:00  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    bg+1:00  id_num
# 0     13.4       0
# 1     12.8       1
# 2     15.5       2
# 3     14.8       3
# 4     12.7       4
#
# [5 rows x 509 columns]

# %% [markdown]
# ## Filtering desired collumns (based on a correlation analises)

# %%
def filter_desired_columns(data, include_target: bool = True):
    desired_columns = [
        "id", "p_num", "time",
        "bg-0:00", "bg-0:05", "bg-0:10", "bg-0:15", "bg-0:20", "bg-0:25", "bg-0:30", "bg-0:35", "bg-0:40", "bg-0:45",
        "insulin-0:00", "insulin-0:05", "insulin-0:10", "insulin-0:15", "insulin-0:20",
        "hr-0:00", "hr-0:05", "hr-0:10", "hr-0:15", "hr-0:20", "hr-0:25", "hr-0:30",
        "steps-0:00", "steps-0:05", "steps-0:10", "steps-0:15",
        "cals-0:00", "cals-0:05",
    ]

    if include_target:
        desired_columns.append("bg+1:00")
        
    return data[desired_columns]

df = filter_desired_columns(df)
df.head(5)
# Out:
#       id p_num      time  bg-0:00  bg-0:05  bg-0:10  bg-0:15  bg-0:20  \
# 0  p01_0   p01  06:10:00     15.1      NaN      NaN     16.2      NaN
# 1  p01_1   p01  06:25:00     14.4      NaN      NaN     15.1      NaN
# 2  p01_2   p01  06:40:00     13.9      NaN      NaN     14.4      NaN
# 3  p01_3   p01  06:55:00     13.8      NaN      NaN     13.9      NaN
# 4  p01_4   p01  07:10:00     13.4      NaN      NaN     13.8      NaN
#
#    bg-0:25  bg-0:30  ...  hr-0:20  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0      NaN     17.3  ...      NaN      NaN      NaN         NaN         NaN
# 1      NaN     16.2  ...      NaN      NaN      NaN         NaN         NaN
# 2      NaN     15.1  ...      NaN      NaN      NaN         NaN         NaN
# 3      NaN     14.4  ...      NaN      NaN      NaN         NaN         NaN
# 4      NaN     13.9  ...      NaN      NaN      NaN         NaN         NaN
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  bg+1:00
# 0         NaN         NaN        NaN        NaN     13.4
# 1         NaN         NaN        NaN        NaN     12.8
# 2         NaN         NaN        NaN        NaN     15.5
# 3         NaN         NaN        NaN        NaN     14.8
# 4         NaN         NaN        NaN        NaN     12.7
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Filling missing values

# %%
columns_to_fill = [
    "bg-0:00", "bg-0:05", "bg-0:10", "bg-0:15", "bg-0:20", "bg-0:25", "bg-0:30", "bg-0:35", "bg-0:40", "bg-0:45",
    "insulin-0:00", "insulin-0:05", "insulin-0:10", "insulin-0:15", "insulin-0:20",
    "hr-0:00", "hr-0:05", "hr-0:10", "hr-0:15", "hr-0:20", "hr-0:25", "hr-0:30",
    "steps-0:00", "steps-0:05", "steps-0:10", "steps-0:15",
    "cals-0:00", "cals-0:05",
]

df[columns_to_fill] = df[columns_to_fill].interpolate()

# %%
imputer = SimpleImputer()

df[columns_to_fill] = imputer.fit_transform(df[columns_to_fill])

# %% [markdown]
# ## Converting time into sin and cos pair

# %% [markdown]
# ### Converting time to minutes

# %%
df['minutes_since_start'] = pd.to_datetime(df['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(df['time'], format="%H:%M:%S").dt.minute
df = df.drop(columns=['time'])

# %% [markdown]
# ### Converting minutes to sin and cos pair (summing constant 2, to avoid zero values)

# %%
df["time_sin"] = np.sin(2 * np.pi / 1440 * df['minutes_since_start']) + 2
df["time_cos"] = np.cos(2 * np.pi / 1440 * df['minutes_since_start']) + 2
df = df.drop(columns=['minutes_since_start'])
df.head(5)
# Out:
#       id p_num  bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  \
# 0  p01_0   p01     15.1  8.246322  8.33178     16.2  8.258647  8.430463
# 1  p01_1   p01     14.4  8.246322  8.33178     15.1  8.258647  8.430463
# 2  p01_2   p01     13.9  8.246322  8.33178     14.4  8.258647  8.430463
# 3  p01_3   p01     13.8  8.246322  8.33178     13.9  8.258647  8.430463
# 4  p01_4   p01     13.4  8.246322  8.33178     13.8  8.258647  8.430463
#
#    bg-0:30   bg-0:35  ...    hr-0:30  steps-0:00  steps-0:05  steps-0:10  \
# 0     17.3  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 1     16.2  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 2     15.1  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 3     14.4  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 4     13.9  8.268978  ...  81.189919   44.927039   43.967174    43.96972
#
#    steps-0:15  cals-0:00  cals-0:05  bg+1:00  time_sin  time_cos
# 0   45.359472   8.130857   8.147582     13.4  2.999048  1.956381
# 1   45.359472   8.130857   8.147582     12.8  2.994056  1.891133
# 2   45.359472   8.130857   8.147582     15.5  2.984808  1.826352
# 3   45.359472   8.130857   8.147582     14.8  2.971342  1.762314
# 4   45.359472   8.130857   8.147582     12.7  2.953717  1.699294
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Removing ID columns

# %%
cols_to_pop = ['id', 'p_num']
identifiers = df[cols_to_pop].copy()
df = df.drop(columns=cols_to_pop)
df.head(5)
# Out:
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  bg-0:30   bg-0:35  \
# 0     15.1  8.246322  8.33178     16.2  8.258647  8.430463     17.3  8.268978
# 1     14.4  8.246322  8.33178     15.1  8.258647  8.430463     16.2  8.268978
# 2     13.9  8.246322  8.33178     14.4  8.258647  8.430463     15.1  8.268978
# 3     13.8  8.246322  8.33178     13.9  8.258647  8.430463     14.4  8.268978
# 4     13.4  8.246322  8.33178     13.8  8.258647  8.430463     13.9  8.268978
#
#     bg-0:40  bg-0:45  ...    hr-0:30  steps-0:00  steps-0:05  steps-0:10  \
# 0  8.412561     17.5  ...  81.189919   44.927039   43.967174    43.96972
# 1  8.412561     17.3  ...  81.189919   44.927039   43.967174    43.96972
# 2  8.412561     16.2  ...  81.189919   44.927039   43.967174    43.96972
# 3  8.412561     15.1  ...  81.189919   44.927039   43.967174    43.96972
# 4  8.412561     14.4  ...  81.189919   44.927039   43.967174    43.96972
#
#    steps-0:15  cals-0:00  cals-0:05  bg+1:00  time_sin  time_cos
# 0   45.359472   8.130857   8.147582     13.4  2.999048  1.956381
# 1   45.359472   8.130857   8.147582     12.8  2.994056  1.891133
# 2   45.359472   8.130857   8.147582     15.5  2.984808  1.826352
# 3   45.359472   8.130857   8.147582     14.8  2.971342  1.762314
# 4   45.359472   8.130857   8.147582     12.7  2.953717  1.699294
#
# [5 rows x 31 columns]

# %%
df.to_csv("dataset/train_interpolate_circle_causalidade.csv", index=False)

# %% [markdown]
# ## Spliting train and test dataframes

# %%
train = df.sample(frac=0.75, random_state=0)
test = df.drop(train.index)

# %%
x_train = train
y_train = train.pop('bg+1:00')

# %%
print(x_train.shape)
x_train.head(5)
# Out:
# (132768, 30)
#        bg-0:00    bg-0:05    bg-0:10  bg-0:15    bg-0:20    bg-0:25  bg-0:30  \
# 91143      5.9   5.807317   8.354752      6.2   6.854918  11.098182      4.6
# 35758      8.2   8.200000   8.300000      8.5   8.700000   8.900000      8.5
# 65296      6.8   7.200000   7.900000      8.4   8.700000   8.700000      8.4
# 14652     10.5  10.600000  10.700000     10.8  10.900000  10.900000     11.0
# 54561      6.3   6.300000   6.300000      6.3   6.300000   6.300000      6.2
#
#          bg-0:35    bg-0:40  bg-0:45  ...    hr-0:25    hr-0:30  steps-0:00  \
# 91143   6.721488  11.227333      3.8  ...  86.000000  84.600000  518.000000
# 35758   8.400000   8.500000      8.8  ...  76.143817  76.139606   23.021904
# 65296   8.100000   7.900000      6.5  ...  86.300000  83.500000    8.000000
# 14652  11.200000  11.400000     11.4  ...  81.250505  81.045791   27.270000
# 54561   6.200000   6.200000      6.1  ...  53.000000  52.800000    0.000000
#
#        steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  \
# 91143  573.000000  440.000000    12.00000   8.350000   5.410000  1.357212
# 35758   23.077783   23.133661    23.18954   5.600000   5.600000  2.965926
# 65296   11.000000   14.000000    72.00000   7.090000   8.630000  1.123273
# 14652   27.193333   27.116667    27.04000   1.819452   1.817945  2.422618
# 54561    0.000000    0.000000     0.00000   5.720000   5.600000  2.939693
#
#        time_cos
# 91143  2.766044
# 35758  2.258819
# 65296  1.519011
# 14652  2.906308
# 54561  1.657980
#
# [5 rows x 30 columns]

# %%
print(y_train.shape)
y_train.head(5)
# Out:
# (132768,)
# 91143    7.6
# 35758    7.6
# 65296    6.2
# 14652    9.0
# 54561    5.7
# Name: bg+1:00, dtype: float64

# %%
x_train.to_csv("x.csv", index=False)
y_train.to_csv("y.csv", index=False)

# %% [markdown]
# ## Building model

# %% [markdown]
# ### Imports and GPU config

# %%
from keras.layers import TimeDistributed, Dense, Input, Lambda, BatchNormalization, Concatenate, Conv1D, ZeroPadding1D
from keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.callbacks import EarlyStopping
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Configurando para não alocar diretamente toda a memória da GPU (alocar conforme necessário)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)  # Aloca memória conforme necessário
    except RuntimeError as e:
        print(e)
# Out:
# 2024-11-22 20:31:53.537572: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-22 20:31:53.546990: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732318313.557736   47051 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732318313.560401   47051 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-22 20:31:53.571124: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available:  1

# %% [markdown]
# ### Model definition

# %%
def attention_block(input_tensor, name="attention"):
  """
  Mecanismo de atenção para features ou grupos de features.
  Args:
      input_tensor: Tensor de entrada com forma (batch_size, feature_dim).
      name: Nome do bloco de atenção.
  Returns:
      output_tensor: Tensor após aplicar atenção.
  """
  # Número de dimensões de entrada
  feature_dim = input_tensor.shape[-1]
  
  # Projeções lineares para calcular atenção (Q, K, V)
  q = Dense(feature_dim, activation=None, use_bias=False, name=f"{name}_query")(input_tensor)  # Query
  k = Dense(feature_dim, activation=None, use_bias=False, name=f"{name}_key")(input_tensor)    # Key
  v = Dense(feature_dim, activation=None, use_bias=False, name=f"{name}_value")(input_tensor)  # Value

  # Ajuste de dimensões para calcular produto interno (expand para [batch_size, feature_dim, 1])
  q = tf.expand_dims(q, axis=1)
  k = tf.expand_dims(k, axis=1)
  v = tf.expand_dims(v, axis=1)

  # Produto interno entre Q e K (atenção escalada)
  attention_scores = tf.keras.layers.Dot(axes=-1, name=f"{name}_scores")([q, k])
  attention_scores = tf.keras.layers.Activation('softmax', name=f"{name}_softmax")(attention_scores)

  # Aplicar pesos de atenção no Value
  weighted_values = tf.keras.layers.Dot(axes=1, name=f"{name}_weighted_values")([attention_scores, v])

  # Remover dimensão adicional para compatibilidade com entrada original
  weighted_values = tf.squeeze(weighted_values, axis=1)

  # Combinar valores ponderados com o tensor de entrada
  output_tensor = tf.keras.layers.Add(name=f"{name}_add")([input_tensor, weighted_values])

  return output_tensor

def extrator_features(input_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims*4), activation=activation, use_bias=bias, kernel_regularizer=None)(input_layer)
  # x_1 = tf.keras.layers.Dropout(0.2)(x_0)
  x_2 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_0)
  
  # Bloco de Atenção
  x_2_attention = attention_block(x_2, name="attention_features")
  
  x_3 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_2_attention)
  x_4 = Dense(int(input_dims*4), activation=activation, use_bias=bias)(x_3)
  x_bottleneck = Dense(int(input_dims), activation=activation, name='encoder', use_bias=bias, kernel_regularizer="l1")(x_4)

  return Model(input_layer, x_bottleneck, name="features")

def regressor(input_dims, output_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims/2), activation=activation, use_bias=bias)(input_layer)
  x_2 = Dense(int(input_dims/4), activation=activation, use_bias=bias)(x_0)
  saidas = Dense(output_dims, activation=None, name='regressor_saidas', use_bias=bias)(x_2)

  return Model(input_layer, saidas, name="regressor")

def build_models(input_dims, output_dims, activation, bias):
  # Camadas de entrada
  input_layer = Input(shape=[input_dims])

  x_n = BatchNormalization()(input_layer)

  # Kernels
  extrator = extrator_features(input_dims, activation, bias)

  # Features
  features = extrator(x_n)

  # Regressão
  regressao = regressor(features.shape[1], output_dims, activation, bias)

  saida = regressao(features)
  
  return (
      Model(input_layer, saida, name="regressao"),
      Model(input_layer, features, name="projecao")
  )

model, features = build_models(x_train.shape[1], 1, 'silu', True)
model.compile(optimizer='adam', loss='mse', metrics=['mae', 'mse', 'mean_absolute_percentage_error'])
plot_model(model, show_shapes=True, expand_nested=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 85
#      78   saida = regressao(features)
#      80   return (
#      81       Model(input_layer, saida, name="regressao"),
#      82       Model(input_layer, features, name="projecao")
#      83   )
# ---> 85 model, features = build_models(x_train.shape[1], 1, 'silu', True)
#      86 model.compile(optimizer='adam', loss='mse', metrics=['mae', 'mse', 'mean_absolute_percentage_error'])
#      87 plot_model(model, show_shapes=True, expand_nested=True)
#
# Cell In[24], line 70, in build_models(input_dims, output_dims, activation, bias)
#      67 x_n = BatchNormalization()(input_layer)
#      69 # Kernels
# ---> 70 extrator = extrator_features(input_dims, activation, bias)
#      72 # Features
#      73 features = extrator(x_n)
#
# Cell In[24], line 46, in extrator_features(input_dims, activation, bias)
#      43 x_2 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_0)
#      45 # Bloco de Atenção
# ---> 46 x_2_attention = attention_block(x_2, name="attention_features")
#      48 x_3 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_2_attention)
#      49 x_4 = Dense(int(input_dims*4), activation=activation, use_bias=bias)(x_3)
#
# Cell In[24], line 19, in attention_block(input_tensor, name)
#      16 v = Dense(feature_dim, activation=None, use_bias=False, name=f"{name}_value")(input_tensor)  # Value
#      18 # Ajuste de dimensões para calcular produto interno (expand para [batch_size, feature_dim, 1])
# ---> 19 q = tf.expand_dims(q, axis=1)
#      20 k = tf.expand_dims(k, axis=1)
#      21 v = tf.expand_dims(v, axis=1)
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/tensorflow/python/ops/weak_tensor_ops.py:88, in weak_tensor_unary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#      86 def wrapper(*args, **kwargs):
#      87   if not ops.is_auto_dtype_conversion_enabled():
# ---> 88     return op(*args, **kwargs)
#      89   bound_arguments = signature.bind(*args, **kwargs)
#      90   bound_arguments.apply_defaults()
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/keras/src/backend/common/keras_tensor.py:138, in KerasTensor.__tf_tensor__(self, dtype, name)
#     137 def __tf_tensor__(self, dtype=None, name=None):
# --> 138     raise ValueError(
#     139         "A KerasTensor cannot be used as input to a TensorFlow function. "
#     140         "A KerasTensor is a symbolic placeholder for a shape and dtype, "
#     141         "used when constructing Keras Functional models "
#     142         "or Keras Functions. You can only use it as input to a Keras layer "
#     143         "or a Keras operation (from the namespaces `keras.layers` "
#     144         "and `keras.operations`). "
#     145         "You are likely doing something like:\n\n"
#     146         "```\n"
#     147         "x = Input(...)\n"
#     148         "...\n"
#     149         "tf_fn(x)  # Invalid.\n"
#     150         "```\n\n"
#     151         "What you should do instead is wrap `tf_fn` in a layer:\n\n"
#     152         "```\n"
#     153         "class MyLayer(Layer):\n"
#     154         "    def call(self, x):\n"
#     155         "        return tf_fn(x)\n\n"
#     156         "x = MyLayer()(x)\n"
#     157         "```\n"
#     158     )
#
# ValueError: A KerasTensor cannot be used as input to a TensorFlow function. A KerasTensor is a symbolic placeholder for a shape and dtype, used when constructing Keras Functional models or Keras Functions. You can only use it as input to a Keras layer or a Keras operation (from the namespaces `keras.layers` and `keras.operations`). You are likely doing something like:
#
# ```
# x = Input(...)
# ...
# tf_fn(x)  # Invalid.
# ```
#
# What you should do instead is wrap `tf_fn` in a layer:
#
# ```
# class MyLayer(Layer):
#     def call(self, x):
#         return tf_fn(x)
#
# x = MyLayer()(x)
# ```

# %% [markdown]
# ### Training model

# %%
# Callback para recuperar o melhor peso, e parar quando ficar três épocas sem melhora
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Treinando o modelo
history = model.fit(x_train, y_train, epochs=200, validation_split = 0.2, callbacks=[callback])
# Out:
# Epoch 1/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 8.4505 - mae: 1.8943 - mean_absolute_percentage_error: 24.6910 - mse: 7.0945 - val_loss: 4.4976 - val_mae: 1.5895 - val_mean_absolute_percentage_error: 22.1809 - val_mse: 4.3507
# Epoch 2/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 799us/step - loss: 4.7054 - mae: 1.6050 - mean_absolute_percentage_error: 21.2251 - mse: 4.5788 - val_loss: 4.2327 - val_mae: 1.5080 - val_mean_absolute_percentage_error: 19.6679 - val_mse: 4.1472
# Epoch 3/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 802us/step - loss: 4.4703 - mae: 1.5724 - mean_absolute_percentage_error: 20.8027 - mse: 4.3974 - val_loss: 4.2032 - val_mae: 1.4923 - val_mean_absolute_percentage_error: 19.0826 - val_mse: 4.1365
# Epoch 4/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 784us/step - loss: 4.4542 - mae: 1.5694 - mean_absolute_percentage_error: 20.7397 - mse: 4.3999 - val_loss: 4.0809 - val_mae: 1.4833 - val_mean_absolute_percentage_error: 19.4434 - val_mse: 4.0336
# Epoch 5/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 782us/step - loss: 4.3855 - mae: 1.5556 - mean_absolute_percentage_error: 20.5587 - mse: 4.3420 - val_loss: 4.0382 - val_mae: 1.4997 - val_mean_absolute_percentage_error: 20.4235 - val_mse: 4.0026
# Epoch 6/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 790us/step - loss: 4.3289 - mae: 1.5470 - mean_absolute_percentage_error: 20.4428 - mse: 4.2946 - val_loss: 3.9893 - val_mae: 1.4726 - val_mean_absolute_percentage_error: 19.3601 - val_mse: 3.9601
# Epoch 7/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 778us/step - loss: 4.2806 - mae: 1.5401 - mean_absolute_percentage_error: 20.3030 - mse: 4.2481 - val_loss: 4.1262 - val_mae: 1.4829 - val_mean_absolute_percentage_error: 18.7864 - val_mse: 4.1025
# Epoch 8/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 788us/step - loss: 4.2141 - mae: 1.5274 - mean_absolute_percentage_error: 20.2018 - mse: 4.1814 - val_loss: 4.0101 - val_mae: 1.4680 - val_mean_absolute_percentage_error: 19.4230 - val_mse: 3.9834
# Epoch 9/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 787us/step - loss: 4.2088 - mae: 1.5282 - mean_absolute_percentage_error: 20.1458 - mse: 4.1805 - val_loss: 3.9172 - val_mae: 1.4659 - val_mean_absolute_percentage_error: 19.5045 - val_mse: 3.8917
# Epoch 10/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 789us/step - loss: 4.1774 - mae: 1.5165 - mean_absolute_percentage_error: 20.0795 - mse: 4.1518 - val_loss: 3.9275 - val_mae: 1.4586 - val_mean_absolute_percentage_error: 19.0721 - val_mse: 3.9012
# Epoch 11/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 790us/step - loss: 4.1284 - mae: 1.5132 - mean_absolute_percentage_error: 19.9798 - mse: 4.1051 - val_loss: 4.0270 - val_mae: 1.4795 - val_mean_absolute_percentage_error: 19.0961 - val_mse: 4.0049
# Epoch 12/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 788us/step - loss: 4.1010 - mae: 1.5083 - mean_absolute_percentage_error: 19.8800 - mse: 4.0793 - val_loss: 3.9547 - val_mae: 1.4703 - val_mean_absolute_percentage_error: 19.1711 - val_mse: 3.9381
# Epoch 13/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 790us/step - loss: 4.0350 - mae: 1.4946 - mean_absolute_percentage_error: 19.7776 - mse: 4.0142 - val_loss: 3.9630 - val_mae: 1.4617 - val_mean_absolute_percentage_error: 18.9985 - val_mse: 3.9382
# Epoch 14/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 794us/step - loss: 4.0288 - mae: 1.4983 - mean_absolute_percentage_error: 19.7980 - mse: 4.0046 - val_loss: 3.8830 - val_mae: 1.4452 - val_mean_absolute_percentage_error: 18.7226 - val_mse: 3.8618
# Epoch 15/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 788us/step - loss: 3.9546 - mae: 1.4832 - mean_absolute_percentage_error: 19.6014 - mse: 3.9341 - val_loss: 3.8856 - val_mae: 1.4699 - val_mean_absolute_percentage_error: 19.7268 - val_mse: 3.8692
# Epoch 16/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 783us/step - loss: 3.9616 - mae: 1.4786 - mean_absolute_percentage_error: 19.4540 - mse: 3.9396 - val_loss: 3.8930 - val_mae: 1.4489 - val_mean_absolute_percentage_error: 18.7982 - val_mse: 3.8741
# Epoch 17/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 782us/step - loss: 3.9207 - mae: 1.4729 - mean_absolute_percentage_error: 19.4199 - mse: 3.8973 - val_loss: 3.8975 - val_mae: 1.4505 - val_mean_absolute_percentage_error: 19.1544 - val_mse: 3.8744
# Epoch 18/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 794us/step - loss: 3.9231 - mae: 1.4775 - mean_absolute_percentage_error: 19.4315 - mse: 3.9022 - val_loss: 3.9499 - val_mae: 1.4617 - val_mean_absolute_percentage_error: 18.8260 - val_mse: 3.9291
# Epoch 19/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 784us/step - loss: 3.8908 - mae: 1.4660 - mean_absolute_percentage_error: 19.2756 - mse: 3.8697 - val_loss: 3.8581 - val_mae: 1.4414 - val_mean_absolute_percentage_error: 18.9271 - val_mse: 3.8357
# Epoch 20/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 797us/step - loss: 3.8871 - mae: 1.4674 - mean_absolute_percentage_error: 19.3302 - mse: 3.8670 - val_loss: 3.8402 - val_mae: 1.4395 - val_mean_absolute_percentage_error: 18.8455 - val_mse: 3.8226
# Epoch 21/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 795us/step - loss: 3.7971 - mae: 1.4499 - mean_absolute_percentage_error: 19.1409 - mse: 3.7760 - val_loss: 3.8318 - val_mae: 1.4348 - val_mean_absolute_percentage_error: 18.7513 - val_mse: 3.8055
# Epoch 22/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 790us/step - loss: 3.7882 - mae: 1.4499 - mean_absolute_percentage_error: 19.1147 - mse: 3.7663 - val_loss: 4.0091 - val_mae: 1.4744 - val_mean_absolute_percentage_error: 19.7106 - val_mse: 3.9811
# Epoch 23/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 799us/step - loss: 3.7300 - mae: 1.4384 - mean_absolute_percentage_error: 18.9478 - mse: 3.7090 - val_loss: 3.9847 - val_mae: 1.4943 - val_mean_absolute_percentage_error: 20.5831 - val_mse: 3.9643
# Epoch 24/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 799us/step - loss: 3.6768 - mae: 1.4275 - mean_absolute_percentage_error: 18.9015 - mse: 3.6562 - val_loss: 3.8961 - val_mae: 1.4541 - val_mean_absolute_percentage_error: 19.4186 - val_mse: 3.8661
# Epoch 25/25
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 834us/step - loss: 3.6808 - mae: 1.4263 - mean_absolute_percentage_error: 18.8288 - mse: 3.6596 - val_loss: 3.8504 - val_mae: 1.4512 - val_mean_absolute_percentage_error: 19.5064 - val_mse: 3.8295

# %% [markdown]
# ### Analysing error metrics

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist['rmse'] = np.sqrt(hist['mse'])
hist['val_rmse'] = np.sqrt(hist['val_mse'])
hist.tail()
# Out:
#         loss       mae  mean_absolute_percentage_error       mse  val_loss  \
# 20  3.815875  1.453179                       19.161469  3.794943  3.831823
# 21  3.786104  1.448610                       19.108414  3.765669  4.009107
# 22  3.755920  1.442362                       19.015005  3.734633  3.984672
# 23  3.718430  1.435104                       18.939503  3.697993  3.896111
# 24  3.691514  1.429877                       18.851685  3.671665  3.850445
#
#      val_mae  val_mean_absolute_percentage_error   val_mse  epoch      rmse  \
# 20  1.434785                           18.751347  3.805461     20  1.948061
# 21  1.474439                           19.710621  3.981056     21  1.940533
# 22  1.494278                           20.583059  3.964268     22  1.932520
# 23  1.454074                           19.418591  3.866101     23  1.923017
# 24  1.451207                           19.506435  3.829519     24  1.916159
#
#     val_rmse
# 20  1.950759
# 21  1.995258
# 22  1.991047
# 23  1.966240
# 24  1.956916

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.title("Evolução das funções de perda durante o treinamento da rede")
plt.xlabel('Rodada')
plt.ylabel('Root Mean Square Error')
plt.plot(hist['epoch'], hist['rmse'], label='RMSE Treino')
plt.plot(hist['epoch'], hist['val_rmse'], label = 'RMSE Validação')
plt.legend()

plt.figure()
plt.xlabel('Rodada')
plt.ylabel('Mean Absolute Error')
plt.plot(hist['epoch'], hist['mae'], label='MAE Treino')
plt.plot(hist['epoch'], hist['val_mae'], label = 'MAE Validação')
plt.legend()

plt.show()

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# ### Preparing test dataframe

# %%
x_test = test
y_test = test.pop('bg+1:00')
print(x_test.shape)
x_test.head(5)
# Out:
# (44256, 30)
#     bg-0:00   bg-0:05  bg-0:10    bg-0:15   bg-0:20   bg-0:25    bg-0:30  \
# 2      13.9  8.246322  8.33178  14.400000  8.258647  8.430463  15.100000
# 10     11.9  8.246322  8.33178  11.400000  8.258647  8.430463  12.700000
# 21      5.8  8.246322  8.33178   6.600000  8.258647  8.430463   8.600000
# 27      3.7  7.100000  8.33178   7.366667  5.200000  8.430463   7.228571
# 30     12.3  7.933333  8.33178  11.066667  8.000000  8.430463  10.271429
#
#      bg-0:35   bg-0:40  bg-0:45  ...    hr-0:25    hr-0:30  steps-0:00  \
# 2   8.268978  8.412561  16.2000  ...  81.177985  81.189919   44.927039
# 10  8.268978  8.412561  14.8000  ...  81.177985  81.189919   44.927039
# 21  8.268978  8.412561  11.2000  ...  81.177985  81.189919   44.927039
# 27  4.800000  8.412561   7.1250  ...  81.177985  81.189919   44.927039
# 30  7.400000  8.412561   9.7125  ...  81.177985  81.189919   44.927039
#
#     steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  \
# 2    43.967174    43.96972   45.359472   8.130857   8.147582  2.984808
# 10   43.967174    43.96972   45.359472   8.130857   8.147582  2.766044
# 21   43.967174    43.96972   45.359472   8.130857   8.147582  2.152123
# 27   43.967174    43.96972   45.359472   8.130857   8.147582  1.741181
# 30   43.967174    43.96972   45.359472   8.130857   8.147582  1.557711
#
#     time_cos
# 2   1.826352
# 10  1.357212
# 21  1.011638
# 27  1.034074
# 30  1.103127
#
# [5 rows x 30 columns]

# %%
y_test.head(5)
# Out:
# 2     15.5
# 10    17.4
# 21     4.8
# 27    13.1
# 30     8.3
# Name: bg+1:00, dtype: float64

# %%
x_test.to_csv("x_t.csv", index=False)
y_test.to_csv("y_t.csv", index=False)

# %% [markdown]
# ### Running prediction

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# 1383/1383 ━━━━━━━━━━━━━━━━━━━━ 1s 464us/step
# [[12.225288 ]
#  [10.820099 ]
#  [ 6.2480307]
#  ...
#  [ 7.363453 ]
#  [ 8.964995 ]
#  [10.879082 ]]

# %% [markdown]
# ### Calculating error metrics

# %%
mse = tf.keras.losses.MSE(y_test, y_pred).numpy().mean()
mae = tf.keras.losses.MAE(y_test, y_pred).numpy().mean()
rmse = np.sqrt(mse)

# %%
print(f"RMSE Test: {rmse}")
print(f"MSE Test: {mse}")
print(f"MAE Test: {mae}")
# Out:
# RMSE Test: 1.9496887922286987
# MSE Test: 3.801286220550537
# MAE Test: 1.4304507970809937

# %% [markdown]
# ## Saving the model

# %%
model.save("brist1d_v4_3.keras")

# %% [markdown]
# ## Loading and processing submission dataframe

# %%
df_submission = pd.read_csv('dataset/test.csv', header=0)
print(df_submission.shape)
df_submission.head(5)
# Out:
# (3644, 507)
#          id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_8459   p01  06:45:00      NaN      9.2      NaN      NaN     10.2
# 1  p01_8460   p01  11:25:00      NaN      NaN      9.9      NaN      NaN
# 2  p01_8461   p01  14:45:00      NaN      5.5      NaN      NaN      5.5
# 3  p01_8462   p01  04:30:00      NaN      3.4      NaN      NaN      3.9
# 4  p01_8463   p01  04:20:00      NaN      NaN      8.3      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:45  activity-0:40  activity-0:35  \
# 0      NaN      NaN  ...            NaN            NaN            NaN
# 1      9.4      NaN  ...            NaN            NaN            NaN
# 2      NaN      NaN  ...            NaN            NaN            NaN
# 3      NaN      NaN  ...            NaN            NaN            NaN
# 4     10.0      NaN  ...            NaN            NaN            NaN
#
#    activity-0:30  activity-0:25  activity-0:20  activity-0:15  activity-0:10  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN           Walk
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    activity-0:05  activity-0:00
# 0            NaN            NaN
# 1           Walk           Walk
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
# [5 rows x 507 columns]

# %%
df_submission = filter_desired_columns(df_submission, False)
df_submission.head(5)
# Out:
#          id p_num      time  bg-0:00  bg-0:05  bg-0:10  bg-0:15  bg-0:20  \
# 0  p01_8459   p01  06:45:00      9.6      NaN      NaN      9.4      NaN
# 1  p01_8460   p01  11:25:00      4.6      NaN      NaN      6.3      NaN
# 2  p01_8461   p01  14:45:00      8.0      NaN      NaN      8.3      NaN
# 3  p01_8462   p01  04:30:00      9.9      NaN      NaN      8.5      NaN
# 4  p01_8463   p01  04:20:00      5.3      NaN      NaN      3.7      NaN
#
#    bg-0:25  bg-0:30  ...  hr-0:15  hr-0:20  hr-0:25  hr-0:30  steps-0:00  \
# 0      NaN      NaN  ...     55.6     53.2     54.4     55.8         NaN
# 1      NaN      6.4  ...     95.6     91.6     93.5     91.1       532.0
# 2      NaN      8.1  ...     75.7     81.1     87.9     92.1        69.0
# 3      NaN      7.8  ...     59.5     58.5     61.2     60.7         0.0
# 4      NaN      3.2  ...     58.9     57.6     55.1     56.2         NaN
#
#    steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05
# 0         NaN         NaN         0.0       6.06       4.90
# 1       377.0       547.0       411.0      32.43      24.57
# 2       283.0        27.0        10.0      10.16      19.76
# 3         NaN         NaN        14.0       4.80       4.90
# 4         NaN         NaN         NaN       4.80       4.80
#
# [5 rows x 31 columns]

# %%
df_submission[columns_to_fill] = df_submission[columns_to_fill].interpolate()
df_submission[columns_to_fill] = imputer.transform(df_submission[columns_to_fill])

# %%
df_submission['minutes_since_start'] = pd.to_datetime(df_submission['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(df_submission['time'], format="%H:%M:%S").dt.minute
df_submission = df_submission.drop(columns=['time'])
df_submission["time_sin"] = np.sin(2 * np.pi / 1440 * df_submission['minutes_since_start']) + 2
df_submission["time_cos"] = np.cos(2 * np.pi / 1440 * df_submission['minutes_since_start']) + 2
df_submission = df_submission.drop(columns=['minutes_since_start'])
df_submission.head(5)
# Out:
#          id p_num  bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  \
# 0  p01_8459   p01      9.6  8.246322  8.33178      9.4  8.258647  8.430463
# 1  p01_8460   p01      4.6  8.246322  8.33178      6.3  8.258647  8.430463
# 2  p01_8461   p01      8.0  8.246322  8.33178      8.3  8.258647  8.430463
# 3  p01_8462   p01      9.9  8.246322  8.33178      8.5  8.258647  8.430463
# 4  p01_8463   p01      5.3  8.246322  8.33178      3.7  8.258647  8.430463
#
#     bg-0:30  bg-0:35  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.282302     10.5  ...     54.4     55.8   44.927039   43.967174
# 1  6.400000     10.2  ...     93.5     91.1  532.000000  377.000000
# 2  8.100000      9.9  ...     87.9     92.1   69.000000  283.000000
# 3  7.800000      9.6  ...     61.2     60.7    0.000000  205.333333
# 4  3.200000      9.3  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 32 columns]

# %%
identifiers_submission = df_submission[cols_to_pop].copy()
df_submission = df_submission.drop(columns=cols_to_pop)
df_submission.head(5)
# Out:
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25   bg-0:30  bg-0:35  \
# 0      9.6  8.246322  8.33178      9.4  8.258647  8.430463  8.282302     10.5
# 1      4.6  8.246322  8.33178      6.3  8.258647  8.430463  6.400000     10.2
# 2      8.0  8.246322  8.33178      8.3  8.258647  8.430463  8.100000      9.9
# 3      9.9  8.246322  8.33178      8.5  8.258647  8.430463  7.800000      9.6
# 4      5.3  8.246322  8.33178      3.7  8.258647  8.430463  3.200000      9.3
#
#     bg-0:40   bg-0:45  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.412561  8.283803  ...     54.4     55.8   44.927039   43.967174
# 1  8.412561  4.500000  ...     93.5     91.1  532.000000  377.000000
# 2  8.412561  6.600000  ...     87.9     92.1   69.000000  283.000000
# 3  8.412561  7.500000  ...     61.2     60.7    0.000000  205.333333
# 4  8.412561  3.400000  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 30 columns]

# %%
print(df_submission.shape)
df_submission.head(5)
# Out:
# (3644, 30)
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25   bg-0:30  bg-0:35  \
# 0      9.6  8.246322  8.33178      9.4  8.258647  8.430463  8.282302     10.5
# 1      4.6  8.246322  8.33178      6.3  8.258647  8.430463  6.400000     10.2
# 2      8.0  8.246322  8.33178      8.3  8.258647  8.430463  8.100000      9.9
# 3      9.9  8.246322  8.33178      8.5  8.258647  8.430463  7.800000      9.6
# 4      5.3  8.246322  8.33178      3.7  8.258647  8.430463  3.200000      9.3
#
#     bg-0:40   bg-0:45  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.412561  8.283803  ...     54.4     55.8   44.927039   43.967174
# 1  8.412561  4.500000  ...     93.5     91.1  532.000000  377.000000
# 2  8.412561  6.600000  ...     87.9     92.1   69.000000  283.000000
# 3  8.412561  7.500000  ...     61.2     60.7    0.000000  205.333333
# 4  8.412561  3.400000  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Predicting submission dataset

# %%
# model = tf.keras.models.load_model("brist1d.keras")

# %%
y_submission = model.predict(df_submission)
df_pred_submission = pd.DataFrame(y_submission, columns=['bg+1:00'])
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %% [markdown]
# ### Joining identifiers

# %%
df_pred_submission = pd.concat([identifiers_submission, df_pred_submission], axis=1)
df_pred_submission.pop('p_num')
df_pred_submission.head(5)
# Out:
#          id    bg+1:00
# 0  p01_8459   9.315093
# 1  p01_8460   5.163402
# 2  p01_8461   7.043850
# 3  p01_8462  10.359314
# 4  p01_8463   7.163373

# %% [markdown]
# ### Exporting submission results

# %%
df_pred_submission.to_csv("dataset/predictions.csv", index=False)
