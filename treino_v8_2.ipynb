# %% [markdown]
# # Trabalhando os dados

# %% [markdown]
# ## Carregando o dataset

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer

# %%
ds = pd.read_csv('dataset/train_corrigido.csv', header=0)
print(ds.shape)
ds.head(5)
# Out:
# /tmp/ipykernel_25158/1130610560.py:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   ds = pd.read_csv('dataset/train_corrigido.csv', header=0)
# (177024, 509)
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:35  activity-0:30  activity-0:25  \
# 0      9.7      NaN  ...            NaN            NaN            NaN
# 1      9.2      NaN  ...            NaN            NaN            NaN
# 2      8.7      NaN  ...            NaN            NaN            NaN
# 3      8.4      NaN  ...            NaN            NaN            NaN
# 4      8.1      NaN  ...            NaN            NaN            NaN
#
#    activity-0:20  activity-0:15  activity-0:10  activity-0:05  activity-0:00  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    bg+1:00  id_num
# 0     13.4       0
# 1     12.8       1
# 2     15.5       2
# 3     14.8       3
# 4     12.7       4
#
# [5 rows x 509 columns]

# %% [markdown]
# ## Preenchendo os nulos com zero (com exceção das colunas de Atividade Física)

# %%
columns_to_fill = []
for prefix in ['bg-', 'insulin-', 'carbs-', 'hr-', 'steps-', 'cals-']:
    cols_to_fill = [col for col in ds.columns if col.startswith(prefix)]
    columns_to_fill += cols_to_fill

ds[columns_to_fill] = ds[columns_to_fill].interpolate()

# imputer = SimpleImputer()
# ds[columns_to_fill] = imputer.fit_transform(ds[columns_to_fill])
ds.loc[:, columns_to_fill] = ds.loc[:, columns_to_fill].fillna(0.0)

ds.head(5)
# Out:
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      0.0      0.0      9.6      0.0      0.0
# 1  p01_1   p01  06:25:00      0.0      0.0      9.7      0.0      0.0
# 2  p01_2   p01  06:40:00      0.0      0.0      9.2      0.0      0.0
# 3  p01_3   p01  06:55:00      0.0      0.0      8.7      0.0      0.0
# 4  p01_4   p01  07:10:00      0.0      0.0      8.4      0.0      0.0
#
#    bg-5:30  bg-5:25  ...  activity-0:35  activity-0:30  activity-0:25  \
# 0      9.7      0.0  ...            NaN            NaN            NaN
# 1      9.2      0.0  ...            NaN            NaN            NaN
# 2      8.7      0.0  ...            NaN            NaN            NaN
# 3      8.4      0.0  ...            NaN            NaN            NaN
# 4      8.1      0.0  ...            NaN            NaN            NaN
#
#    activity-0:20  activity-0:15  activity-0:10  activity-0:05  activity-0:00  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    bg+1:00  id_num
# 0     13.4       0
# 1     12.8       1
# 2     15.5       2
# 3     14.8       3
# 4     12.7       4
#
# [5 rows x 509 columns]

# %% [markdown]
# ## Preencher com "other" as ativiades físicas nulas

# %%
cols_to_fill = [col for col in ds.columns if col.startswith('activity-')]

ds.loc[:, cols_to_fill] = ds.loc[:, cols_to_fill].fillna('other')

# %% [markdown]
# ## Convertendo o time num inteiro crescente

# %%
ds['minutes_since_start'] = pd.to_datetime(ds['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(ds['time'], format="%H:%M:%S").dt.minute
ds = ds.drop(columns=['time'])
ds.head(5)
# Out:
# /tmp/ipykernel_25158/161608706.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ds['minutes_since_start'] = pd.to_datetime(ds['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(ds['time'], format="%H:%M:%S").dt.minute
#       id p_num  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  bg-5:25  \
# 0  p01_0   p01      0.0      0.0      9.6      0.0      0.0      9.7      0.0
# 1  p01_1   p01      0.0      0.0      9.7      0.0      0.0      9.2      0.0
# 2  p01_2   p01      0.0      0.0      9.2      0.0      0.0      8.7      0.0
# 3  p01_3   p01      0.0      0.0      8.7      0.0      0.0      8.4      0.0
# 4  p01_4   p01      0.0      0.0      8.4      0.0      0.0      8.1      0.0
#
#    bg-5:20  ...  activity-0:30  activity-0:25  activity-0:20  activity-0:15  \
# 0      0.0  ...          other          other          other          other
# 1      0.0  ...          other          other          other          other
# 2      0.0  ...          other          other          other          other
# 3      0.0  ...          other          other          other          other
# 4      0.0  ...          other          other          other          other
#
#    activity-0:10  activity-0:05  activity-0:00  bg+1:00  id_num  \
# 0          other          other          other     13.4       0
# 1          other          other          other     12.8       1
# 2          other          other          other     15.5       2
# 3          other          other          other     14.8       3
# 4          other          other          other     12.7       4
#
#    minutes_since_start
# 0                  370
# 1                  385
# 2                  400
# 3                  415
# 4                  430
#
# [5 rows x 509 columns]

# %% [markdown]
# ## Removendo as colunas de identificação

# %%
cols_to_pop = ['id', 'p_num']
identificadores = ds[cols_to_pop].copy()
ds = ds.drop(columns=cols_to_pop)
ds.head(5)
# Out:
#    bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  bg-5:25  bg-5:20  \
# 0      0.0      0.0      9.6      0.0      0.0      9.7      0.0      0.0
# 1      0.0      0.0      9.7      0.0      0.0      9.2      0.0      0.0
# 2      0.0      0.0      9.2      0.0      0.0      8.7      0.0      0.0
# 3      0.0      0.0      8.7      0.0      0.0      8.4      0.0      0.0
# 4      0.0      0.0      8.4      0.0      0.0      8.1      0.0      0.0
#
#    bg-5:15  bg-5:10  ...  activity-0:30  activity-0:25  activity-0:20  \
# 0      9.2      0.0  ...          other          other          other
# 1      8.7      0.0  ...          other          other          other
# 2      8.4      0.0  ...          other          other          other
# 3      8.1      0.0  ...          other          other          other
# 4      8.3      0.0  ...          other          other          other
#
#    activity-0:15  activity-0:10  activity-0:05  activity-0:00  bg+1:00  \
# 0          other          other          other          other     13.4
# 1          other          other          other          other     12.8
# 2          other          other          other          other     15.5
# 3          other          other          other          other     14.8
# 4          other          other          other          other     12.7
#
#    id_num  minutes_since_start
# 0       0                  370
# 1       1                  385
# 2       2                  400
# 3       3                  415
# 4       4                  430
#
# [5 rows x 507 columns]

# %% [markdown]
# ## Trocando as colunas de atividade por um valor inteiro

# %%
# ds['activity-0:00'].unique()
mapeamento = {
    'other': 0, 'Walk': 1, 'Indoor climbing': 2, 'Yoga': 3, 'Zumba': 4, 'HIIT': 5,
    'Dancing': 6, 'Swim': 7, 'Outdoor Bike': 8, 'Aerobic Workout': 9, 'Sport': 10,
    'Walking': 11, 'Running': 12, 'Swimming': 13, 'Run': 14, 'Weights': 15, 'Workout': 16,
    'Tennis': 17, 'Strength training': 18, 'Stairclimber': 19, 'Spinning': 20, 'Hike': 21,
    'Bike':21
}

prefix = 'activity-'
cols_to_map = [col for col in ds.columns if col.startswith(prefix)]
ds[cols_to_map] = ds[cols_to_map].apply(lambda col: col.map(mapeamento))

ds.head(5)
# Out:
#    bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  bg-5:25  bg-5:20  \
# 0      0.0      0.0      9.6      0.0      0.0      9.7      0.0      0.0
# 1      0.0      0.0      9.7      0.0      0.0      9.2      0.0      0.0
# 2      0.0      0.0      9.2      0.0      0.0      8.7      0.0      0.0
# 3      0.0      0.0      8.7      0.0      0.0      8.4      0.0      0.0
# 4      0.0      0.0      8.4      0.0      0.0      8.1      0.0      0.0
#
#    bg-5:15  bg-5:10  ...  activity-0:30  activity-0:25  activity-0:20  \
# 0      9.2      0.0  ...              0              0              0
# 1      8.7      0.0  ...              0              0              0
# 2      8.4      0.0  ...              0              0              0
# 3      8.1      0.0  ...              0              0              0
# 4      8.3      0.0  ...              0              0              0
#
#    activity-0:15  activity-0:10  activity-0:05  activity-0:00  bg+1:00  \
# 0              0              0              0              0     13.4
# 1              0              0              0              0     12.8
# 2              0              0              0              0     15.5
# 3              0              0              0              0     14.8
# 4              0              0              0              0     12.7
#
#    id_num  minutes_since_start
# 0       0                  370
# 1       1                  385
# 2       2                  400
# 3       3                  415
# 4       4                  430
#
# [5 rows x 507 columns]

# %% [markdown]
# # Montando o modelo

# %% [markdown]
# ## Separando treino e teste

# %%
train = ds.sample(frac=0.75, random_state=0)
test = ds.drop(train.index)

# %%
x_train = train
y_train = train.pop('bg+1:00')

# %%
print(x_train.shape)
x_train.head(5)
# Out:
# (132768, 506)
#          bg-5:55  bg-5:50  bg-5:45    bg-5:40    bg-5:35  bg-5:30    bg-5:25  \
# 91143  10.890515    6.471      4.9  10.847561   6.361386      5.2  10.719293
# 35758  11.000000   11.000     11.4  11.700000  12.400000     12.6  13.000000
# 65296   9.500000    9.400      9.9  10.000000  10.300000     10.2  10.200000
# 14652   7.700000    7.700      8.0   8.200000   8.700000      9.8  10.500000
# 54561   9.300000    9.500      9.2   8.700000   8.400000      7.9   7.300000
#
#          bg-5:20  bg-5:15    bg-5:10  ...  activity-0:35  activity-0:30  \
# 91143   6.282353      6.7  10.889519  ...              0              0
# 35758  13.600000     13.8  14.500000  ...              0              0
# 65296   9.800000      9.4   9.300000  ...              0              0
# 14652  10.800000     10.7  10.700000  ...              0              0
# 54561   6.900000      6.5   6.200000  ...              0              0
#
#        activity-0:25  activity-0:20  activity-0:15  activity-0:10  \
# 91143              0              0              0              0
# 35758              0              0              0              0
# 65296              0              0              0              0
# 14652              0              0              0              0
# 54561              0              0              0              0
#
#        activity-0:05  activity-0:00  id_num  minutes_since_start
# 91143              1              1    6098                 1280
# 35758              0              0    1427                  300
# 65296              0              0    4937                  965
# 14652              0              0    6193                  100
# 54561              0              0   20230                  440
#
# [5 rows x 506 columns]

# %%
print(y_train.shape)
y_train.head(5)
# Out:
# (132768,)
# 91143    7.6
# 35758    7.6
# 65296    6.2
# 14652    9.0
# 54561    5.7
# Name: bg+1:00, dtype: float64

# %% [markdown]
# ## Construindo o modelo

# %%
from keras.layers import TimeDistributed, Dense, Input, Lambda, BatchNormalization, Concatenate, Conv1D, ZeroPadding1D
from keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.callbacks import EarlyStopping
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Configurando para não alocar diretamente toda a memória da GPU (alocar conforme necessário)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)  # Aloca memória conforme necessário
    except RuntimeError as e:
        print(e)
# Out:
# 2024-11-29 14:35:27.690080: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-29 14:35:27.699301: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732901727.710908   25158 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732901727.714901   25158 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-29 14:35:27.729241: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available:  1

# %%
def extrator_features(input_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims), activation=activation, use_bias=bias, kernel_regularizer="l1")(input_layer)
  # x_1 = tf.keras.layers.Dropout(0.2)(x_0)
  x_2 = Dense(int(input_dims/4), activation=activation, use_bias=bias)(x_0)
  x_3 = Dense(int(input_dims/8), activation=activation, use_bias=bias)(x_2)
  x_4 = Dense(int(input_dims/16), activation=activation, use_bias=bias)(x_3)
  x_bottleneck = Dense(int(input_dims/16), activation=activation, name='encoder', use_bias=bias, kernel_regularizer="l2")(x_4)

  return Model(input_layer, x_bottleneck, name="features")

def regressor(input_dims, output_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims/2), activation=activation, use_bias=bias)(input_layer)
  x_2 = Dense(int(input_dims/4), activation=activation, use_bias=bias)(x_0)
  saidas = Dense(output_dims, activation=None, name='regressor_saidas', use_bias=bias)(x_2)

  return Model(input_layer, saidas, name="regressor")

def build_models(input_dims, output_dims, activation, bias):
  # Camadas de entrada
  input_layer = Input(shape=[input_dims])

  # x_n = BatchNormalization()(input_layer)
  x_n = input_layer

  # Kernels
  extrator = extrator_features(input_dims, activation, bias)

  # Features
  features = extrator(x_n)

  # Regressão
  regressao = regressor(features.shape[1], output_dims, activation, bias)

  saida = regressao(features)
  
  return (
      Model(input_layer, saida, name="regressao"),
      Model(input_layer, features, name="projecao")
  )

model, features = build_models(x_train.shape[1], 1, 'elu', False)
model.compile(optimizer='Adamax', loss='mse', metrics=['mae', 'mse'])
plot_model(model, show_shapes=True, expand_nested=True)
# Out:
# I0000 00:00:1732901729.157003   25158 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2609 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# ## Treinando o modelo

# %%
# Callback para recuperar o melhor peso, e parar quando ficar três épocas sem melhora
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Treinando o modelo
history = model.fit(x_train, y_train, epochs=200, validation_split = 0.2, callbacks=[callback])
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732901731.152817   25262 service.cc:148] XLA service 0x74861000a740 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732901731.152835   25262 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2024-11-29 14:35:31.176058: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1732901731.222624   25262 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  258/3320 ━━━━━━━━━━━━━━━━━━━━ 1s 636us/step - loss: 527.1704 - mae: 8.4262 - mse: 440.0247
# I0000 00:00:1732901732.632307   25262 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 123.5420 - mae: 3.3153 - mse: 60.5474 - val_loss: 43.1704 - val_mae: 2.0403 - val_mse: 7.2774
# Epoch 2/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 706us/step - loss: 39.2544 - mae: 2.3923 - mse: 9.6700 - val_loss: 23.4466 - val_mae: 2.3401 - val_mse: 9.9420
# Epoch 3/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 694us/step - loss: 17.4062 - mae: 2.0493 - mse: 7.1353 - val_loss: 10.3806 - val_mae: 1.9759 - val_mse: 6.1302
# Epoch 4/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 693us/step - loss: 9.8522 - mae: 1.9638 - mse: 6.5607 - val_loss: 7.3820 - val_mae: 1.8559 - val_mse: 5.6452
# Epoch 5/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 676us/step - loss: 7.6507 - mae: 1.8818 - mse: 6.0606 - val_loss: 7.8329 - val_mae: 1.8835 - val_mse: 6.5206
# Epoch 6/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 686us/step - loss: 7.1125 - mae: 1.8497 - mse: 5.8803 - val_loss: 6.2375 - val_mae: 1.7529 - val_mse: 5.1872
# Epoch 7/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 681us/step - loss: 6.6891 - mae: 1.8080 - mse: 5.6316 - val_loss: 6.6590 - val_mae: 1.7461 - val_mse: 5.7075
# Epoch 8/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 689us/step - loss: 6.4138 - mae: 1.7755 - mse: 5.4487 - val_loss: 5.9334 - val_mae: 1.7016 - val_mse: 5.0290
# Epoch 9/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 675us/step - loss: 6.1064 - mae: 1.7335 - mse: 5.2441 - val_loss: 5.8066 - val_mae: 1.6780 - val_mse: 5.0130
# Epoch 10/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 688us/step - loss: 5.9801 - mae: 1.7201 - mse: 5.1870 - val_loss: 5.8728 - val_mae: 1.7426 - val_mse: 5.0722
# Epoch 11/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 711us/step - loss: 5.8909 - mae: 1.7164 - mse: 5.1492 - val_loss: 5.4898 - val_mae: 1.6174 - val_mse: 4.8053
# Epoch 12/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 706us/step - loss: 5.6377 - mae: 1.6751 - mse: 4.9440 - val_loss: 5.5990 - val_mae: 1.6307 - val_mse: 4.9046
# Epoch 13/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 689us/step - loss: 5.6257 - mae: 1.6776 - mse: 4.9579 - val_loss: 5.2884 - val_mae: 1.5996 - val_mse: 4.6965
# Epoch 14/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 693us/step - loss: 5.5522 - mae: 1.6725 - mse: 4.9220 - val_loss: 5.3267 - val_mae: 1.6751 - val_mse: 4.7344
# Epoch 15/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 689us/step - loss: 5.3954 - mae: 1.6447 - mse: 4.7812 - val_loss: 5.7892 - val_mae: 1.6830 - val_mse: 5.1931
# Epoch 16/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 708us/step - loss: 5.4411 - mae: 1.6547 - mse: 4.8334 - val_loss: 5.3044 - val_mae: 1.6467 - val_mse: 4.7050
# Epoch 17/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 689us/step - loss: 5.4263 - mae: 1.6543 - mse: 4.8181 - val_loss: 5.2365 - val_mae: 1.5960 - val_mse: 4.6520
# Epoch 18/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 704us/step - loss: 5.4370 - mae: 1.6586 - mse: 4.8479 - val_loss: 5.1093 - val_mae: 1.5987 - val_mse: 4.5509
# Epoch 19/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 709us/step - loss: 5.3326 - mae: 1.6361 - mse: 4.7481 - val_loss: 5.7297 - val_mae: 1.6529 - val_mse: 5.0970
# Epoch 20/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 697us/step - loss: 5.3336 - mae: 1.6373 - mse: 4.7512 - val_loss: 5.1717 - val_mae: 1.6360 - val_mse: 4.5858
# Epoch 21/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 710us/step - loss: 5.3036 - mae: 1.6348 - mse: 4.7255 - val_loss: 5.2154 - val_mae: 1.5784 - val_mse: 4.6361
# Epoch 22/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 699us/step - loss: 5.2751 - mae: 1.6331 - mse: 4.7116 - val_loss: 5.1207 - val_mae: 1.6104 - val_mse: 4.5562
# Epoch 23/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 723us/step - loss: 5.2479 - mae: 1.6254 - mse: 4.6870 - val_loss: 5.0773 - val_mae: 1.5991 - val_mse: 4.5287
# Epoch 24/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 721us/step - loss: 5.2333 - mae: 1.6256 - mse: 4.6848 - val_loss: 5.0797 - val_mae: 1.5976 - val_mse: 4.5457
# Epoch 25/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 739us/step - loss: 5.2394 - mae: 1.6259 - mse: 4.6805 - val_loss: 5.3113 - val_mae: 1.6905 - val_mse: 4.7907
# Epoch 26/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 791us/step - loss: 5.2211 - mae: 1.6285 - mse: 4.6877 - val_loss: 5.1384 - val_mae: 1.5810 - val_mse: 4.6477
# Epoch 27/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 756us/step - loss: 5.1699 - mae: 1.6179 - mse: 4.6339 - val_loss: 5.0523 - val_mae: 1.6132 - val_mse: 4.5541
# Epoch 28/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 742us/step - loss: 5.1862 - mae: 1.6182 - mse: 4.6571 - val_loss: 5.1053 - val_mae: 1.6297 - val_mse: 4.5632
# Epoch 29/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 758us/step - loss: 5.1562 - mae: 1.6145 - mse: 4.6150 - val_loss: 4.9182 - val_mae: 1.5731 - val_mse: 4.3952
# Epoch 30/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 752us/step - loss: 5.1057 - mae: 1.6045 - mse: 4.5868 - val_loss: 5.3226 - val_mae: 1.5930 - val_mse: 4.6987
# Epoch 31/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 744us/step - loss: 5.1717 - mae: 1.6195 - mse: 4.6513 - val_loss: 4.9403 - val_mae: 1.5556 - val_mse: 4.4332
# Epoch 32/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 755us/step - loss: 5.0445 - mae: 1.6033 - mse: 4.5531 - val_loss: 5.5162 - val_mae: 1.6239 - val_mse: 4.8924
# Epoch 33/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 758us/step - loss: 5.1224 - mae: 1.6141 - mse: 4.6165 - val_loss: 4.8675 - val_mae: 1.5577 - val_mse: 4.3669
# Epoch 34/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 749us/step - loss: 5.0785 - mae: 1.6038 - mse: 4.5799 - val_loss: 4.8915 - val_mae: 1.5954 - val_mse: 4.4188
# Epoch 35/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 767us/step - loss: 5.0978 - mae: 1.6140 - mse: 4.5992 - val_loss: 4.8753 - val_mae: 1.5523 - val_mse: 4.3774
# Epoch 36/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 741us/step - loss: 5.0086 - mae: 1.5926 - mse: 4.5183 - val_loss: 5.6858 - val_mae: 1.6817 - val_mse: 5.2171
# Epoch 37/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 750us/step - loss: 4.9763 - mae: 1.5873 - mse: 4.4912 - val_loss: 4.9584 - val_mae: 1.5683 - val_mse: 4.4805
# Epoch 38/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 770us/step - loss: 5.0138 - mae: 1.5960 - mse: 4.5307 - val_loss: 4.9500 - val_mae: 1.6026 - val_mse: 4.4465
# Epoch 39/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 771us/step - loss: 5.0557 - mae: 1.6032 - mse: 4.5680 - val_loss: 4.9056 - val_mae: 1.5507 - val_mse: 4.4380
# Epoch 40/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 805us/step - loss: 5.0077 - mae: 1.5962 - mse: 4.5299 - val_loss: 4.8632 - val_mae: 1.5872 - val_mse: 4.3979
# Epoch 41/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 775us/step - loss: 5.0389 - mae: 1.6006 - mse: 4.5672 - val_loss: 4.9028 - val_mae: 1.5750 - val_mse: 4.3916
# Epoch 42/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 752us/step - loss: 4.9699 - mae: 1.5913 - mse: 4.4983 - val_loss: 4.8613 - val_mae: 1.5513 - val_mse: 4.3429
# Epoch 43/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 786us/step - loss: 4.9019 - mae: 1.5778 - mse: 4.4369 - val_loss: 4.8697 - val_mae: 1.5489 - val_mse: 4.3942
# Epoch 44/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 784us/step - loss: 4.9819 - mae: 1.5896 - mse: 4.5248 - val_loss: 4.8479 - val_mae: 1.5438 - val_mse: 4.4280
# Epoch 45/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 787us/step - loss: 4.9717 - mae: 1.5943 - mse: 4.5216 - val_loss: 4.8223 - val_mae: 1.5814 - val_mse: 4.4120
# Epoch 46/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 811us/step - loss: 4.9391 - mae: 1.5881 - mse: 4.4909 - val_loss: 4.9739 - val_mae: 1.5630 - val_mse: 4.5276
# Epoch 47/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 804us/step - loss: 4.9139 - mae: 1.5871 - mse: 4.4717 - val_loss: 4.7853 - val_mae: 1.5582 - val_mse: 4.3262
# Epoch 48/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 796us/step - loss: 4.9325 - mae: 1.5834 - mse: 4.4887 - val_loss: 4.7349 - val_mae: 1.5469 - val_mse: 4.3407
# Epoch 49/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 804us/step - loss: 4.8844 - mae: 1.5808 - mse: 4.4434 - val_loss: 4.8041 - val_mae: 1.5490 - val_mse: 4.3305
# Epoch 50/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 790us/step - loss: 4.9085 - mae: 1.5811 - mse: 4.4587 - val_loss: 4.7311 - val_mae: 1.5725 - val_mse: 4.3250
# Epoch 51/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 814us/step - loss: 4.8962 - mae: 1.5822 - mse: 4.4564 - val_loss: 4.9522 - val_mae: 1.6324 - val_mse: 4.5365
# Epoch 52/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 801us/step - loss: 4.9159 - mae: 1.5823 - mse: 4.4757 - val_loss: 5.1078 - val_mae: 1.6312 - val_mse: 4.6699
# Epoch 53/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 808us/step - loss: 4.8745 - mae: 1.5751 - mse: 4.4330 - val_loss: 4.8280 - val_mae: 1.5557 - val_mse: 4.3427
# Epoch 54/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 862us/step - loss: 4.9123 - mae: 1.5804 - mse: 4.4710 - val_loss: 4.8073 - val_mae: 1.5409 - val_mse: 4.3236
# Epoch 55/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 803us/step - loss: 4.8845 - mae: 1.5756 - mse: 4.4449 - val_loss: 5.3818 - val_mae: 1.7115 - val_mse: 4.8142
# Epoch 56/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 858us/step - loss: 4.9131 - mae: 1.5877 - mse: 4.4820 - val_loss: 4.6694 - val_mae: 1.5499 - val_mse: 4.2840
# Epoch 57/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 808us/step - loss: 4.8614 - mae: 1.5745 - mse: 4.4289 - val_loss: 4.7517 - val_mae: 1.5318 - val_mse: 4.3354
# Epoch 58/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 811us/step - loss: 4.9088 - mae: 1.5798 - mse: 4.4795 - val_loss: 4.6834 - val_mae: 1.5543 - val_mse: 4.2924
# Epoch 59/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 846us/step - loss: 4.8209 - mae: 1.5666 - mse: 4.3973 - val_loss: 4.7916 - val_mae: 1.5567 - val_mse: 4.3568
# Epoch 60/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 850us/step - loss: 4.8321 - mae: 1.5721 - mse: 4.3981 - val_loss: 4.7352 - val_mae: 1.5282 - val_mse: 4.3162
# Epoch 61/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 810us/step - loss: 4.7463 - mae: 1.5521 - mse: 4.3173 - val_loss: 4.8138 - val_mae: 1.5341 - val_mse: 4.3533
# Epoch 62/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 831us/step - loss: 4.7739 - mae: 1.5619 - mse: 4.3410 - val_loss: 4.7044 - val_mae: 1.5295 - val_mse: 4.2299
# Epoch 63/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 822us/step - loss: 4.8237 - mae: 1.5598 - mse: 4.3800 - val_loss: 4.7613 - val_mae: 1.5473 - val_mse: 4.3423
# Epoch 64/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 824us/step - loss: 4.8261 - mae: 1.5653 - mse: 4.3898 - val_loss: 4.7765 - val_mae: 1.5317 - val_mse: 4.3139
# Epoch 65/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 834us/step - loss: 4.8321 - mae: 1.5717 - mse: 4.3858 - val_loss: 4.7366 - val_mae: 1.5344 - val_mse: 4.3368
# Epoch 66/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 838us/step - loss: 4.8033 - mae: 1.5638 - mse: 4.3692 - val_loss: 4.7354 - val_mae: 1.5458 - val_mse: 4.2954
# Epoch 67/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 808us/step - loss: 4.8134 - mae: 1.5615 - mse: 4.3734 - val_loss: 4.8144 - val_mae: 1.5840 - val_mse: 4.3892
# Epoch 68/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 815us/step - loss: 4.7956 - mae: 1.5604 - mse: 4.3643 - val_loss: 4.8170 - val_mae: 1.5838 - val_mse: 4.3694
# Epoch 69/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 832us/step - loss: 4.8000 - mae: 1.5632 - mse: 4.3600 - val_loss: 4.7775 - val_mae: 1.5394 - val_mse: 4.3904
# Epoch 70/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 847us/step - loss: 4.8017 - mae: 1.5571 - mse: 4.3632 - val_loss: 4.7080 - val_mae: 1.5531 - val_mse: 4.3177
# Epoch 71/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 832us/step - loss: 4.7471 - mae: 1.5527 - mse: 4.3192 - val_loss: 4.8570 - val_mae: 1.5420 - val_mse: 4.4140
# Epoch 72/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 843us/step - loss: 4.7928 - mae: 1.5623 - mse: 4.3548 - val_loss: 4.7361 - val_mae: 1.5487 - val_mse: 4.3507
# Epoch 73/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 833us/step - loss: 4.7907 - mae: 1.5573 - mse: 4.3519 - val_loss: 4.8751 - val_mae: 1.5933 - val_mse: 4.4135
# Epoch 74/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 845us/step - loss: 4.7692 - mae: 1.5524 - mse: 4.3285 - val_loss: 4.6370 - val_mae: 1.5334 - val_mse: 4.2457
# Epoch 75/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 859us/step - loss: 4.7606 - mae: 1.5540 - mse: 4.3262 - val_loss: 4.6680 - val_mae: 1.5431 - val_mse: 4.2795
# Epoch 76/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 841us/step - loss: 4.7517 - mae: 1.5539 - mse: 4.3349 - val_loss: 5.1210 - val_mae: 1.5890 - val_mse: 4.6957
# Epoch 77/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 887us/step - loss: 4.7147 - mae: 1.5504 - mse: 4.2880 - val_loss: 4.8015 - val_mae: 1.5398 - val_mse: 4.3753
# Epoch 78/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 852us/step - loss: 4.7257 - mae: 1.5452 - mse: 4.2881 - val_loss: 5.1152 - val_mae: 1.5839 - val_mse: 4.6052
# Epoch 79/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 855us/step - loss: 4.7623 - mae: 1.5505 - mse: 4.3231 - val_loss: 5.0144 - val_mae: 1.6504 - val_mse: 4.6167
# Epoch 80/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 856us/step - loss: 4.8108 - mae: 1.5614 - mse: 4.3681 - val_loss: 4.9752 - val_mae: 1.5711 - val_mse: 4.5711
# Epoch 81/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 856us/step - loss: 4.7679 - mae: 1.5545 - mse: 4.3167 - val_loss: 4.7364 - val_mae: 1.5180 - val_mse: 4.3266
# Epoch 82/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 856us/step - loss: 4.7156 - mae: 1.5444 - mse: 4.2833 - val_loss: 5.0809 - val_mae: 1.5989 - val_mse: 4.6694
# Epoch 83/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 861us/step - loss: 4.7435 - mae: 1.5449 - mse: 4.3015 - val_loss: 4.7595 - val_mae: 1.5807 - val_mse: 4.3607
# Epoch 84/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 855us/step - loss: 4.7092 - mae: 1.5414 - mse: 4.2622 - val_loss: 4.6504 - val_mae: 1.5346 - val_mse: 4.2348
# Epoch 85/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 896us/step - loss: 4.7319 - mae: 1.5486 - mse: 4.2942 - val_loss: 4.6825 - val_mae: 1.5139 - val_mse: 4.2519
# Epoch 86/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 919us/step - loss: 4.7514 - mae: 1.5453 - mse: 4.3080 - val_loss: 4.7038 - val_mae: 1.5214 - val_mse: 4.2603
# Epoch 87/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 893us/step - loss: 4.7543 - mae: 1.5485 - mse: 4.3010 - val_loss: 5.4480 - val_mae: 1.7388 - val_mse: 4.9667
# Epoch 88/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 893us/step - loss: 4.6894 - mae: 1.5396 - mse: 4.2459 - val_loss: 4.6569 - val_mae: 1.5478 - val_mse: 4.2361
# Epoch 89/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 884us/step - loss: 4.7371 - mae: 1.5449 - mse: 4.2769 - val_loss: 4.7762 - val_mae: 1.5375 - val_mse: 4.3089
# Epoch 90/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 889us/step - loss: 4.7203 - mae: 1.5393 - mse: 4.2782 - val_loss: 4.7289 - val_mae: 1.5287 - val_mse: 4.2740
# Epoch 91/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 880us/step - loss: 4.6986 - mae: 1.5416 - mse: 4.2445 - val_loss: 4.5900 - val_mae: 1.5142 - val_mse: 4.1657
# Epoch 92/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 879us/step - loss: 4.6645 - mae: 1.5338 - mse: 4.2164 - val_loss: 4.7227 - val_mae: 1.5591 - val_mse: 4.2713
# Epoch 93/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 882us/step - loss: 4.6452 - mae: 1.5293 - mse: 4.1988 - val_loss: 4.5954 - val_mae: 1.5017 - val_mse: 4.1495
# Epoch 94/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 878us/step - loss: 4.6670 - mae: 1.5295 - mse: 4.2130 - val_loss: 4.7313 - val_mae: 1.5315 - val_mse: 4.2735
# Epoch 95/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 909us/step - loss: 4.7143 - mae: 1.5403 - mse: 4.2663 - val_loss: 4.6943 - val_mae: 1.5271 - val_mse: 4.2480
# Epoch 96/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 876us/step - loss: 4.7086 - mae: 1.5362 - mse: 4.2535 - val_loss: 4.6244 - val_mae: 1.5243 - val_mse: 4.1739
# Epoch 97/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 885us/step - loss: 4.6877 - mae: 1.5330 - mse: 4.2275 - val_loss: 4.9116 - val_mae: 1.6165 - val_mse: 4.4751
# Epoch 98/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 881us/step - loss: 4.6595 - mae: 1.5321 - mse: 4.2047 - val_loss: 4.5498 - val_mae: 1.5048 - val_mse: 4.1185
# Epoch 99/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 867us/step - loss: 4.6791 - mae: 1.5343 - mse: 4.2222 - val_loss: 4.6619 - val_mae: 1.5482 - val_mse: 4.2237
# Epoch 100/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 879us/step - loss: 4.6505 - mae: 1.5264 - mse: 4.1982 - val_loss: 5.1148 - val_mae: 1.6585 - val_mse: 4.6360
# Epoch 101/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 887us/step - loss: 4.7383 - mae: 1.5445 - mse: 4.2744 - val_loss: 4.8029 - val_mae: 1.5299 - val_mse: 4.3777
# Epoch 102/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 891us/step - loss: 4.6615 - mae: 1.5292 - mse: 4.2108 - val_loss: 4.6552 - val_mae: 1.5070 - val_mse: 4.2103
# Epoch 103/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 877us/step - loss: 4.6210 - mae: 1.5212 - mse: 4.1659 - val_loss: 4.5785 - val_mae: 1.5009 - val_mse: 4.1265
# Epoch 104/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 875us/step - loss: 4.6837 - mae: 1.5327 - mse: 4.2251 - val_loss: 4.6983 - val_mae: 1.5110 - val_mse: 4.2567
# Epoch 105/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 872us/step - loss: 4.6699 - mae: 1.5284 - mse: 4.2088 - val_loss: 5.0167 - val_mae: 1.5575 - val_mse: 4.5182
# Epoch 106/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 888us/step - loss: 4.6468 - mae: 1.5261 - mse: 4.1831 - val_loss: 4.6602 - val_mae: 1.5351 - val_mse: 4.1943
# Epoch 107/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 877us/step - loss: 4.6789 - mae: 1.5275 - mse: 4.2188 - val_loss: 4.8464 - val_mae: 1.5168 - val_mse: 4.2973
# Epoch 108/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 873us/step - loss: 4.6401 - mae: 1.5190 - mse: 4.1756 - val_loss: 4.7371 - val_mae: 1.5076 - val_mse: 4.2809
# Epoch 109/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 886us/step - loss: 4.6466 - mae: 1.5220 - mse: 4.1810 - val_loss: 4.8658 - val_mae: 1.5367 - val_mse: 4.4149
# Epoch 110/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 881us/step - loss: 4.6408 - mae: 1.5175 - mse: 4.1815 - val_loss: 4.8652 - val_mae: 1.5318 - val_mse: 4.3739
# Epoch 111/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 887us/step - loss: 4.6724 - mae: 1.5266 - mse: 4.2019 - val_loss: 4.6035 - val_mae: 1.5238 - val_mse: 4.1639
# Epoch 112/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 884us/step - loss: 4.6792 - mae: 1.5307 - mse: 4.2190 - val_loss: 4.6044 - val_mae: 1.5334 - val_mse: 4.1768
# Epoch 113/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 894us/step - loss: 4.5718 - mae: 1.5098 - mse: 4.1092 - val_loss: 4.8175 - val_mae: 1.5612 - val_mse: 4.2828
# Epoch 114/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 878us/step - loss: 4.5801 - mae: 1.5123 - mse: 4.1201 - val_loss: 4.6472 - val_mae: 1.5325 - val_mse: 4.1806
# Epoch 115/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 899us/step - loss: 4.6946 - mae: 1.5294 - mse: 4.2306 - val_loss: 4.5469 - val_mae: 1.5129 - val_mse: 4.1357
# Epoch 116/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 890us/step - loss: 4.6035 - mae: 1.5187 - mse: 4.1489 - val_loss: 4.9060 - val_mae: 1.5643 - val_mse: 4.2749
# Epoch 117/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 883us/step - loss: 4.6829 - mae: 1.5277 - mse: 4.2111 - val_loss: 4.6147 - val_mae: 1.5032 - val_mse: 4.0941
# Epoch 118/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 882us/step - loss: 4.6473 - mae: 1.5280 - mse: 4.1831 - val_loss: 4.7524 - val_mae: 1.5335 - val_mse: 4.3247
# Epoch 119/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 887us/step - loss: 4.5943 - mae: 1.5102 - mse: 4.1321 - val_loss: 4.5350 - val_mae: 1.4934 - val_mse: 4.0633
# Epoch 120/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 892us/step - loss: 4.6507 - mae: 1.5235 - mse: 4.1770 - val_loss: 4.8104 - val_mae: 1.5248 - val_mse: 4.2466
# Epoch 121/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 881us/step - loss: 4.5995 - mae: 1.5126 - mse: 4.1287 - val_loss: 5.0036 - val_mae: 1.5248 - val_mse: 4.2723
# Epoch 122/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 879us/step - loss: 4.6738 - mae: 1.5254 - mse: 4.1994 - val_loss: 4.9907 - val_mae: 1.5614 - val_mse: 4.5697
# Epoch 123/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 904us/step - loss: 4.6277 - mae: 1.5184 - mse: 4.1598 - val_loss: 4.6281 - val_mae: 1.5020 - val_mse: 4.1654
# Epoch 124/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 883us/step - loss: 4.6843 - mae: 1.5260 - mse: 4.1948 - val_loss: 4.6462 - val_mae: 1.5025 - val_mse: 4.1892
# Epoch 125/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 891us/step - loss: 4.5773 - mae: 1.5128 - mse: 4.1148 - val_loss: 4.5675 - val_mae: 1.5053 - val_mse: 4.1125
# Epoch 126/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 895us/step - loss: 4.5710 - mae: 1.5064 - mse: 4.1050 - val_loss: 4.6668 - val_mae: 1.5053 - val_mse: 4.1592
# Epoch 127/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 892us/step - loss: 4.5680 - mae: 1.5088 - mse: 4.1047 - val_loss: 4.7085 - val_mae: 1.5108 - val_mse: 4.2401
# Epoch 128/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 888us/step - loss: 4.5781 - mae: 1.5068 - mse: 4.1024 - val_loss: 4.7734 - val_mae: 1.5284 - val_mse: 4.2971
# Epoch 129/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 902us/step - loss: 4.5913 - mae: 1.5095 - mse: 4.1094 - val_loss: 4.8011 - val_mae: 1.5140 - val_mse: 4.2732
# Epoch 130/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 902us/step - loss: 4.5807 - mae: 1.5041 - mse: 4.1058 - val_loss: 4.8747 - val_mae: 1.5865 - val_mse: 4.3660
# Epoch 131/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 902us/step - loss: 4.5819 - mae: 1.5037 - mse: 4.1015 - val_loss: 4.6901 - val_mae: 1.5015 - val_mse: 4.1426
# Epoch 132/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 900us/step - loss: 4.6039 - mae: 1.5098 - mse: 4.1270 - val_loss: 4.6646 - val_mae: 1.5479 - val_mse: 4.2179
# Epoch 133/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 896us/step - loss: 4.5925 - mae: 1.5081 - mse: 4.1065 - val_loss: 4.6010 - val_mae: 1.4876 - val_mse: 4.1287
# Epoch 134/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 897us/step - loss: 4.5709 - mae: 1.5060 - mse: 4.0886 - val_loss: 5.0058 - val_mae: 1.6377 - val_mse: 4.5510
# Epoch 135/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 909us/step - loss: 4.6230 - mae: 1.5147 - mse: 4.1360 - val_loss: 4.9323 - val_mae: 1.6126 - val_mse: 4.4740
# Epoch 136/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 904us/step - loss: 4.6310 - mae: 1.5164 - mse: 4.1526 - val_loss: 5.0678 - val_mae: 1.5846 - val_mse: 4.6201
# Epoch 137/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 906us/step - loss: 4.6013 - mae: 1.5079 - mse: 4.1232 - val_loss: 4.6750 - val_mae: 1.5451 - val_mse: 4.1989
# Epoch 138/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 905us/step - loss: 4.5617 - mae: 1.5016 - mse: 4.0814 - val_loss: 4.7912 - val_mae: 1.5168 - val_mse: 4.2268
# Epoch 139/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 893us/step - loss: 4.5346 - mae: 1.4969 - mse: 4.0518 - val_loss: 4.7973 - val_mae: 1.5230 - val_mse: 4.3730

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist['rmse'] = np.sqrt(hist['mse'])
hist['val_rmse'] = np.sqrt(hist['val_mse'])
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch  \
# 134  4.591783  1.507066  4.107633  4.932322  1.612588  4.474019    134
# 135  4.603245  1.510506  4.122724  5.067756  1.584641  4.620083    135
# 136  4.580993  1.505895  4.102381  4.675037  1.545095  4.198874    136
# 137  4.584663  1.505744  4.099901  4.791180  1.516837  4.226826    137
# 138  4.583369  1.502516  4.092794  4.797335  1.523039  4.373039    138
#
#          rmse  val_rmse
# 134  2.026730  2.115188
# 135  2.030449  2.149438
# 136  2.025433  2.049115
# 137  2.024821  2.055925
# 138  2.023065  2.091181

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.title("Evolução das funções de perda durante o treinamento da rede")
plt.xlabel('Rodada')
plt.ylabel('Root Mean Square Error')
plt.plot(hist['epoch'], hist['rmse'], label='RMSE Treino')
plt.plot(hist['epoch'], hist['val_rmse'], label = 'RMSE Validação')
plt.legend()

plt.figure()
plt.xlabel('Rodada')
plt.ylabel('Mean Absolute Error')
plt.plot(hist['epoch'], hist['mae'], label='MAE Treino')
plt.plot(hist['epoch'], hist['val_mae'], label = 'MAE Validação')
plt.legend()

plt.show()

# %% [markdown]
# ## Avaliando o modelo nos dados de teste

# %% [markdown]
# ### Ajustando a base de teste

# %%
x_test = test
y_test = test.pop('bg+1:00')
print(x_test.shape)
x_test.head(5)
# Out:
# (44256, 506)
#     bg-5:55  bg-5:50    bg-5:45  bg-5:40  bg-5:35    bg-5:30  bg-5:25  \
# 2       0.0      0.0   9.200000      0.0      0.0   8.700000      0.0
# 10      0.0      0.0  12.800000      0.0      0.0  13.900000      0.0
# 21      0.0      0.0  17.300000      0.0      0.0  16.200000      0.0
# 27      0.0     13.4  14.166667      0.0     12.8  14.533333      0.0
# 30      0.0     14.8  14.566667      0.0     12.7  15.633333      0.0
#
#     bg-5:20  bg-5:15  bg-5:10  ...  activity-0:35  activity-0:30  \
# 2       0.0      8.4      0.0  ...              0              0
# 10      0.0     14.2      0.0  ...              0              0
# 21      0.0     15.1      0.0  ...              0              0
# 27     15.5     14.4      0.0  ...              0              0
# 30     11.4     15.9      0.0  ...              0              0
#
#     activity-0:25  activity-0:20  activity-0:15  activity-0:10  activity-0:05  \
# 2               0              0              0              0              0
# 10              0              0              0              0              0
# 21              0              0              0              0              0
# 27              0              0              0              0              0
# 30              0              0              0              0              0
#
#     activity-0:00  id_num  minutes_since_start
# 2               0       2                  400
# 10              0      10                  520
# 21              0      21                  685
# 27              0      27                  780
# 30              0      30                  825
#
# [5 rows x 506 columns]

# %%
y_test.head(5)
# Out:
# 2     15.5
# 10    17.4
# 21     4.8
# 27    13.1
# 30     8.3
# Name: bg+1:00, dtype: float64

# %% [markdown]
# ### Prevendo para a base de teste

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# 1383/1383 ━━━━━━━━━━━━━━━━━━━━ 1s 571us/step
# [[12.066376 ]
#  [ 9.606111 ]
#  [ 6.8840666]
#  ...
#  [ 7.149266 ]
#  [ 8.974066 ]
#  [11.75648  ]]

# %% [markdown]
# ### Calculando o erro para a base de teste

# %%
mse = tf.keras.losses.MSE(y_test, y_pred).numpy().mean()
mae = tf.keras.losses.MAE(y_test, y_pred).numpy().mean()
rmse = np.sqrt(mse)

# %%
print(f"RMSE Test: {rmse}")
print(f"MSE Test: {mse}")
print(f"MAE Test: {mae}")
# Out:
# RMSE Test: 2.0019631385803223
# MSE Test: 4.007856845855713
# MAE Test: 1.4863868951797485

# %% [markdown]
# ## Salvando o modelo em arquivo

# %%
model.save("brist1d_8_2.keras")
