# %% [markdown]
# # Análise Exploratória

# %%
import pandas as pd
from statsmodels.tsa.stattools import grangercausalitytests

# %% [markdown]
# ## Carregando o dataset de treino

# %%
df = pd.read_csv('dataset/train.csv', header=0)
print(df.shape)
df.head(5)
# Out:
# /tmp/ipykernel_30925/1990298691.py:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   ds = pd.read_csv('dataset/train.csv', header=0)
# (177024, 508)
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
# ...

# %% [markdown]
# ## Verificando a causalidade entre insulin e bg

# %%
selected_lags = []
start_lag = 1 # including it
final_lag = 7 # excluding it

# for each (feature, target), instead of 'chicken' and 'egg'
for lag in range(start_lag, final_lag):
    result = grangercausalitytests(df[['insulin-0:00', 'bg+1:00']], maxlag=iter([lag]))
    pvalue = result.get(lag)[0].get('ssr_ftest')[1]
    if (pvalue < 0.05): # coloquei 5%, mas esse valor pode ser ajustado. Quando menor, menos lags serão selecionados
        selected_lags.append(lag)
print(selected_lags)
# Out:
# 177024
# id                    0
# p_num                 0
# time                  0
# bg-5:55           27254
# bg-5:50           18491
#                   ...
# activity-0:15    174293
# activity-0:10    174287
# activity-0:05    174271
# activity-0:00    174287
# bg+1:00               0
# Length: 508, dtype: int64
# id                0.000000
# p_num             0.000000
# time              0.000000
# bg-5:55          15.395653
# bg-5:50          10.445476
#                    ...
# activity-0:15    98.457271
# activity-0:10    98.453882
# activity-0:05    98.444844
# activity-0:00    98.453882
# bg+1:00           0.000000
# Length: 508, dtype: float64
