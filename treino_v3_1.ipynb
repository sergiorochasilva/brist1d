# %% [markdown]
# # Brist1D - Kaggle competition

# %% [markdown]
# ## Loading and hadling dataset

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('dataset/train.csv', header=0)
print(df.shape)
df.head(5)
# Out:
# /tmp/ipykernel_1348570/722352279.py:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset/train.csv', header=0)
# (177024, 508)
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:40  activity-0:35  activity-0:30  \
# 0      9.7      NaN  ...            NaN            NaN            NaN
# 1      9.2      NaN  ...            NaN            NaN            NaN
# 2      8.7      NaN  ...            NaN            NaN            NaN
# 3      8.4      NaN  ...            NaN            NaN            NaN
# 4      8.1      NaN  ...            NaN            NaN            NaN
#
#    activity-0:25  activity-0:20  activity-0:15  activity-0:10  activity-0:05  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    activity-0:00  bg+1:00
# 0            NaN     13.4
# 1            NaN     12.8
# 2            NaN     15.5
# 3            NaN     14.8
# 4            NaN     12.7
#
# [5 rows x 508 columns]

# %% [markdown]
# ## Filtering desired collumns (based on a correlation analises)

# %%
def filter_desired_columns(data, include_target: bool = True):
    desired_columns = [
        "id", "p_num", "time",
        "bg-0:00", "bg-0:05", "bg-0:10", "bg-0:15", "bg-0:20", "bg-0:25", "bg-0:30", "bg-0:35", "bg-0:40", "bg-0:45",
        "insulin-0:00", "insulin-0:05", "insulin-0:10", "insulin-0:15", "insulin-0:20",
        "hr-0:00", "hr-0:05", "hr-0:10", "hr-0:15", "hr-0:20", "hr-0:25", "hr-0:30",
        "steps-0:00", "steps-0:05", "steps-0:10", "steps-0:15",
        "cals-0:00", "cals-0:05",
    ]

    if include_target:
        desired_columns.append("bg+1:00")
        
    return data[desired_columns]

df = filter_desired_columns(df)
df.head(5)
# Out:
#       id p_num      time  bg-0:00  bg-0:05  bg-0:10  bg-0:15  bg-0:20  \
# 0  p01_0   p01  06:10:00     15.1      NaN      NaN     16.2      NaN
# 1  p01_1   p01  06:25:00     14.4      NaN      NaN     15.1      NaN
# 2  p01_2   p01  06:40:00     13.9      NaN      NaN     14.4      NaN
# 3  p01_3   p01  06:55:00     13.8      NaN      NaN     13.9      NaN
# 4  p01_4   p01  07:10:00     13.4      NaN      NaN     13.8      NaN
#
#    bg-0:25  bg-0:30  ...  hr-0:20  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0      NaN     17.3  ...      NaN      NaN      NaN         NaN         NaN
# 1      NaN     16.2  ...      NaN      NaN      NaN         NaN         NaN
# 2      NaN     15.1  ...      NaN      NaN      NaN         NaN         NaN
# 3      NaN     14.4  ...      NaN      NaN      NaN         NaN         NaN
# 4      NaN     13.9  ...      NaN      NaN      NaN         NaN         NaN
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  bg+1:00
# 0         NaN         NaN        NaN        NaN     13.4
# 1         NaN         NaN        NaN        NaN     12.8
# 2         NaN         NaN        NaN        NaN     15.5
# 3         NaN         NaN        NaN        NaN     14.8
# 4         NaN         NaN        NaN        NaN     12.7
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Filling missing values

# %%
columns_to_fill = [
    "bg-0:00", "bg-0:05", "bg-0:10", "bg-0:15", "bg-0:20", "bg-0:25", "bg-0:30", "bg-0:35", "bg-0:40", "bg-0:45",
    "insulin-0:00", "insulin-0:05", "insulin-0:10", "insulin-0:15", "insulin-0:20",
    "hr-0:00", "hr-0:05", "hr-0:10", "hr-0:15", "hr-0:20", "hr-0:25", "hr-0:30",
    "steps-0:00", "steps-0:05", "steps-0:10", "steps-0:15",
    "cals-0:00", "cals-0:05",
]

df[columns_to_fill] = df[columns_to_fill].interpolate()

# %%
imputer = SimpleImputer()

df[columns_to_fill] = imputer.fit_transform(df[columns_to_fill])

# %% [markdown]
# ## Converting time into sin and cos pair

# %% [markdown]
# ### Converting time to minutes

# %%
df['minutes_since_start'] = pd.to_datetime(df['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(df['time'], format="%H:%M:%S").dt.minute
df = df.drop(columns=['time'])

# %% [markdown]
# ### Converting minutes to sin and cos pair (summing constant 2, to avoid zero values)

# %%
df["time_sin"] = np.sin(2 * np.pi / 1440 * df['minutes_since_start']) + 2
df["time_cos"] = np.cos(2 * np.pi / 1440 * df['minutes_since_start']) + 2
df = df.drop(columns=['minutes_since_start'])
df.head(5)
# Out:
#       id p_num  bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  \
# 0  p01_0   p01     15.1  8.246322  8.33178     16.2  8.258647  8.430463
# 1  p01_1   p01     14.4  8.246322  8.33178     15.1  8.258647  8.430463
# 2  p01_2   p01     13.9  8.246322  8.33178     14.4  8.258647  8.430463
# 3  p01_3   p01     13.8  8.246322  8.33178     13.9  8.258647  8.430463
# 4  p01_4   p01     13.4  8.246322  8.33178     13.8  8.258647  8.430463
#
#    bg-0:30   bg-0:35  ...    hr-0:30  steps-0:00  steps-0:05  steps-0:10  \
# 0     17.3  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 1     16.2  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 2     15.1  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 3     14.4  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 4     13.9  8.268978  ...  81.189919   44.927039   43.967174    43.96972
#
#    steps-0:15  cals-0:00  cals-0:05  bg+1:00  time_sin  time_cos
# 0   45.359472   8.130857   8.147582     13.4  2.999048  1.956381
# 1   45.359472   8.130857   8.147582     12.8  2.994056  1.891133
# 2   45.359472   8.130857   8.147582     15.5  2.984808  1.826352
# 3   45.359472   8.130857   8.147582     14.8  2.971342  1.762314
# 4   45.359472   8.130857   8.147582     12.7  2.953717  1.699294
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Removing ID columns

# %%
cols_to_pop = ['id', 'p_num']
identifiers = df[cols_to_pop].copy()
df = df.drop(columns=cols_to_pop)
df.head(5)
# Out:
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  bg-0:30   bg-0:35  \
# 0     15.1  8.246322  8.33178     16.2  8.258647  8.430463     17.3  8.268978
# 1     14.4  8.246322  8.33178     15.1  8.258647  8.430463     16.2  8.268978
# 2     13.9  8.246322  8.33178     14.4  8.258647  8.430463     15.1  8.268978
# 3     13.8  8.246322  8.33178     13.9  8.258647  8.430463     14.4  8.268978
# 4     13.4  8.246322  8.33178     13.8  8.258647  8.430463     13.9  8.268978
#
#     bg-0:40  bg-0:45  ...    hr-0:30  steps-0:00  steps-0:05  steps-0:10  \
# 0  8.412561     17.5  ...  81.189919   44.927039   43.967174    43.96972
# 1  8.412561     17.3  ...  81.189919   44.927039   43.967174    43.96972
# 2  8.412561     16.2  ...  81.189919   44.927039   43.967174    43.96972
# 3  8.412561     15.1  ...  81.189919   44.927039   43.967174    43.96972
# 4  8.412561     14.4  ...  81.189919   44.927039   43.967174    43.96972
#
#    steps-0:15  cals-0:00  cals-0:05  bg+1:00  time_sin  time_cos
# 0   45.359472   8.130857   8.147582     13.4  2.999048  1.956381
# 1   45.359472   8.130857   8.147582     12.8  2.994056  1.891133
# 2   45.359472   8.130857   8.147582     15.5  2.984808  1.826352
# 3   45.359472   8.130857   8.147582     14.8  2.971342  1.762314
# 4   45.359472   8.130857   8.147582     12.7  2.953717  1.699294
#
# [5 rows x 31 columns]

# %%
df.to_csv("dataset/train_interpolate_circle_causalidade.csv", index=False)

# %% [markdown]
# ## Spliting train and test dataframes

# %%
train = df.sample(frac=0.75, random_state=0)
test = df.drop(train.index)

# %%
x_train = train
y_train = train.pop('bg+1:00')

# %%
print(x_train.shape)
x_train.head(5)
# Out:
# (132768, 30)
#        bg-0:00    bg-0:05    bg-0:10  bg-0:15    bg-0:20    bg-0:25  bg-0:30  \
# 91143      5.9   5.807317   8.354752      6.2   6.854918  11.098182      4.6
# 35758      8.2   8.200000   8.300000      8.5   8.700000   8.900000      8.5
# 65296      6.8   7.200000   7.900000      8.4   8.700000   8.700000      8.4
# 14652     10.5  10.600000  10.700000     10.8  10.900000  10.900000     11.0
# 54561      6.3   6.300000   6.300000      6.3   6.300000   6.300000      6.2
#
#          bg-0:35    bg-0:40  bg-0:45  ...    hr-0:25    hr-0:30  steps-0:00  \
# 91143   6.721488  11.227333      3.8  ...  86.000000  84.600000  518.000000
# 35758   8.400000   8.500000      8.8  ...  76.143817  76.139606   23.021904
# 65296   8.100000   7.900000      6.5  ...  86.300000  83.500000    8.000000
# 14652  11.200000  11.400000     11.4  ...  81.250505  81.045791   27.270000
# 54561   6.200000   6.200000      6.1  ...  53.000000  52.800000    0.000000
#
#        steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  \
# 91143  573.000000  440.000000    12.00000   8.350000   5.410000  1.357212
# 35758   23.077783   23.133661    23.18954   5.600000   5.600000  2.965926
# 65296   11.000000   14.000000    72.00000   7.090000   8.630000  1.123273
# 14652   27.193333   27.116667    27.04000   1.819452   1.817945  2.422618
# 54561    0.000000    0.000000     0.00000   5.720000   5.600000  2.939693
#
#        time_cos
# 91143  2.766044
# 35758  2.258819
# 65296  1.519011
# 14652  2.906308
# 54561  1.657980
#
# [5 rows x 30 columns]

# %%
print(y_train.shape)
y_train.head(5)
# Out:
# (132768,)
# 91143    7.6
# 35758    7.6
# 65296    6.2
# 14652    9.0
# 54561    5.7
# Name: bg+1:00, dtype: float64

# %%
x_train.to_csv("x.csv", index=False)
y_train.to_csv("y.csv", index=False)

# %% [markdown]
# ## Building model

# %% [markdown]
# ### Imports and GPU config

# %%
from keras.layers import TimeDistributed, Dense, Input, Lambda, BatchNormalization, Concatenate, Conv1D, ZeroPadding1D
from keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.callbacks import EarlyStopping
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Configurando para não alocar diretamente toda a memória da GPU (alocar conforme necessário)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)  # Aloca memória conforme necessário
    except RuntimeError as e:
        print(e)
# Out:
# 2024-11-20 11:36:50.383954: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-20 11:36:50.393290: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732113410.403823 1348570 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732113410.406699 1348570 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-20 11:36:50.417373: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available:  1

# %% [markdown]
# ### Model definition

# %%
def extrator_features(input_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims*4), activation=activation, use_bias=bias, kernel_regularizer=None)(input_layer)
  # x_1 = tf.keras.layers.Dropout(0.2)(x_0)
  x_2 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_0)
  x_3 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_2)
  x_4 = Dense(int(input_dims*4), activation=activation, use_bias=bias)(x_3)
  x_bottleneck = Dense(int(input_dims), activation=activation, name='encoder', use_bias=bias, kernel_regularizer="l1")(x_4)

  return Model(input_layer, x_bottleneck, name="features")

def regressor(input_dims, output_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims/2), activation=activation, use_bias=bias)(input_layer)
  x_2 = Dense(int(input_dims/4), activation=activation, use_bias=bias)(x_0)
  saidas = Dense(output_dims, activation=None, name='regressor_saidas', use_bias=bias)(x_2)

  return Model(input_layer, saidas, name="regressor")

def build_models(input_dims, output_dims, activation, bias):
  # Camadas de entrada
  input_layer = Input(shape=[input_dims])

  x_n = BatchNormalization()(input_layer)

  # Kernels
  extrator = extrator_features(input_dims, activation, bias)

  # Features
  features = extrator(x_n)

  # Regressão
  regressao = regressor(features.shape[1], output_dims, activation, bias)

  saida = regressao(features)
  
  return (
      Model(input_layer, saida, name="regressao"),
      Model(input_layer, features, name="projecao")
  )

model, features = build_models(x_train.shape[1], 1, 'silu', True)
model.compile(optimizer='adam', loss='mse', metrics=['mae', 'mse', 'mean_absolute_percentage_error'])
plot_model(model, show_shapes=True, expand_nested=True)
# Out:
# I0000 00:00:1732113420.182403 1348570 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2609 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# ### Training model

# %%
# Callback para recuperar o melhor peso, e parar quando ficar três épocas sem melhora
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Treinando o modelo
history = model.fit(x_train, y_train, epochs=200, validation_split = 0.2, callbacks=[callback])
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732113427.477751 1348713 service.cc:148] XLA service 0x700a98019c80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732113427.477774 1348713 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2024-11-20 11:37:07.515036: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1732113427.696208 1348713 cuda_dnn.cc:529] Loaded cuDNN version 90501
#  248/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 744us/step - loss: 23.3887 - mae: 3.2617 - mean_absolute_percentage_error: 41.2576 - mse: 20.0396
# I0000 00:00:1732113429.334319 1348713 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.9988 - mae: 1.8551 - mean_absolute_percentage_error: 24.2941 - mse: 6.7634 - val_loss: 4.1814 - val_mae: 1.4841 - val_mean_absolute_percentage_error: 19.5133 - val_mse: 4.0310
# Epoch 2/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 803us/step - loss: 4.5716 - mae: 1.5882 - mean_absolute_percentage_error: 20.9751 - mse: 4.4600 - val_loss: 4.1326 - val_mae: 1.4981 - val_mean_absolute_percentage_error: 20.0415 - val_mse: 4.0650
# Epoch 3/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 809us/step - loss: 4.4925 - mae: 1.5756 - mean_absolute_percentage_error: 20.8004 - mse: 4.4345 - val_loss: 4.1448 - val_mae: 1.4878 - val_mean_absolute_percentage_error: 19.2222 - val_mse: 4.0996
# Epoch 4/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 788us/step - loss: 4.3911 - mae: 1.5590 - mean_absolute_percentage_error: 20.6092 - mse: 4.3454 - val_loss: 4.2289 - val_mae: 1.5074 - val_mean_absolute_percentage_error: 19.0285 - val_mse: 4.1844
# Epoch 5/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 823us/step - loss: 4.3176 - mae: 1.5498 - mean_absolute_percentage_error: 20.4416 - mse: 4.2810 - val_loss: 4.0193 - val_mae: 1.4706 - val_mean_absolute_percentage_error: 19.0551 - val_mse: 3.9894
# Epoch 6/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 840us/step - loss: 4.2576 - mae: 1.5362 - mean_absolute_percentage_error: 20.2880 - mse: 4.2254 - val_loss: 4.0616 - val_mae: 1.4768 - val_mean_absolute_percentage_error: 18.9131 - val_mse: 4.0300
# Epoch 7/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 823us/step - loss: 4.2901 - mae: 1.5430 - mean_absolute_percentage_error: 20.3680 - mse: 4.2596 - val_loss: 3.9295 - val_mae: 1.4605 - val_mean_absolute_percentage_error: 19.3302 - val_mse: 3.9011
# Epoch 8/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 816us/step - loss: 4.2466 - mae: 1.5317 - mean_absolute_percentage_error: 20.1942 - mse: 4.2158 - val_loss: 3.9625 - val_mae: 1.4867 - val_mean_absolute_percentage_error: 20.2158 - val_mse: 3.9334
# Epoch 9/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 813us/step - loss: 4.1955 - mae: 1.5247 - mean_absolute_percentage_error: 20.1146 - mse: 4.1667 - val_loss: 3.9717 - val_mae: 1.4835 - val_mean_absolute_percentage_error: 19.7897 - val_mse: 3.9465
# Epoch 10/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 819us/step - loss: 4.1250 - mae: 1.5149 - mean_absolute_percentage_error: 20.0081 - mse: 4.0951 - val_loss: 3.8691 - val_mae: 1.4481 - val_mean_absolute_percentage_error: 19.0510 - val_mse: 3.8390
# Epoch 11/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 831us/step - loss: 4.1036 - mae: 1.5089 - mean_absolute_percentage_error: 19.9490 - mse: 4.0763 - val_loss: 3.9174 - val_mae: 1.4616 - val_mean_absolute_percentage_error: 19.2549 - val_mse: 3.8900
# Epoch 12/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 839us/step - loss: 4.0858 - mae: 1.5024 - mean_absolute_percentage_error: 19.7816 - mse: 4.0564 - val_loss: 3.9254 - val_mae: 1.4536 - val_mean_absolute_percentage_error: 18.7621 - val_mse: 3.9047
# Epoch 13/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 809us/step - loss: 4.0388 - mae: 1.4947 - mean_absolute_percentage_error: 19.7420 - mse: 4.0115 - val_loss: 4.0200 - val_mae: 1.4854 - val_mean_absolute_percentage_error: 20.0427 - val_mse: 3.9959
# Epoch 14/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 828us/step - loss: 4.0253 - mae: 1.4903 - mean_absolute_percentage_error: 19.6553 - mse: 3.9975 - val_loss: 3.8201 - val_mae: 1.4368 - val_mean_absolute_percentage_error: 18.8370 - val_mse: 3.8010
# Epoch 15/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 813us/step - loss: 3.9700 - mae: 1.4824 - mean_absolute_percentage_error: 19.4912 - mse: 3.9456 - val_loss: 3.8915 - val_mae: 1.4472 - val_mean_absolute_percentage_error: 18.9405 - val_mse: 3.8649
# Epoch 16/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 836us/step - loss: 3.9300 - mae: 1.4750 - mean_absolute_percentage_error: 19.4601 - mse: 3.9055 - val_loss: 3.9064 - val_mae: 1.4638 - val_mean_absolute_percentage_error: 19.5885 - val_mse: 3.8753
# Epoch 17/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 817us/step - loss: 3.8813 - mae: 1.4678 - mean_absolute_percentage_error: 19.3515 - mse: 3.8536 - val_loss: 3.8276 - val_mae: 1.4556 - val_mean_absolute_percentage_error: 19.6027 - val_mse: 3.8075
# Epoch 18/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 797us/step - loss: 3.8783 - mae: 1.4685 - mean_absolute_percentage_error: 19.3666 - mse: 3.8551 - val_loss: 3.9473 - val_mae: 1.4574 - val_mean_absolute_percentage_error: 18.6874 - val_mse: 3.9194
# Epoch 19/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 811us/step - loss: 3.8330 - mae: 1.4509 - mean_absolute_percentage_error: 19.1059 - mse: 3.8113 - val_loss: 3.8241 - val_mae: 1.4305 - val_mean_absolute_percentage_error: 18.5515 - val_mse: 3.8033
# Epoch 20/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 803us/step - loss: 3.8139 - mae: 1.4544 - mean_absolute_percentage_error: 19.2086 - mse: 3.7902 - val_loss: 3.8874 - val_mae: 1.4421 - val_mean_absolute_percentage_error: 18.4347 - val_mse: 3.8649
# Epoch 21/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 824us/step - loss: 3.7484 - mae: 1.4382 - mean_absolute_percentage_error: 18.9595 - mse: 3.7251 - val_loss: 3.8916 - val_mae: 1.4457 - val_mean_absolute_percentage_error: 18.5769 - val_mse: 3.8721
# Epoch 22/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 859us/step - loss: 3.7731 - mae: 1.4435 - mean_absolute_percentage_error: 18.9871 - mse: 3.7516 - val_loss: 3.7808 - val_mae: 1.4231 - val_mean_absolute_percentage_error: 18.5069 - val_mse: 3.7613
# Epoch 23/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 866us/step - loss: 3.7050 - mae: 1.4356 - mean_absolute_percentage_error: 18.9038 - mse: 3.6816 - val_loss: 3.8218 - val_mae: 1.4435 - val_mean_absolute_percentage_error: 19.3421 - val_mse: 3.7919
# Epoch 24/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 853us/step - loss: 3.6818 - mae: 1.4317 - mean_absolute_percentage_error: 18.8548 - mse: 3.6592 - val_loss: 3.7995 - val_mae: 1.4321 - val_mean_absolute_percentage_error: 18.8674 - val_mse: 3.7766
# Epoch 25/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 841us/step - loss: 3.6495 - mae: 1.4216 - mean_absolute_percentage_error: 18.7365 - mse: 3.6271 - val_loss: 3.8059 - val_mae: 1.4481 - val_mean_absolute_percentage_error: 19.5883 - val_mse: 3.7811
# Epoch 26/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 851us/step - loss: 3.5986 - mae: 1.4110 - mean_absolute_percentage_error: 18.6705 - mse: 3.5759 - val_loss: 3.8162 - val_mae: 1.4294 - val_mean_absolute_percentage_error: 18.4962 - val_mse: 3.7955
# Epoch 27/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 850us/step - loss: 3.5914 - mae: 1.4101 - mean_absolute_percentage_error: 18.5350 - mse: 3.5702 - val_loss: 3.8174 - val_mae: 1.4351 - val_mean_absolute_percentage_error: 18.6670 - val_mse: 3.7878
# Epoch 28/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 870us/step - loss: 3.6059 - mae: 1.4128 - mean_absolute_percentage_error: 18.6162 - mse: 3.5830 - val_loss: 3.7807 - val_mae: 1.4238 - val_mean_absolute_percentage_error: 18.4864 - val_mse: 3.7598
# Epoch 29/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 874us/step - loss: 3.5337 - mae: 1.3999 - mean_absolute_percentage_error: 18.4555 - mse: 3.5108 - val_loss: 3.8295 - val_mae: 1.4324 - val_mean_absolute_percentage_error: 18.8144 - val_mse: 3.8093
# Epoch 30/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 857us/step - loss: 3.5114 - mae: 1.3969 - mean_absolute_percentage_error: 18.4096 - mse: 3.4892 - val_loss: 3.7951 - val_mae: 1.4373 - val_mean_absolute_percentage_error: 19.1112 - val_mse: 3.7754
# Epoch 31/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 906us/step - loss: 3.4697 - mae: 1.3919 - mean_absolute_percentage_error: 18.3713 - mse: 3.4475 - val_loss: 3.8082 - val_mae: 1.4257 - val_mean_absolute_percentage_error: 18.4201 - val_mse: 3.7842
# Epoch 32/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 930us/step - loss: 3.4362 - mae: 1.3829 - mean_absolute_percentage_error: 18.2325 - mse: 3.4129 - val_loss: 3.7468 - val_mae: 1.4177 - val_mean_absolute_percentage_error: 18.7165 - val_mse: 3.7282
# Epoch 33/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 893us/step - loss: 3.4819 - mae: 1.3904 - mean_absolute_percentage_error: 18.3402 - mse: 3.4600 - val_loss: 3.8685 - val_mae: 1.4614 - val_mean_absolute_percentage_error: 19.8801 - val_mse: 3.8394
# Epoch 34/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 870us/step - loss: 3.4648 - mae: 1.3874 - mean_absolute_percentage_error: 18.2977 - mse: 3.4418 - val_loss: 3.8779 - val_mae: 1.4252 - val_mean_absolute_percentage_error: 18.5896 - val_mse: 3.8558
# Epoch 35/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 904us/step - loss: 3.3546 - mae: 1.3649 - mean_absolute_percentage_error: 18.0214 - mse: 3.3325 - val_loss: 3.8035 - val_mae: 1.4436 - val_mean_absolute_percentage_error: 19.5357 - val_mse: 3.7788
# Epoch 36/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 867us/step - loss: 3.3948 - mae: 1.3720 - mean_absolute_percentage_error: 18.0962 - mse: 3.3726 - val_loss: 3.7914 - val_mae: 1.4161 - val_mean_absolute_percentage_error: 18.3452 - val_mse: 3.7710
# Epoch 37/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 860us/step - loss: 3.3133 - mae: 1.3595 - mean_absolute_percentage_error: 17.9575 - mse: 3.2899 - val_loss: 3.7459 - val_mae: 1.4213 - val_mean_absolute_percentage_error: 18.7867 - val_mse: 3.7258
# Epoch 38/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 863us/step - loss: 3.3231 - mae: 1.3580 - mean_absolute_percentage_error: 17.8681 - mse: 3.3002 - val_loss: 3.8513 - val_mae: 1.4272 - val_mean_absolute_percentage_error: 18.2154 - val_mse: 3.8309
# Epoch 39/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 874us/step - loss: 3.2992 - mae: 1.3536 - mean_absolute_percentage_error: 17.8566 - mse: 3.2781 - val_loss: 3.8214 - val_mae: 1.4254 - val_mean_absolute_percentage_error: 18.5334 - val_mse: 3.7946
# Epoch 40/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 917us/step - loss: 3.2927 - mae: 1.3535 - mean_absolute_percentage_error: 17.7953 - mse: 3.2694 - val_loss: 4.0833 - val_mae: 1.4802 - val_mean_absolute_percentage_error: 19.7001 - val_mse: 4.0597
# Epoch 41/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 855us/step - loss: 3.2567 - mae: 1.3444 - mean_absolute_percentage_error: 17.7319 - mse: 3.2340 - val_loss: 3.7618 - val_mae: 1.4308 - val_mean_absolute_percentage_error: 19.1899 - val_mse: 3.7391
# Epoch 42/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 892us/step - loss: 3.2365 - mae: 1.3449 - mean_absolute_percentage_error: 17.7413 - mse: 3.2135 - val_loss: 3.7508 - val_mae: 1.4191 - val_mean_absolute_percentage_error: 18.7064 - val_mse: 3.7238
# Epoch 43/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 880us/step - loss: 3.2411 - mae: 1.3400 - mean_absolute_percentage_error: 17.6672 - mse: 3.2168 - val_loss: 3.7874 - val_mae: 1.4301 - val_mean_absolute_percentage_error: 18.7969 - val_mse: 3.7636
# Epoch 44/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 875us/step - loss: 3.2149 - mae: 1.3372 - mean_absolute_percentage_error: 17.6134 - mse: 3.1926 - val_loss: 3.7636 - val_mae: 1.4255 - val_mean_absolute_percentage_error: 18.6632 - val_mse: 3.7434
# Epoch 45/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 881us/step - loss: 3.1954 - mae: 1.3342 - mean_absolute_percentage_error: 17.5740 - mse: 3.1724 - val_loss: 3.7504 - val_mae: 1.4121 - val_mean_absolute_percentage_error: 18.0973 - val_mse: 3.7275
# Epoch 46/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 870us/step - loss: 3.2299 - mae: 1.3362 - mean_absolute_percentage_error: 17.6023 - mse: 3.2058 - val_loss: 3.8390 - val_mae: 1.4392 - val_mean_absolute_percentage_error: 19.1965 - val_mse: 3.8025
# Epoch 47/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 854us/step - loss: 3.2042 - mae: 1.3356 - mean_absolute_percentage_error: 17.5847 - mse: 3.1810 - val_loss: 3.7380 - val_mae: 1.4215 - val_mean_absolute_percentage_error: 18.7366 - val_mse: 3.7131
# Epoch 48/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 854us/step - loss: 3.2016 - mae: 1.3343 - mean_absolute_percentage_error: 17.5826 - mse: 3.1784 - val_loss: 3.8041 - val_mae: 1.4298 - val_mean_absolute_percentage_error: 18.8533 - val_mse: 3.7814
# Epoch 49/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 854us/step - loss: 3.1731 - mae: 1.3276 - mean_absolute_percentage_error: 17.5316 - mse: 3.1502 - val_loss: 3.8920 - val_mae: 1.4409 - val_mean_absolute_percentage_error: 18.4675 - val_mse: 3.8655
# Epoch 50/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 860us/step - loss: 3.1529 - mae: 1.3277 - mean_absolute_percentage_error: 17.5543 - mse: 3.1296 - val_loss: 3.7338 - val_mae: 1.4078 - val_mean_absolute_percentage_error: 18.3373 - val_mse: 3.7116
# Epoch 51/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 868us/step - loss: 3.1332 - mae: 1.3204 - mean_absolute_percentage_error: 17.4318 - mse: 3.1113 - val_loss: 3.7952 - val_mae: 1.4281 - val_mean_absolute_percentage_error: 18.8964 - val_mse: 3.7765
# Epoch 52/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 868us/step - loss: 3.1194 - mae: 1.3174 - mean_absolute_percentage_error: 17.3683 - mse: 3.0975 - val_loss: 3.7232 - val_mae: 1.4136 - val_mean_absolute_percentage_error: 18.4544 - val_mse: 3.7040
# Epoch 53/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 858us/step - loss: 3.0859 - mae: 1.3113 - mean_absolute_percentage_error: 17.2694 - mse: 3.0634 - val_loss: 3.8139 - val_mae: 1.4344 - val_mean_absolute_percentage_error: 19.0836 - val_mse: 3.7948
# Epoch 54/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 859us/step - loss: 3.0802 - mae: 1.3078 - mean_absolute_percentage_error: 17.2407 - mse: 3.0579 - val_loss: 3.8128 - val_mae: 1.4321 - val_mean_absolute_percentage_error: 18.9963 - val_mse: 3.7931
# Epoch 55/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 847us/step - loss: 3.1376 - mae: 1.3207 - mean_absolute_percentage_error: 17.3954 - mse: 3.1162 - val_loss: 3.7819 - val_mae: 1.4172 - val_mean_absolute_percentage_error: 18.3722 - val_mse: 3.7615
# Epoch 56/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 865us/step - loss: 3.0970 - mae: 1.3094 - mean_absolute_percentage_error: 17.2383 - mse: 3.0736 - val_loss: 3.7608 - val_mae: 1.4189 - val_mean_absolute_percentage_error: 18.7012 - val_mse: 3.7365
# Epoch 57/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 889us/step - loss: 3.1329 - mae: 1.3197 - mean_absolute_percentage_error: 17.4012 - mse: 3.1101 - val_loss: 3.8224 - val_mae: 1.4288 - val_mean_absolute_percentage_error: 18.8857 - val_mse: 3.7972
# Epoch 58/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 882us/step - loss: 3.0840 - mae: 1.3099 - mean_absolute_percentage_error: 17.2977 - mse: 3.0616 - val_loss: 3.7875 - val_mae: 1.4227 - val_mean_absolute_percentage_error: 18.7275 - val_mse: 3.7655
# Epoch 59/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 869us/step - loss: 3.0541 - mae: 1.3054 - mean_absolute_percentage_error: 17.2771 - mse: 3.0310 - val_loss: 3.8013 - val_mae: 1.4280 - val_mean_absolute_percentage_error: 18.9010 - val_mse: 3.7791
# Epoch 60/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 887us/step - loss: 3.0396 - mae: 1.3029 - mean_absolute_percentage_error: 17.2027 - mse: 3.0169 - val_loss: 3.8571 - val_mae: 1.4508 - val_mean_absolute_percentage_error: 19.3912 - val_mse: 3.8360
# Epoch 61/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 865us/step - loss: 3.0415 - mae: 1.2987 - mean_absolute_percentage_error: 17.1889 - mse: 3.0187 - val_loss: 3.8434 - val_mae: 1.4463 - val_mean_absolute_percentage_error: 19.6463 - val_mse: 3.8214
# Epoch 62/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 862us/step - loss: 2.9918 - mae: 1.2920 - mean_absolute_percentage_error: 17.0957 - mse: 2.9690 - val_loss: 3.7259 - val_mae: 1.4251 - val_mean_absolute_percentage_error: 19.0910 - val_mse: 3.6999
# Epoch 63/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 886us/step - loss: 2.9692 - mae: 1.2867 - mean_absolute_percentage_error: 17.0638 - mse: 2.9467 - val_loss: 3.8215 - val_mae: 1.4378 - val_mean_absolute_percentage_error: 19.2260 - val_mse: 3.7962
# Epoch 64/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 871us/step - loss: 2.9966 - mae: 1.2928 - mean_absolute_percentage_error: 17.0909 - mse: 2.9720 - val_loss: 3.8899 - val_mae: 1.4335 - val_mean_absolute_percentage_error: 18.5880 - val_mse: 3.8670
# Epoch 65/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 889us/step - loss: 3.0051 - mae: 1.2920 - mean_absolute_percentage_error: 17.0481 - mse: 2.9840 - val_loss: 3.7757 - val_mae: 1.4157 - val_mean_absolute_percentage_error: 18.4170 - val_mse: 3.7523
# Epoch 66/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 866us/step - loss: 2.9929 - mae: 1.2930 - mean_absolute_percentage_error: 17.0600 - mse: 2.9696 - val_loss: 3.8269 - val_mae: 1.4314 - val_mean_absolute_percentage_error: 19.1468 - val_mse: 3.8015
# Epoch 67/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 877us/step - loss: 2.9907 - mae: 1.2927 - mean_absolute_percentage_error: 17.0111 - mse: 2.9668 - val_loss: 3.8019 - val_mae: 1.4284 - val_mean_absolute_percentage_error: 18.9448 - val_mse: 3.7783
# Epoch 68/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 889us/step - loss: 2.9744 - mae: 1.2881 - mean_absolute_percentage_error: 16.9922 - mse: 2.9515 - val_loss: 3.7956 - val_mae: 1.4213 - val_mean_absolute_percentage_error: 18.4209 - val_mse: 3.7606
# Epoch 69/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 864us/step - loss: 2.9640 - mae: 1.2876 - mean_absolute_percentage_error: 17.0308 - mse: 2.9394 - val_loss: 3.7870 - val_mae: 1.4138 - val_mean_absolute_percentage_error: 18.3293 - val_mse: 3.7631
# Epoch 70/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 875us/step - loss: 2.9609 - mae: 1.2815 - mean_absolute_percentage_error: 16.9537 - mse: 2.9385 - val_loss: 3.7812 - val_mae: 1.4195 - val_mean_absolute_percentage_error: 18.7405 - val_mse: 3.7583
# Epoch 71/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 864us/step - loss: 2.9080 - mae: 1.2733 - mean_absolute_percentage_error: 16.8247 - mse: 2.8855 - val_loss: 3.7954 - val_mae: 1.4318 - val_mean_absolute_percentage_error: 18.9218 - val_mse: 3.7719
# Epoch 72/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 875us/step - loss: 2.9242 - mae: 1.2767 - mean_absolute_percentage_error: 16.8611 - mse: 2.9024 - val_loss: 3.8283 - val_mae: 1.4181 - val_mean_absolute_percentage_error: 18.3530 - val_mse: 3.7997

# %% [markdown]
# ### Analysing error metrics

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist['rmse'] = np.sqrt(hist['mse'])
hist['val_rmse'] = np.sqrt(hist['val_mse'])
hist.tail()
# Out:
#         loss       mae  mean_absolute_percentage_error       mse  val_loss  \
# 67  3.004888  1.292198                       17.067974  2.981622  3.795569
# 68  2.988214  1.291262                       17.036251  2.965440  3.786984
# 69  2.964964  1.283930                       16.973764  2.942460  3.781153
# 70  2.972970  1.286794                       16.975559  2.949947  3.795355
# 71  2.963369  1.283599                       16.939898  2.940745  3.828309
#
#      val_mae  val_mean_absolute_percentage_error   val_mse  epoch      rmse  \
# 67  1.421276                           18.420870  3.760597     67  1.726737
# 68  1.413786                           18.329277  3.763095     68  1.722045
# 69  1.419462                           18.740543  3.758257     69  1.715360
# 70  1.431847                           18.921776  3.771900     70  1.717541
# 71  1.418134                           18.352976  3.799713     71  1.714860
#
#     val_rmse
# 67  1.939226
# 68  1.939870
# 69  1.938622
# 70  1.942138
# 71  1.949285

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.title("Evolução das funções de perda durante o treinamento da rede")
plt.xlabel('Rodada')
plt.ylabel('Root Mean Square Error')
plt.plot(hist['epoch'], hist['rmse'], label='RMSE Treino')
plt.plot(hist['epoch'], hist['val_rmse'], label = 'RMSE Validação')
plt.legend()

plt.figure()
plt.xlabel('Rodada')
plt.ylabel('Mean Absolute Error')
plt.plot(hist['epoch'], hist['mae'], label='MAE Treino')
plt.plot(hist['epoch'], hist['val_mae'], label = 'MAE Validação')
plt.legend()

plt.show()

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# ### Preparing test dataframe

# %%
x_test = test
y_test = test.pop('bg+1:00')
print(x_test.shape)
x_test.head(5)
# Out:
# (44256, 30)
#     bg-0:00   bg-0:05  bg-0:10    bg-0:15   bg-0:20   bg-0:25    bg-0:30  \
# 2      13.9  8.246322  8.33178  14.400000  8.258647  8.430463  15.100000
# 10     11.9  8.246322  8.33178  11.400000  8.258647  8.430463  12.700000
# 21      5.8  8.246322  8.33178   6.600000  8.258647  8.430463   8.600000
# 27      7.8  7.100000  8.33178   7.366667  5.200000  8.430463   7.228571
# 30     12.3  7.933333  8.33178  11.066667  8.000000  8.430463  10.271429
#
#      bg-0:35   bg-0:40  bg-0:45  ...    hr-0:25    hr-0:30  steps-0:00  \
# 2   8.268978  8.412561  16.2000  ...  81.177985  81.189919   44.927039
# 10  8.268978  8.412561  14.8000  ...  81.177985  81.189919   44.927039
# 21  8.268978  8.412561  11.2000  ...  81.177985  81.189919   44.927039
# 27  4.800000  8.412561   7.1250  ...  81.177985  81.189919   44.927039
# 30  7.400000  8.412561   9.7125  ...  81.177985  81.189919   44.927039
#
#     steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  \
# 2    43.967174    43.96972   45.359472   8.130857   8.147582  2.984808
# 10   43.967174    43.96972   45.359472   8.130857   8.147582  2.766044
# 21   43.967174    43.96972   45.359472   8.130857   8.147582  2.152123
# 27   43.967174    43.96972   45.359472   8.130857   8.147582  1.741181
# 30   43.967174    43.96972   45.359472   8.130857   8.147582  1.557711
#
#     time_cos
# 2   1.826352
# 10  1.357212
# 21  1.011638
# 27  1.034074
# 30  1.103127
#
# [5 rows x 30 columns]

# %%
y_test.head(5)
# Out:
# 2     15.5
# 10    17.4
# 21     4.8
# 27    13.1
# 30     8.3
# Name: bg+1:00, dtype: float64

# %%
x_test.to_csv("x_t.csv", index=False)
y_test.to_csv("y_t.csv", index=False)

# %% [markdown]
# ### Running prediction

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# 1383/1383 ━━━━━━━━━━━━━━━━━━━━ 1s 421us/step
# [[12.965429 ]
#  [10.708067 ]
#  [ 5.9320016]
#  ...
#  [ 6.9438972]
#  [ 9.141082 ]
#  [11.055035 ]]

# %% [markdown]
# ### Calculating error metrics

# %%
mse = tf.keras.losses.MSE(y_test, y_pred).numpy().mean()
mae = tf.keras.losses.MAE(y_test, y_pred).numpy().mean()
rmse = np.sqrt(mse)

# %%
print(f"RMSE Test: {rmse}")
print(f"MSE Test: {mse}")
print(f"MAE Test: {mae}")
# Out:
# RMSE Test: 1.9193589687347412
# MSE Test: 3.68393874168396
# MAE Test: 1.406235933303833

# %% [markdown]
# ## Saving the model

# %%
model.save("brist1d_v3.keras")

# %% [markdown]
# ## Loading and processing submission dataframe

# %%
df_submission = pd.read_csv('dataset/test.csv', header=0)
print(df_submission.shape)
df_submission.head(5)
# Out:
# (3644, 507)
#          id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_8459   p01  06:45:00      NaN      9.2      NaN      NaN     10.2
# 1  p01_8460   p01  11:25:00      NaN      NaN      9.9      NaN      NaN
# 2  p01_8461   p01  14:45:00      NaN      5.5      NaN      NaN      5.5
# 3  p01_8462   p01  04:30:00      NaN      3.4      NaN      NaN      3.9
# 4  p01_8463   p01  04:20:00      NaN      NaN      8.3      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:45  activity-0:40  activity-0:35  \
# 0      NaN      NaN  ...            NaN            NaN            NaN
# 1      9.4      NaN  ...            NaN            NaN            NaN
# 2      NaN      NaN  ...            NaN            NaN            NaN
# 3      NaN      NaN  ...            NaN            NaN            NaN
# 4     10.0      NaN  ...            NaN            NaN            NaN
#
#    activity-0:30  activity-0:25  activity-0:20  activity-0:15  activity-0:10  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN           Walk
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    activity-0:05  activity-0:00
# 0            NaN            NaN
# 1           Walk           Walk
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
# [5 rows x 507 columns]

# %%
df_submission = filter_desired_columns(df_submission, False)
df_submission.head(5)
# Out:
#          id p_num      time  bg-0:00  bg-0:05  bg-0:10  bg-0:15  bg-0:20  \
# 0  p01_8459   p01  06:45:00      9.6      NaN      NaN      9.4      NaN
# 1  p01_8460   p01  11:25:00      4.6      NaN      NaN      6.3      NaN
# 2  p01_8461   p01  14:45:00      8.0      NaN      NaN      8.3      NaN
# 3  p01_8462   p01  04:30:00      9.9      NaN      NaN      8.5      NaN
# 4  p01_8463   p01  04:20:00      5.3      NaN      NaN      3.7      NaN
#
#    bg-0:25  bg-0:30  ...  hr-0:15  hr-0:20  hr-0:25  hr-0:30  steps-0:00  \
# 0      NaN      NaN  ...     55.6     53.2     54.4     55.8         NaN
# 1      NaN      6.4  ...     95.6     91.6     93.5     91.1       532.0
# 2      NaN      8.1  ...     75.7     81.1     87.9     92.1        69.0
# 3      NaN      7.8  ...     59.5     58.5     61.2     60.7         0.0
# 4      NaN      3.2  ...     58.9     57.6     55.1     56.2         NaN
#
#    steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05
# 0         NaN         NaN         0.0       6.06       4.90
# 1       377.0       547.0       411.0      32.43      24.57
# 2       283.0        27.0        10.0      10.16      19.76
# 3         NaN         NaN        14.0       4.80       4.90
# 4         NaN         NaN         NaN       4.80       4.80
#
# [5 rows x 31 columns]

# %%
df_submission[columns_to_fill] = df_submission[columns_to_fill].interpolate()
df_submission[columns_to_fill] = imputer.transform(df_submission[columns_to_fill])

# %%
df_submission['minutes_since_start'] = pd.to_datetime(df_submission['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(df_submission['time'], format="%H:%M:%S").dt.minute
df_submission = df_submission.drop(columns=['time'])
df_submission["time_sin"] = np.sin(2 * np.pi / 1440 * df_submission['minutes_since_start']) + 2
df_submission["time_cos"] = np.cos(2 * np.pi / 1440 * df_submission['minutes_since_start']) + 2
df_submission = df_submission.drop(columns=['minutes_since_start'])
df_submission.head(5)
# Out:
#          id p_num  bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  \
# 0  p01_8459   p01      9.6  8.246322  8.33178      9.4  8.258647  8.430463
# 1  p01_8460   p01      4.6  8.246322  8.33178      6.3  8.258647  8.430463
# 2  p01_8461   p01      8.0  8.246322  8.33178      8.3  8.258647  8.430463
# 3  p01_8462   p01      9.9  8.246322  8.33178      8.5  8.258647  8.430463
# 4  p01_8463   p01      5.3  8.246322  8.33178      3.7  8.258647  8.430463
#
#     bg-0:30  bg-0:35  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.282302     10.5  ...     54.4     55.8   44.927039   43.967174
# 1  6.400000     10.2  ...     93.5     91.1  532.000000  377.000000
# 2  8.100000      9.9  ...     87.9     92.1   69.000000  283.000000
# 3  7.800000      9.6  ...     61.2     60.7    0.000000  205.333333
# 4  3.200000      9.3  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 32 columns]

# %%
identifiers_submission = df_submission[cols_to_pop].copy()
df_submission = df_submission.drop(columns=cols_to_pop)
df_submission.head(5)
# Out:
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25   bg-0:30  bg-0:35  \
# 0      9.6  8.246322  8.33178      9.4  8.258647  8.430463  8.282302     10.5
# 1      4.6  8.246322  8.33178      6.3  8.258647  8.430463  6.400000     10.2
# 2      8.0  8.246322  8.33178      8.3  8.258647  8.430463  8.100000      9.9
# 3      9.9  8.246322  8.33178      8.5  8.258647  8.430463  7.800000      9.6
# 4      5.3  8.246322  8.33178      3.7  8.258647  8.430463  3.200000      9.3
#
#     bg-0:40   bg-0:45  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.412561  8.283803  ...     54.4     55.8   44.927039   43.967174
# 1  8.412561  4.500000  ...     93.5     91.1  532.000000  377.000000
# 2  8.412561  6.600000  ...     87.9     92.1   69.000000  283.000000
# 3  8.412561  7.500000  ...     61.2     60.7    0.000000  205.333333
# 4  8.412561  3.400000  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 30 columns]

# %%
print(df_submission.shape)
df_submission.head(5)
# Out:
# (3644, 30)
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25   bg-0:30  bg-0:35  \
# 0      9.6  8.246322  8.33178      9.4  8.258647  8.430463  8.282302     10.5
# 1      4.6  8.246322  8.33178      6.3  8.258647  8.430463  6.400000     10.2
# 2      8.0  8.246322  8.33178      8.3  8.258647  8.430463  8.100000      9.9
# 3      9.9  8.246322  8.33178      8.5  8.258647  8.430463  7.800000      9.6
# 4      5.3  8.246322  8.33178      3.7  8.258647  8.430463  3.200000      9.3
#
#     bg-0:40   bg-0:45  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.412561  8.283803  ...     54.4     55.8   44.927039   43.967174
# 1  8.412561  4.500000  ...     93.5     91.1  532.000000  377.000000
# 2  8.412561  6.600000  ...     87.9     92.1   69.000000  283.000000
# 3  8.412561  7.500000  ...     61.2     60.7    0.000000  205.333333
# 4  8.412561  3.400000  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Predicting submission dataset

# %%
# model = tf.keras.models.load_model("brist1d.keras")

# %%
y_submission = model.predict(df_submission)
df_pred_submission = pd.DataFrame(y_submission, columns=['bg+1:00'])
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %% [markdown]
# ### Joining identifiers

# %%
df_pred_submission = pd.concat([identifiers_submission, df_pred_submission], axis=1)
df_pred_submission.pop('p_num')
df_pred_submission.head(5)
# Out:
#          id    bg+1:00
# 0  p01_8459   9.315093
# 1  p01_8460   5.163402
# 2  p01_8461   7.043850
# 3  p01_8462  10.359314
# 4  p01_8463   7.163373

# %% [markdown]
# ### Exporting submission results

# %%
df_pred_submission.to_csv("dataset/predictions.csv", index=False)
