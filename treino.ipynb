# %% [markdown]
# # Brist1D - Kaggle competition

# %% [markdown]
# ## Loading and hadling dataset

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('dataset/train.csv', header=0)
print(df.shape)
df.head(5)
# Out:
# /tmp/ipykernel_80507/722352279.py:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset/train.csv', header=0)
# (177024, 508)
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:40  activity-0:35  activity-0:30  \
# 0      9.7      NaN  ...            NaN            NaN            NaN
# 1      9.2      NaN  ...            NaN            NaN            NaN
# 2      8.7      NaN  ...            NaN            NaN            NaN
# 3      8.4      NaN  ...            NaN            NaN            NaN
# 4      8.1      NaN  ...            NaN            NaN            NaN
#
#    activity-0:25  activity-0:20  activity-0:15  activity-0:10  activity-0:05  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    activity-0:00  bg+1:00
# 0            NaN     13.4
# 1            NaN     12.8
# 2            NaN     15.5
# 3            NaN     14.8
# 4            NaN     12.7
#
# [5 rows x 508 columns]

# %% [markdown]
# ## Filtering desired collumns (based on a correlation analises)

# %%
def filter_desired_columns(data, include_target: bool = True):
    desired_columns = [
        "id", "p_num", "time",
        "bg-0:00", "bg-0:05", "bg-0:10", "bg-0:15", "bg-0:20", "bg-0:25", "bg-0:30", "bg-0:35", "bg-0:40", "bg-0:45",
        "insulin-0:00", "insulin-0:05", "insulin-0:10", "insulin-0:15", "insulin-0:20",
        "hr-0:00", "hr-0:05", "hr-0:10", "hr-0:15", "hr-0:20", "hr-0:25", "hr-0:30",
        "steps-0:00", "steps-0:05", "steps-0:10", "steps-0:15",
        "cals-0:00", "cals-0:05",
    ]

    if include_target:
        desired_columns.append("bg+1:00")
        
    return data[desired_columns]

df = filter_desired_columns(df)
df.head(5)
# Out:
#       id p_num      time  bg-0:00  bg-0:05  bg-0:10  bg-0:15  bg-0:20  \
# 0  p01_0   p01  06:10:00     15.1      NaN      NaN     16.2      NaN
# 1  p01_1   p01  06:25:00     14.4      NaN      NaN     15.1      NaN
# 2  p01_2   p01  06:40:00     13.9      NaN      NaN     14.4      NaN
# 3  p01_3   p01  06:55:00     13.8      NaN      NaN     13.9      NaN
# 4  p01_4   p01  07:10:00     13.4      NaN      NaN     13.8      NaN
#
#    bg-0:25  bg-0:30  ...  hr-0:20  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0      NaN     17.3  ...      NaN      NaN      NaN         NaN         NaN
# 1      NaN     16.2  ...      NaN      NaN      NaN         NaN         NaN
# 2      NaN     15.1  ...      NaN      NaN      NaN         NaN         NaN
# 3      NaN     14.4  ...      NaN      NaN      NaN         NaN         NaN
# 4      NaN     13.9  ...      NaN      NaN      NaN         NaN         NaN
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  bg+1:00
# 0         NaN         NaN        NaN        NaN     13.4
# 1         NaN         NaN        NaN        NaN     12.8
# 2         NaN         NaN        NaN        NaN     15.5
# 3         NaN         NaN        NaN        NaN     14.8
# 4         NaN         NaN        NaN        NaN     12.7
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Filling missing values

# %%
columns_to_fill = [
    "bg-0:00", "bg-0:05", "bg-0:10", "bg-0:15", "bg-0:20", "bg-0:25", "bg-0:30", "bg-0:35", "bg-0:40", "bg-0:45",
    "insulin-0:00", "insulin-0:05", "insulin-0:10", "insulin-0:15", "insulin-0:20",
    "hr-0:00", "hr-0:05", "hr-0:10", "hr-0:15", "hr-0:20", "hr-0:25", "hr-0:30",
    "steps-0:00", "steps-0:05", "steps-0:10", "steps-0:15",
    "cals-0:00", "cals-0:05",
]

df[columns_to_fill] = df[columns_to_fill].interpolate()

# %%
imputer = SimpleImputer()

df[columns_to_fill] = imputer.fit_transform(df[columns_to_fill])

# %% [markdown]
# ## Converting time into sin and cos pair

# %% [markdown]
# ### Converting time to minutes

# %%
df['minutes_since_start'] = pd.to_datetime(df['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(df['time'], format="%H:%M:%S").dt.minute
df = df.drop(columns=['time'])

# %% [markdown]
# ### Converting minutes to sin and cos pair (summing constant 2, to avoid zero values)

# %%
df["time_sin"] = np.sin(2 * np.pi / 1440 * df['minutes_since_start']) + 2
df["time_cos"] = np.cos(2 * np.pi / 1440 * df['minutes_since_start']) + 2
df = df.drop(columns=['minutes_since_start'])
df.head(5)
# Out:
#       id p_num  bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  \
# 0  p01_0   p01     15.1  8.246322  8.33178     16.2  8.258647  8.430463
# 1  p01_1   p01     14.4  8.246322  8.33178     15.1  8.258647  8.430463
# 2  p01_2   p01     13.9  8.246322  8.33178     14.4  8.258647  8.430463
# 3  p01_3   p01     13.8  8.246322  8.33178     13.9  8.258647  8.430463
# 4  p01_4   p01     13.4  8.246322  8.33178     13.8  8.258647  8.430463
#
#    bg-0:30   bg-0:35  ...    hr-0:30  steps-0:00  steps-0:05  steps-0:10  \
# 0     17.3  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 1     16.2  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 2     15.1  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 3     14.4  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 4     13.9  8.268978  ...  81.189919   44.927039   43.967174    43.96972
#
#    steps-0:15  cals-0:00  cals-0:05  bg+1:00  time_sin  time_cos
# 0   45.359472   8.130857   8.147582     13.4  2.999048  1.956381
# 1   45.359472   8.130857   8.147582     12.8  2.994056  1.891133
# 2   45.359472   8.130857   8.147582     15.5  2.984808  1.826352
# 3   45.359472   8.130857   8.147582     14.8  2.971342  1.762314
# 4   45.359472   8.130857   8.147582     12.7  2.953717  1.699294
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Removing ID columns

# %%
cols_to_pop = ['id', 'p_num']
identifiers = df[cols_to_pop].copy()
df = df.drop(columns=cols_to_pop)
df.head(5)
# Out:
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  bg-0:30   bg-0:35  \
# 0     15.1  8.246322  8.33178     16.2  8.258647  8.430463     17.3  8.268978
# 1     14.4  8.246322  8.33178     15.1  8.258647  8.430463     16.2  8.268978
# 2     13.9  8.246322  8.33178     14.4  8.258647  8.430463     15.1  8.268978
# 3     13.8  8.246322  8.33178     13.9  8.258647  8.430463     14.4  8.268978
# 4     13.4  8.246322  8.33178     13.8  8.258647  8.430463     13.9  8.268978
#
#     bg-0:40  bg-0:45  ...    hr-0:30  steps-0:00  steps-0:05  steps-0:10  \
# 0  8.412561     17.5  ...  81.189919   44.927039   43.967174    43.96972
# 1  8.412561     17.3  ...  81.189919   44.927039   43.967174    43.96972
# 2  8.412561     16.2  ...  81.189919   44.927039   43.967174    43.96972
# 3  8.412561     15.1  ...  81.189919   44.927039   43.967174    43.96972
# 4  8.412561     14.4  ...  81.189919   44.927039   43.967174    43.96972
#
#    steps-0:15  cals-0:00  cals-0:05  bg+1:00  time_sin  time_cos
# 0   45.359472   8.130857   8.147582     13.4  2.999048  1.956381
# 1   45.359472   8.130857   8.147582     12.8  2.994056  1.891133
# 2   45.359472   8.130857   8.147582     15.5  2.984808  1.826352
# 3   45.359472   8.130857   8.147582     14.8  2.971342  1.762314
# 4   45.359472   8.130857   8.147582     12.7  2.953717  1.699294
#
# [5 rows x 31 columns]

# %%
df.to_csv("dataset/train_interpolate_circle_causalidade.csv", index=False)

# %% [markdown]
# ## Spliting train and test dataframes

# %%
train = df.sample(frac=0.75, random_state=0)
test = df.drop(train.index)

# %%
x_train = train
y_train = train.pop('bg+1:00')

# %%
print(x_train.shape)
x_train.head(5)
# Out:
# (132768, 30)
#        bg-0:00    bg-0:05    bg-0:10  bg-0:15    bg-0:20    bg-0:25  bg-0:30  \
# 91143      5.9   5.807317   8.354752      6.2   6.854918  11.098182      4.6
# 35758      8.2   8.200000   8.300000      8.5   8.700000   8.900000      8.5
# 65296      6.8   7.200000   7.900000      8.4   8.700000   8.700000      8.4
# 14652     10.5  10.600000  10.700000     10.8  10.900000  10.900000     11.0
# 54561      6.3   6.300000   6.300000      6.3   6.300000   6.300000      6.2
#
#          bg-0:35    bg-0:40  bg-0:45  ...    hr-0:25    hr-0:30  steps-0:00  \
# 91143   6.721488  11.227333      3.8  ...  86.000000  84.600000  518.000000
# 35758   8.400000   8.500000      8.8  ...  76.143817  76.139606   23.021904
# 65296   8.100000   7.900000      6.5  ...  86.300000  83.500000    8.000000
# 14652  11.200000  11.400000     11.4  ...  81.250505  81.045791   27.270000
# 54561   6.200000   6.200000      6.1  ...  53.000000  52.800000    0.000000
#
#        steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  \
# 91143  573.000000  440.000000    12.00000   8.350000   5.410000  1.357212
# 35758   23.077783   23.133661    23.18954   5.600000   5.600000  2.965926
# 65296   11.000000   14.000000    72.00000   7.090000   8.630000  1.123273
# 14652   27.193333   27.116667    27.04000   1.819452   1.817945  2.422618
# 54561    0.000000    0.000000     0.00000   5.720000   5.600000  2.939693
#
#        time_cos
# 91143  2.766044
# 35758  2.258819
# 65296  1.519011
# 14652  2.906308
# 54561  1.657980
#
# [5 rows x 30 columns]

# %%
print(y_train.shape)
y_train.head(5)
# Out:
# (132768,)
# 91143    7.6
# 35758    7.6
# 65296    6.2
# 14652    9.0
# 54561    5.7
# Name: bg+1:00, dtype: float64

# %%
x_train.to_csv("x.csv", index=False)
y_train.to_csv("y.csv", index=False)

# %% [markdown]
# ## Building model

# %% [markdown]
# ### Imports and GPU config

# %%
from keras.layers import TimeDistributed, Dense, Input, Lambda, BatchNormalization, Concatenate, Conv1D, ZeroPadding1D
from keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.callbacks import EarlyStopping
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Configurando para não alocar diretamente toda a memória da GPU (alocar conforme necessário)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)  # Aloca memória conforme necessário
    except RuntimeError as e:
        print(e)
# Out:
# 2024-11-19 21:03:47.307046: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-19 21:03:47.317012: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732061027.327300   80507 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732061027.329994   80507 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-19 21:03:47.341017: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available:  1

# %% [markdown]
# ### Model definition

# %%
def extrator_features(input_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims*4), activation=activation, use_bias=bias, kernel_regularizer="l2")(input_layer)
  x_1 = tf.keras.layers.Dropout(0.2)(x_0)
  x_2 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_1)
  x_3 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_2)
  x_4 = Dense(int(input_dims*4), activation=activation, use_bias=bias)(x_3)
  x_bottleneck = Dense(int(input_dims), activation=activation, name='encoder', use_bias=True, kernel_regularizer="l1")(x_4)

  return Model(input_layer, x_bottleneck, name="features")

def regressor(input_dims, output_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims/2), activation=activation, use_bias=bias)(input_layer)
  x_2 = Dense(int(input_dims/4), activation=activation, use_bias=bias)(x_0)
  saidas = Dense(output_dims, activation=None, name='regressor_saidas', use_bias=bias)(x_2)

  return Model(input_layer, saidas, name="regressor")

def build_models(input_dims, output_dims, activation, bias):
  # Camadas de entrada
  input_layer = Input(shape=[input_dims])

  x_n = BatchNormalization()(input_layer)

  # Kernels
  extrator = extrator_features(input_dims, activation, bias)

  # Features
  features = extrator(x_n)

  # Regressão
  regressao = regressor(features.shape[1], output_dims, activation, bias)

  saida = regressao(features)
  
  return (
      Model(input_layer, saida, name="regressao"),
      Model(input_layer, features, name="projecao")
  )

model, features = build_models(x_train.shape[1], 1, 'relu', False)
model.compile(optimizer='adam', loss='mse', metrics=['mae', 'mse', 'mean_absolute_percentage_error'])
plot_model(model, show_shapes=True, expand_nested=True)
# Out:
# I0000 00:00:1732061029.033511   80507 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2609 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# ### Training model

# %%
# Callback para recuperar o melhor peso, e parar quando ficar três épocas sem melhora
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Treinando o modelo
history = model.fit(x_train, y_train, epochs=200, validation_split = 0.2, callbacks=[callback])
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732061030.722793  136506 service.cc:148] XLA service 0x70448c00ff10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732061030.722817  136506 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2024-11-19 21:03:50.752733: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1732061030.910068  136506 cuda_dnn.cc:529] Loaded cuDNN version 90501
#  275/3320 ━━━━━━━━━━━━━━━━━━━━ 1s 642us/step - loss: 24.6974 - mae: 3.4804 - mean_absolute_percentage_error: 42.8201 - mse: 21.4285
# I0000 00:00:1732061032.576689  136506 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 9.6706 - mae: 2.1050 - mean_absolute_percentage_error: 27.0226 - mse: 8.3152 - val_loss: 4.7570 - val_mae: 1.5413 - val_mean_absolute_percentage_error: 20.3168 - val_mse: 4.3001
# Epoch 2/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 707us/step - loss: 5.2884 - mae: 1.6681 - mean_absolute_percentage_error: 21.9167 - mse: 4.9011 - val_loss: 4.4216 - val_mae: 1.5132 - val_mean_absolute_percentage_error: 19.4994 - val_mse: 4.1845
# Epoch 3/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 692us/step - loss: 4.8250 - mae: 1.6105 - mean_absolute_percentage_error: 21.1958 - mse: 4.6160 - val_loss: 4.5099 - val_mae: 1.5847 - val_mean_absolute_percentage_error: 22.0330 - val_mse: 4.3519
# Epoch 4/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 697us/step - loss: 4.6282 - mae: 1.5842 - mean_absolute_percentage_error: 20.9527 - mse: 4.4772 - val_loss: 4.2707 - val_mae: 1.5002 - val_mean_absolute_percentage_error: 19.1993 - val_mse: 4.1413
# Epoch 5/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 698us/step - loss: 4.5594 - mae: 1.5811 - mean_absolute_percentage_error: 20.8647 - mse: 4.4331 - val_loss: 4.2900 - val_mae: 1.5154 - val_mean_absolute_percentage_error: 19.6034 - val_mse: 4.1716
# Epoch 6/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 696us/step - loss: 4.5662 - mae: 1.5806 - mean_absolute_percentage_error: 20.8807 - mse: 4.4470 - val_loss: 4.1146 - val_mae: 1.5106 - val_mean_absolute_percentage_error: 20.7010 - val_mse: 3.9991
# Epoch 7/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 693us/step - loss: 4.5431 - mae: 1.5765 - mean_absolute_percentage_error: 20.8519 - mse: 4.4275 - val_loss: 4.1591 - val_mae: 1.5246 - val_mean_absolute_percentage_error: 20.9371 - val_mse: 4.0504
# Epoch 8/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 699us/step - loss: 4.5203 - mae: 1.5731 - mean_absolute_percentage_error: 20.8034 - mse: 4.4116 - val_loss: 4.0858 - val_mae: 1.4908 - val_mean_absolute_percentage_error: 19.8929 - val_mse: 3.9776
# Epoch 9/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 703us/step - loss: 4.4716 - mae: 1.5596 - mean_absolute_percentage_error: 20.6003 - mse: 4.3651 - val_loss: 4.1408 - val_mae: 1.5020 - val_mean_absolute_percentage_error: 19.9337 - val_mse: 4.0364
# Epoch 10/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 691us/step - loss: 4.4644 - mae: 1.5598 - mean_absolute_percentage_error: 20.6177 - mse: 4.3597 - val_loss: 4.0814 - val_mae: 1.4855 - val_mean_absolute_percentage_error: 19.8048 - val_mse: 3.9795
# Epoch 11/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 691us/step - loss: 4.4316 - mae: 1.5568 - mean_absolute_percentage_error: 20.5220 - mse: 4.3307 - val_loss: 4.1101 - val_mae: 1.4983 - val_mean_absolute_percentage_error: 20.1864 - val_mse: 4.0078
# Epoch 12/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 698us/step - loss: 4.4634 - mae: 1.5629 - mean_absolute_percentage_error: 20.6748 - mse: 4.3622 - val_loss: 4.0792 - val_mae: 1.5046 - val_mean_absolute_percentage_error: 20.5034 - val_mse: 3.9794
# Epoch 13/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 696us/step - loss: 4.4689 - mae: 1.5635 - mean_absolute_percentage_error: 20.6174 - mse: 4.3685 - val_loss: 4.0487 - val_mae: 1.4784 - val_mean_absolute_percentage_error: 19.5999 - val_mse: 3.9464
# Epoch 14/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 699us/step - loss: 4.4926 - mae: 1.5672 - mean_absolute_percentage_error: 20.7347 - mse: 4.3905 - val_loss: 4.0738 - val_mae: 1.4773 - val_mean_absolute_percentage_error: 19.4355 - val_mse: 3.9735
# Epoch 15/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 694us/step - loss: 4.4978 - mae: 1.5697 - mean_absolute_percentage_error: 20.7316 - mse: 4.3963 - val_loss: 4.1252 - val_mae: 1.4761 - val_mean_absolute_percentage_error: 18.9993 - val_mse: 4.0226
# Epoch 16/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 705us/step - loss: 4.4496 - mae: 1.5581 - mean_absolute_percentage_error: 20.5897 - mse: 4.3475 - val_loss: 4.0686 - val_mae: 1.5049 - val_mean_absolute_percentage_error: 20.4720 - val_mse: 3.9666
# Epoch 17/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 694us/step - loss: 4.4149 - mae: 1.5550 - mean_absolute_percentage_error: 20.6038 - mse: 4.3129 - val_loss: 4.1089 - val_mae: 1.5091 - val_mean_absolute_percentage_error: 20.4652 - val_mse: 4.0071
# Epoch 18/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 701us/step - loss: 4.4583 - mae: 1.5611 - mean_absolute_percentage_error: 20.6107 - mse: 4.3562 - val_loss: 4.0611 - val_mae: 1.4855 - val_mean_absolute_percentage_error: 19.7207 - val_mse: 3.9568
# Epoch 19/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 689us/step - loss: 4.4068 - mae: 1.5558 - mean_absolute_percentage_error: 20.5387 - mse: 4.3033 - val_loss: 4.0589 - val_mae: 1.4750 - val_mean_absolute_percentage_error: 19.5180 - val_mse: 3.9552
# Epoch 20/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 697us/step - loss: 4.4180 - mae: 1.5533 - mean_absolute_percentage_error: 20.5500 - mse: 4.3140 - val_loss: 4.0613 - val_mae: 1.5028 - val_mean_absolute_percentage_error: 20.4881 - val_mse: 3.9581
# Epoch 21/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 702us/step - loss: 4.4044 - mae: 1.5529 - mean_absolute_percentage_error: 20.4950 - mse: 4.3004 - val_loss: 4.0633 - val_mae: 1.4928 - val_mean_absolute_percentage_error: 20.1862 - val_mse: 3.9589
# Epoch 22/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 694us/step - loss: 4.3893 - mae: 1.5510 - mean_absolute_percentage_error: 20.4752 - mse: 4.2849 - val_loss: 4.0452 - val_mae: 1.4865 - val_mean_absolute_percentage_error: 19.8100 - val_mse: 3.9417
# Epoch 23/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 702us/step - loss: 4.4280 - mae: 1.5527 - mean_absolute_percentage_error: 20.5018 - mse: 4.3240 - val_loss: 4.0245 - val_mae: 1.4705 - val_mean_absolute_percentage_error: 19.4796 - val_mse: 3.9212
# Epoch 24/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 694us/step - loss: 4.3695 - mae: 1.5436 - mean_absolute_percentage_error: 20.4625 - mse: 4.2648 - val_loss: 4.1218 - val_mae: 1.5061 - val_mean_absolute_percentage_error: 20.0218 - val_mse: 4.0168
# Epoch 25/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 695us/step - loss: 4.4417 - mae: 1.5547 - mean_absolute_percentage_error: 20.5367 - mse: 4.3358 - val_loss: 4.0756 - val_mae: 1.5122 - val_mean_absolute_percentage_error: 20.7746 - val_mse: 3.9728
# Epoch 26/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 706us/step - loss: 4.4150 - mae: 1.5550 - mean_absolute_percentage_error: 20.6174 - mse: 4.3103 - val_loss: 4.0544 - val_mae: 1.4762 - val_mean_absolute_percentage_error: 19.3442 - val_mse: 3.9488
# Epoch 27/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 699us/step - loss: 4.3548 - mae: 1.5407 - mean_absolute_percentage_error: 20.3664 - mse: 4.2478 - val_loss: 4.2199 - val_mae: 1.5161 - val_mean_absolute_percentage_error: 19.7237 - val_mse: 4.1165
# Epoch 28/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 698us/step - loss: 4.4370 - mae: 1.5530 - mean_absolute_percentage_error: 20.5445 - mse: 4.3312 - val_loss: 4.0328 - val_mae: 1.4901 - val_mean_absolute_percentage_error: 20.2326 - val_mse: 3.9263
# Epoch 29/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 700us/step - loss: 4.4219 - mae: 1.5541 - mean_absolute_percentage_error: 20.6029 - mse: 4.3148 - val_loss: 4.1493 - val_mae: 1.5301 - val_mean_absolute_percentage_error: 21.2312 - val_mse: 4.0437
# Epoch 30/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 691us/step - loss: 4.3836 - mae: 1.5498 - mean_absolute_percentage_error: 20.4770 - mse: 4.2781 - val_loss: 4.1249 - val_mae: 1.5127 - val_mean_absolute_percentage_error: 20.1364 - val_mse: 4.0219
# Epoch 31/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 700us/step - loss: 4.3563 - mae: 1.5386 - mean_absolute_percentage_error: 20.3211 - mse: 4.2504 - val_loss: 4.1195 - val_mae: 1.4951 - val_mean_absolute_percentage_error: 19.7121 - val_mse: 4.0129
# Epoch 32/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 694us/step - loss: 4.3923 - mae: 1.5449 - mean_absolute_percentage_error: 20.4455 - mse: 4.2861 - val_loss: 4.1843 - val_mae: 1.5043 - val_mean_absolute_percentage_error: 19.5807 - val_mse: 4.0788
# Epoch 33/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 706us/step - loss: 4.3658 - mae: 1.5453 - mean_absolute_percentage_error: 20.4035 - mse: 4.2586 - val_loss: 4.0106 - val_mae: 1.4746 - val_mean_absolute_percentage_error: 19.7564 - val_mse: 3.9027
# Epoch 34/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 696us/step - loss: 4.4192 - mae: 1.5521 - mean_absolute_percentage_error: 20.4965 - mse: 4.3113 - val_loss: 4.0166 - val_mae: 1.4743 - val_mean_absolute_percentage_error: 19.6823 - val_mse: 3.9083
# Epoch 35/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 698us/step - loss: 4.3969 - mae: 1.5453 - mean_absolute_percentage_error: 20.4167 - mse: 4.2882 - val_loss: 4.0224 - val_mae: 1.4726 - val_mean_absolute_percentage_error: 19.5854 - val_mse: 3.9142
# Epoch 36/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 708us/step - loss: 4.3227 - mae: 1.5377 - mean_absolute_percentage_error: 20.2915 - mse: 4.2139 - val_loss: 4.0081 - val_mae: 1.4738 - val_mean_absolute_percentage_error: 19.7948 - val_mse: 3.8992
# Epoch 37/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 698us/step - loss: 4.3493 - mae: 1.5396 - mean_absolute_percentage_error: 20.3106 - mse: 4.2400 - val_loss: 4.6997 - val_mae: 1.6087 - val_mean_absolute_percentage_error: 22.0063 - val_mse: 4.5894
# Epoch 38/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 700us/step - loss: 4.3683 - mae: 1.5397 - mean_absolute_percentage_error: 20.3470 - mse: 4.2596 - val_loss: 4.1007 - val_mae: 1.4978 - val_mean_absolute_percentage_error: 19.8077 - val_mse: 3.9933
# Epoch 39/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 703us/step - loss: 4.3760 - mae: 1.5425 - mean_absolute_percentage_error: 20.3474 - mse: 4.2674 - val_loss: 4.0145 - val_mae: 1.4887 - val_mean_absolute_percentage_error: 20.1300 - val_mse: 3.9070
# Epoch 40/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 700us/step - loss: 4.3816 - mae: 1.5452 - mean_absolute_percentage_error: 20.3759 - mse: 4.2720 - val_loss: 4.0740 - val_mae: 1.5024 - val_mean_absolute_percentage_error: 20.2546 - val_mse: 3.9632
# Epoch 41/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 694us/step - loss: 4.4309 - mae: 1.5537 - mean_absolute_percentage_error: 20.5428 - mse: 4.3199 - val_loss: 4.0595 - val_mae: 1.5034 - val_mean_absolute_percentage_error: 20.3676 - val_mse: 3.9444
# Epoch 42/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 698us/step - loss: 4.4177 - mae: 1.5495 - mean_absolute_percentage_error: 20.4783 - mse: 4.3057 - val_loss: 4.0077 - val_mae: 1.4809 - val_mean_absolute_percentage_error: 19.9802 - val_mse: 3.8975
# Epoch 43/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 702us/step - loss: 4.4008 - mae: 1.5489 - mean_absolute_percentage_error: 20.4549 - mse: 4.2906 - val_loss: 4.1092 - val_mae: 1.4830 - val_mean_absolute_percentage_error: 19.1890 - val_mse: 3.9981
# Epoch 44/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 696us/step - loss: 4.3855 - mae: 1.5459 - mean_absolute_percentage_error: 20.3916 - mse: 4.2739 - val_loss: 4.1289 - val_mae: 1.5291 - val_mean_absolute_percentage_error: 21.2166 - val_mse: 4.0182
# Epoch 45/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 704us/step - loss: 4.3541 - mae: 1.5422 - mean_absolute_percentage_error: 20.3923 - mse: 4.2436 - val_loss: 4.1292 - val_mae: 1.4946 - val_mean_absolute_percentage_error: 19.6053 - val_mse: 4.0209
# Epoch 46/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 708us/step - loss: 4.3511 - mae: 1.5476 - mean_absolute_percentage_error: 20.4071 - mse: 4.2406 - val_loss: 4.2503 - val_mae: 1.5220 - val_mean_absolute_percentage_error: 19.7769 - val_mse: 4.1402
# Epoch 47/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 712us/step - loss: 4.3579 - mae: 1.5397 - mean_absolute_percentage_error: 20.3520 - mse: 4.2474 - val_loss: 4.0960 - val_mae: 1.4862 - val_mean_absolute_percentage_error: 19.3927 - val_mse: 3.9882
# Epoch 48/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 703us/step - loss: 4.3359 - mae: 1.5363 - mean_absolute_percentage_error: 20.2890 - mse: 4.2249 - val_loss: 4.1607 - val_mae: 1.4895 - val_mean_absolute_percentage_error: 19.2090 - val_mse: 4.0508
# Epoch 49/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 698us/step - loss: 4.3541 - mae: 1.5397 - mean_absolute_percentage_error: 20.3242 - mse: 4.2426 - val_loss: 4.0285 - val_mae: 1.4847 - val_mean_absolute_percentage_error: 19.8811 - val_mse: 3.9188
# Epoch 50/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 711us/step - loss: 4.3965 - mae: 1.5460 - mean_absolute_percentage_error: 20.4966 - mse: 4.2866 - val_loss: 4.1013 - val_mae: 1.5186 - val_mean_absolute_percentage_error: 21.0132 - val_mse: 3.9893
# Epoch 51/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 701us/step - loss: 4.3514 - mae: 1.5395 - mean_absolute_percentage_error: 20.4419 - mse: 4.2401 - val_loss: 4.0084 - val_mae: 1.4707 - val_mean_absolute_percentage_error: 19.7136 - val_mse: 3.8968
# Epoch 52/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 707us/step - loss: 4.3561 - mae: 1.5427 - mean_absolute_percentage_error: 20.3615 - mse: 4.2432 - val_loss: 4.0161 - val_mae: 1.4775 - val_mean_absolute_percentage_error: 19.8259 - val_mse: 3.9053
# Epoch 53/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 735us/step - loss: 4.3729 - mae: 1.5426 - mean_absolute_percentage_error: 20.3885 - mse: 4.2607 - val_loss: 4.0172 - val_mae: 1.4684 - val_mean_absolute_percentage_error: 19.4598 - val_mse: 3.9054
# Epoch 54/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 745us/step - loss: 4.2987 - mae: 1.5294 - mean_absolute_percentage_error: 20.2108 - mse: 4.1870 - val_loss: 4.1332 - val_mae: 1.4984 - val_mean_absolute_percentage_error: 19.7553 - val_mse: 4.0162
# Epoch 55/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 736us/step - loss: 4.3672 - mae: 1.5428 - mean_absolute_percentage_error: 20.4225 - mse: 4.2533 - val_loss: 4.1315 - val_mae: 1.5131 - val_mean_absolute_percentage_error: 20.7007 - val_mse: 4.0173
# Epoch 56/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 745us/step - loss: 4.3464 - mae: 1.5376 - mean_absolute_percentage_error: 20.3796 - mse: 4.2318 - val_loss: 4.0547 - val_mae: 1.4892 - val_mean_absolute_percentage_error: 20.1810 - val_mse: 3.9420
# Epoch 57/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 734us/step - loss: 4.3415 - mae: 1.5348 - mean_absolute_percentage_error: 20.2889 - mse: 4.2279 - val_loss: 4.0390 - val_mae: 1.4748 - val_mean_absolute_percentage_error: 19.4378 - val_mse: 3.9249
# Epoch 58/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 724us/step - loss: 4.3509 - mae: 1.5374 - mean_absolute_percentage_error: 20.2804 - mse: 4.2365 - val_loss: 4.0173 - val_mae: 1.4972 - val_mean_absolute_percentage_error: 20.5615 - val_mse: 3.9050
# Epoch 59/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 721us/step - loss: 4.3389 - mae: 1.5343 - mean_absolute_percentage_error: 20.2830 - mse: 4.2240 - val_loss: 4.0189 - val_mae: 1.4877 - val_mean_absolute_percentage_error: 20.2409 - val_mse: 3.9014
# Epoch 60/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 740us/step - loss: 4.3233 - mae: 1.5320 - mean_absolute_percentage_error: 20.2402 - mse: 4.2080 - val_loss: 4.0166 - val_mae: 1.4868 - val_mean_absolute_percentage_error: 20.3607 - val_mse: 3.9024
# Epoch 61/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 772us/step - loss: 4.3344 - mae: 1.5355 - mean_absolute_percentage_error: 20.2789 - mse: 4.2185 - val_loss: 4.0288 - val_mae: 1.4841 - val_mean_absolute_percentage_error: 19.8682 - val_mse: 3.9153
# Epoch 62/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 723us/step - loss: 4.3067 - mae: 1.5306 - mean_absolute_percentage_error: 20.2492 - mse: 4.1918 - val_loss: 4.0161 - val_mae: 1.4827 - val_mean_absolute_percentage_error: 19.8444 - val_mse: 3.8978

# %% [markdown]
# ### Analysing error metrics

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist['rmse'] = np.sqrt(hist['mse'])
hist['val_rmse'] = np.sqrt(hist['val_mse'])
hist.tail()
# Out:
#         loss       mae  mean_absolute_percentage_error       mse  val_loss  \
# 57  4.340024  1.537171                       20.323988  4.225806  4.017310
# 58  4.336960  1.533976                       20.262638  4.221745  4.018899
# 59  4.360562  1.538844                       20.326763  4.244974  4.016597
# 60  4.344462  1.538361                       20.322729  4.228534  4.028811
# 61  4.338585  1.534642                       20.276775  4.222898  4.016149
#
#      val_mae  val_mean_absolute_percentage_error   val_mse  epoch      rmse  \
# 57  1.497249                           20.561522  3.904954     57  2.055676
# 58  1.487725                           20.240910  3.901382     58  2.054689
# 59  1.486825                           20.360691  3.902421     59  2.060333
# 60  1.484128                           19.868181  3.915312     60  2.056340
# 61  1.482692                           19.844376  3.897831     61  2.054969
#
#     val_rmse
# 57  1.976096
# 58  1.975192
# 59  1.975455
# 60  1.978715
# 61  1.974293

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.title("Evolução das funções de perda durante o treinamento da rede")
plt.xlabel('Rodada')
plt.ylabel('Root Mean Square Error')
plt.plot(hist['epoch'], hist['rmse'], label='RMSE Treino')
plt.plot(hist['epoch'], hist['val_rmse'], label = 'RMSE Validação')
plt.legend()

plt.figure()
plt.xlabel('Rodada')
plt.ylabel('Mean Absolute Error')
plt.plot(hist['epoch'], hist['mae'], label='MAE Treino')
plt.plot(hist['epoch'], hist['val_mae'], label = 'MAE Validação')
plt.legend()

plt.show()

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# ### Preparing test dataframe

# %%
x_test = test
y_test = test.pop('bg+1:00')
print(x_test.shape)
x_test.head(5)
# Out:
# (44256, 30)
#     bg-0:00   bg-0:05  bg-0:10    bg-0:15   bg-0:20   bg-0:25    bg-0:30  \
# 2      13.9  8.246322  8.33178  14.400000  8.258647  8.430463  15.100000
# 10     11.9  8.246322  8.33178  11.400000  8.258647  8.430463  12.700000
# 21      5.8  8.246322  8.33178   6.600000  8.258647  8.430463   8.600000
# 27      7.8  7.100000  8.33178   7.366667  5.200000  8.430463   7.228571
# 30     12.3  7.933333  8.33178  11.066667  8.000000  8.430463  10.271429
#
#      bg-0:35   bg-0:40  bg-0:45  ...    hr-0:25    hr-0:30  steps-0:00  \
# 2   8.268978  8.412561  16.2000  ...  81.177985  81.189919   44.927039
# 10  8.268978  8.412561  14.8000  ...  81.177985  81.189919   44.927039
# 21  8.268978  8.412561  11.2000  ...  81.177985  81.189919   44.927039
# 27  4.800000  8.412561   7.1250  ...  81.177985  81.189919   44.927039
# 30  7.400000  8.412561   9.7125  ...  81.177985  81.189919   44.927039
#
#     steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  \
# 2    43.967174    43.96972   45.359472   8.130857   8.147582  2.984808
# 10   43.967174    43.96972   45.359472   8.130857   8.147582  2.766044
# 21   43.967174    43.96972   45.359472   8.130857   8.147582  2.152123
# 27   43.967174    43.96972   45.359472   8.130857   8.147582  1.741181
# 30   43.967174    43.96972   45.359472   8.130857   8.147582  1.557711
#
#     time_cos
# 2   1.826352
# 10  1.357212
# 21  1.011638
# 27  1.034074
# 30  1.103127
#
# [5 rows x 30 columns]

# %%
y_test.head(5)
# Out:
# 2     15.5
# 10    17.4
# 21     4.8
# 27    13.1
# 30     8.3
# Name: bg+1:00, dtype: float64

# %%
x_test.to_csv("x_t.csv", index=False)
y_test.to_csv("y_t.csv", index=False)

# %% [markdown]
# ### Running prediction

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# 1383/1383 ━━━━━━━━━━━━━━━━━━━━ 1s 435us/step
# [[11.951106 ]
#  [10.340038 ]
#  [ 6.0976496]
#  ...
#  [ 6.928029 ]
#  [ 9.13205  ]
#  [10.975103 ]]

# %% [markdown]
# ### Calculating error metrics

# %%
mse = tf.keras.losses.MSE(y_test, y_pred).numpy().mean()
mae = tf.keras.losses.MAE(y_test, y_pred).numpy().mean()
rmse = np.sqrt(mse)

# %%
print(f"RMSE Test: {rmse}")
print(f"MSE Test: {mse}")
print(f"MAE Test: {mae}")
# Out:
# RMSE Test: 1.9677470922470093
# MSE Test: 3.8720285892486572
# MAE Test: 1.4699809551239014

# %% [markdown]
# ## Saving the model

# %%
model.save("brist1d.keras")

# %% [markdown]
# ## Loading and processing submission dataframe

# %%
df_submission = pd.read_csv('dataset/test.csv', header=0)
print(df_submission.shape)
df_submission.head(5)
# Out:
# (3644, 507)
#          id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_8459   p01  06:45:00      NaN      9.2      NaN      NaN     10.2
# 1  p01_8460   p01  11:25:00      NaN      NaN      9.9      NaN      NaN
# 2  p01_8461   p01  14:45:00      NaN      5.5      NaN      NaN      5.5
# 3  p01_8462   p01  04:30:00      NaN      3.4      NaN      NaN      3.9
# 4  p01_8463   p01  04:20:00      NaN      NaN      8.3      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:45  activity-0:40  activity-0:35  \
# 0      NaN      NaN  ...            NaN            NaN            NaN
# 1      9.4      NaN  ...            NaN            NaN            NaN
# 2      NaN      NaN  ...            NaN            NaN            NaN
# 3      NaN      NaN  ...            NaN            NaN            NaN
# 4     10.0      NaN  ...            NaN            NaN            NaN
#
#    activity-0:30  activity-0:25  activity-0:20  activity-0:15  activity-0:10  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN           Walk
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    activity-0:05  activity-0:00
# 0            NaN            NaN
# 1           Walk           Walk
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
# [5 rows x 507 columns]

# %%
df_submission = filter_desired_columns(df_submission, False)
df_submission.head(5)
# Out:
#          id p_num      time  bg-0:00  bg-0:05  bg-0:10  bg-0:15  bg-0:20  \
# 0  p01_8459   p01  06:45:00      9.6      NaN      NaN      9.4      NaN
# 1  p01_8460   p01  11:25:00      4.6      NaN      NaN      6.3      NaN
# 2  p01_8461   p01  14:45:00      8.0      NaN      NaN      8.3      NaN
# 3  p01_8462   p01  04:30:00      9.9      NaN      NaN      8.5      NaN
# 4  p01_8463   p01  04:20:00      5.3      NaN      NaN      3.7      NaN
#
#    bg-0:25  bg-0:30  ...  hr-0:15  hr-0:20  hr-0:25  hr-0:30  steps-0:00  \
# 0      NaN      NaN  ...     55.6     53.2     54.4     55.8         NaN
# 1      NaN      6.4  ...     95.6     91.6     93.5     91.1       532.0
# 2      NaN      8.1  ...     75.7     81.1     87.9     92.1        69.0
# 3      NaN      7.8  ...     59.5     58.5     61.2     60.7         0.0
# 4      NaN      3.2  ...     58.9     57.6     55.1     56.2         NaN
#
#    steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05
# 0         NaN         NaN         0.0       6.06       4.90
# 1       377.0       547.0       411.0      32.43      24.57
# 2       283.0        27.0        10.0      10.16      19.76
# 3         NaN         NaN        14.0       4.80       4.90
# 4         NaN         NaN         NaN       4.80       4.80
#
# [5 rows x 31 columns]

# %%
df_submission[columns_to_fill] = df_submission[columns_to_fill].interpolate()
df_submission[columns_to_fill] = imputer.transform(df_submission[columns_to_fill])

# %%
df_submission['minutes_since_start'] = pd.to_datetime(df_submission['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(df_submission['time'], format="%H:%M:%S").dt.minute
df_submission = df_submission.drop(columns=['time'])
df_submission["time_sin"] = np.sin(2 * np.pi / 1440 * df_submission['minutes_since_start']) + 2
df_submission["time_cos"] = np.cos(2 * np.pi / 1440 * df_submission['minutes_since_start']) + 2
df_submission = df_submission.drop(columns=['minutes_since_start'])
df_submission.head(5)
# Out:
#          id p_num  bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  \
# 0  p01_8459   p01      9.6  8.246322  8.33178      9.4  8.258647  8.430463
# 1  p01_8460   p01      4.6  8.246322  8.33178      6.3  8.258647  8.430463
# 2  p01_8461   p01      8.0  8.246322  8.33178      8.3  8.258647  8.430463
# 3  p01_8462   p01      9.9  8.246322  8.33178      8.5  8.258647  8.430463
# 4  p01_8463   p01      5.3  8.246322  8.33178      3.7  8.258647  8.430463
#
#     bg-0:30  bg-0:35  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.282302     10.5  ...     54.4     55.8   44.927039   43.967174
# 1  6.400000     10.2  ...     93.5     91.1  532.000000  377.000000
# 2  8.100000      9.9  ...     87.9     92.1   69.000000  283.000000
# 3  7.800000      9.6  ...     61.2     60.7    0.000000  205.333333
# 4  3.200000      9.3  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 32 columns]

# %%
identifiers_submission = df_submission[cols_to_pop].copy()
df_submission = df_submission.drop(columns=cols_to_pop)
df_submission.head(5)
# Out:
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25   bg-0:30  bg-0:35  \
# 0      9.6  8.246322  8.33178      9.4  8.258647  8.430463  8.282302     10.5
# 1      4.6  8.246322  8.33178      6.3  8.258647  8.430463  6.400000     10.2
# 2      8.0  8.246322  8.33178      8.3  8.258647  8.430463  8.100000      9.9
# 3      9.9  8.246322  8.33178      8.5  8.258647  8.430463  7.800000      9.6
# 4      5.3  8.246322  8.33178      3.7  8.258647  8.430463  3.200000      9.3
#
#     bg-0:40   bg-0:45  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.412561  8.283803  ...     54.4     55.8   44.927039   43.967174
# 1  8.412561  4.500000  ...     93.5     91.1  532.000000  377.000000
# 2  8.412561  6.600000  ...     87.9     92.1   69.000000  283.000000
# 3  8.412561  7.500000  ...     61.2     60.7    0.000000  205.333333
# 4  8.412561  3.400000  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 30 columns]

# %%
print(df_submission.shape)
df_submission.head(5)
# Out:
# (3644, 30)
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25   bg-0:30  bg-0:35  \
# 0      9.6  8.246322  8.33178      9.4  8.258647  8.430463  8.282302     10.5
# 1      4.6  8.246322  8.33178      6.3  8.258647  8.430463  6.400000     10.2
# 2      8.0  8.246322  8.33178      8.3  8.258647  8.430463  8.100000      9.9
# 3      9.9  8.246322  8.33178      8.5  8.258647  8.430463  7.800000      9.6
# 4      5.3  8.246322  8.33178      3.7  8.258647  8.430463  3.200000      9.3
#
#     bg-0:40   bg-0:45  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.412561  8.283803  ...     54.4     55.8   44.927039   43.967174
# 1  8.412561  4.500000  ...     93.5     91.1  532.000000  377.000000
# 2  8.412561  6.600000  ...     87.9     92.1   69.000000  283.000000
# 3  8.412561  7.500000  ...     61.2     60.7    0.000000  205.333333
# 4  8.412561  3.400000  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Predicting submission dataset

# %%
# model = tf.keras.models.load_model("brist1d.keras")

# %%
y_submission = model.predict(df_submission)
df_pred_submission = pd.DataFrame(y_submission, columns=['bg+1:00'])
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %% [markdown]
# ### Joining identifiers

# %%
df_pred_submission = pd.concat([identifiers_submission, df_pred_submission], axis=1)
df_pred_submission.pop('p_num')
df_pred_submission.head(5)
# Out:
#          id    bg+1:00
# 0  p01_8459   9.315093
# 1  p01_8460   5.163402
# 2  p01_8461   7.043850
# 3  p01_8462  10.359314
# 4  p01_8463   7.163373

# %% [markdown]
# ### Exporting submission results

# %%
df_pred_submission.to_csv("dataset/predictions.csv", index=False)
