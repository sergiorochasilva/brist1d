# %% [markdown]
# # Brist1D - Kaggle competition

# %% [markdown]
# ## Loading and hadling dataset

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('dataset/train.csv', header=0)
print(df.shape)
df.head(5)
# Out:
# /tmp/ipykernel_64839/722352279.py:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset/train.csv', header=0)
# (177024, 508)
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:40  activity-0:35  activity-0:30  \
# 0      9.7      NaN  ...            NaN            NaN            NaN
# 1      9.2      NaN  ...            NaN            NaN            NaN
# 2      8.7      NaN  ...            NaN            NaN            NaN
# 3      8.4      NaN  ...            NaN            NaN            NaN
# 4      8.1      NaN  ...            NaN            NaN            NaN
#
#    activity-0:25  activity-0:20  activity-0:15  activity-0:10  activity-0:05  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    activity-0:00  bg+1:00
# 0            NaN     13.4
# 1            NaN     12.8
# 2            NaN     15.5
# 3            NaN     14.8
# 4            NaN     12.7
#
# [5 rows x 508 columns]

# %% [markdown]
# ## Filtering desired collumns (based on a correlation analises)

# %%
def filter_desired_columns(data, include_target: bool = True):
    desired_columns = [
        "id", "p_num", "time",
        "bg-0:00", "bg-0:05", "bg-0:10", "bg-0:15", "bg-0:20", "bg-0:25", "bg-0:30", "bg-0:35", "bg-0:40", "bg-0:45",
        "insulin-0:00", "insulin-0:05", "insulin-0:10", "insulin-0:15", "insulin-0:20",
        "hr-0:00", "hr-0:05", "hr-0:10", "hr-0:15", "hr-0:20", "hr-0:25", "hr-0:30",
        "steps-0:00", "steps-0:05", "steps-0:10", "steps-0:15",
        "cals-0:00", "cals-0:05",
    ]

    if include_target:
        desired_columns.append("bg+1:00")
        
    return data[desired_columns]

df = filter_desired_columns(df)
df.head(5)
# Out:
#       id p_num      time  bg-0:00  bg-0:05  bg-0:10  bg-0:15  bg-0:20  \
# 0  p01_0   p01  06:10:00     15.1      NaN      NaN     16.2      NaN
# 1  p01_1   p01  06:25:00     14.4      NaN      NaN     15.1      NaN
# 2  p01_2   p01  06:40:00     13.9      NaN      NaN     14.4      NaN
# 3  p01_3   p01  06:55:00     13.8      NaN      NaN     13.9      NaN
# 4  p01_4   p01  07:10:00     13.4      NaN      NaN     13.8      NaN
#
#    bg-0:25  bg-0:30  ...  hr-0:20  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0      NaN     17.3  ...      NaN      NaN      NaN         NaN         NaN
# 1      NaN     16.2  ...      NaN      NaN      NaN         NaN         NaN
# 2      NaN     15.1  ...      NaN      NaN      NaN         NaN         NaN
# 3      NaN     14.4  ...      NaN      NaN      NaN         NaN         NaN
# 4      NaN     13.9  ...      NaN      NaN      NaN         NaN         NaN
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  bg+1:00
# 0         NaN         NaN        NaN        NaN     13.4
# 1         NaN         NaN        NaN        NaN     12.8
# 2         NaN         NaN        NaN        NaN     15.5
# 3         NaN         NaN        NaN        NaN     14.8
# 4         NaN         NaN        NaN        NaN     12.7
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Filling missing values

# %%
columns_to_fill = [
    "bg-0:00", "bg-0:05", "bg-0:10", "bg-0:15", "bg-0:20", "bg-0:25", "bg-0:30", "bg-0:35", "bg-0:40", "bg-0:45",
    "insulin-0:00", "insulin-0:05", "insulin-0:10", "insulin-0:15", "insulin-0:20",
    "hr-0:00", "hr-0:05", "hr-0:10", "hr-0:15", "hr-0:20", "hr-0:25", "hr-0:30",
    "steps-0:00", "steps-0:05", "steps-0:10", "steps-0:15",
    "cals-0:00", "cals-0:05",
]

df[columns_to_fill] = df[columns_to_fill].interpolate()

# %%
imputer = SimpleImputer()

df[columns_to_fill] = imputer.fit_transform(df[columns_to_fill])

# %% [markdown]
# ## Converting time into sin and cos pair

# %% [markdown]
# ### Converting time to minutes

# %%
df['minutes_since_start'] = pd.to_datetime(df['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(df['time'], format="%H:%M:%S").dt.minute
df = df.drop(columns=['time'])

# %% [markdown]
# ### Converting minutes to sin and cos pair (summing constant 2, to avoid zero values)

# %%
df["time_sin"] = np.sin(2 * np.pi / 1440 * df['minutes_since_start']) + 2
df["time_cos"] = np.cos(2 * np.pi / 1440 * df['minutes_since_start']) + 2
df = df.drop(columns=['minutes_since_start'])
df.head(5)
# Out:
#       id p_num  bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  \
# 0  p01_0   p01     15.1  8.246322  8.33178     16.2  8.258647  8.430463
# 1  p01_1   p01     14.4  8.246322  8.33178     15.1  8.258647  8.430463
# 2  p01_2   p01     13.9  8.246322  8.33178     14.4  8.258647  8.430463
# 3  p01_3   p01     13.8  8.246322  8.33178     13.9  8.258647  8.430463
# 4  p01_4   p01     13.4  8.246322  8.33178     13.8  8.258647  8.430463
#
#    bg-0:30   bg-0:35  ...    hr-0:30  steps-0:00  steps-0:05  steps-0:10  \
# 0     17.3  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 1     16.2  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 2     15.1  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 3     14.4  8.268978  ...  81.189919   44.927039   43.967174    43.96972
# 4     13.9  8.268978  ...  81.189919   44.927039   43.967174    43.96972
#
#    steps-0:15  cals-0:00  cals-0:05  bg+1:00  time_sin  time_cos
# 0   45.359472   8.130857   8.147582     13.4  2.999048  1.956381
# 1   45.359472   8.130857   8.147582     12.8  2.994056  1.891133
# 2   45.359472   8.130857   8.147582     15.5  2.984808  1.826352
# 3   45.359472   8.130857   8.147582     14.8  2.971342  1.762314
# 4   45.359472   8.130857   8.147582     12.7  2.953717  1.699294
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Removing ID columns

# %%
cols_to_pop = ['id', 'p_num']
identifiers = df[cols_to_pop].copy()
df = df.drop(columns=cols_to_pop)
df.head(5)
# Out:
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  bg-0:30   bg-0:35  \
# 0     15.1  8.246322  8.33178     16.2  8.258647  8.430463     17.3  8.268978
# 1     14.4  8.246322  8.33178     15.1  8.258647  8.430463     16.2  8.268978
# 2     13.9  8.246322  8.33178     14.4  8.258647  8.430463     15.1  8.268978
# 3     13.8  8.246322  8.33178     13.9  8.258647  8.430463     14.4  8.268978
# 4     13.4  8.246322  8.33178     13.8  8.258647  8.430463     13.9  8.268978
#
#     bg-0:40  bg-0:45  ...    hr-0:30  steps-0:00  steps-0:05  steps-0:10  \
# 0  8.412561     17.5  ...  81.189919   44.927039   43.967174    43.96972
# 1  8.412561     17.3  ...  81.189919   44.927039   43.967174    43.96972
# 2  8.412561     16.2  ...  81.189919   44.927039   43.967174    43.96972
# 3  8.412561     15.1  ...  81.189919   44.927039   43.967174    43.96972
# 4  8.412561     14.4  ...  81.189919   44.927039   43.967174    43.96972
#
#    steps-0:15  cals-0:00  cals-0:05  bg+1:00  time_sin  time_cos
# 0   45.359472   8.130857   8.147582     13.4  2.999048  1.956381
# 1   45.359472   8.130857   8.147582     12.8  2.994056  1.891133
# 2   45.359472   8.130857   8.147582     15.5  2.984808  1.826352
# 3   45.359472   8.130857   8.147582     14.8  2.971342  1.762314
# 4   45.359472   8.130857   8.147582     12.7  2.953717  1.699294
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Spliting train and test dataframes

# %%
train = df.sample(frac=0.75, random_state=0)
test = df.drop(train.index)

# %%
x_train = train
y_train = train.pop('bg+1:00')

# %%
print(x_train.shape)
x_train.head(5)
# Out:
# (132768, 30)
#        bg-0:00    bg-0:05    bg-0:10  bg-0:15    bg-0:20    bg-0:25  bg-0:30  \
# 91143      5.9   5.807317   8.354752      6.2   6.854918  11.098182      4.6
# 35758      8.2   8.200000   8.300000      8.5   8.700000   8.900000      8.5
# 65296      6.8   7.200000   7.900000      8.4   8.700000   8.700000      8.4
# 14652     10.5  10.600000  10.700000     10.8  10.900000  10.900000     11.0
# 54561      6.3   6.300000   6.300000      6.3   6.300000   6.300000      6.2
#
#          bg-0:35    bg-0:40  bg-0:45  ...    hr-0:25    hr-0:30  steps-0:00  \
# 91143   6.721488  11.227333      3.8  ...  86.000000  84.600000  518.000000
# 35758   8.400000   8.500000      8.8  ...  76.143817  76.139606   23.021904
# 65296   8.100000   7.900000      6.5  ...  86.300000  83.500000    8.000000
# 14652  11.200000  11.400000     11.4  ...  81.250505  81.045791   27.270000
# 54561   6.200000   6.200000      6.1  ...  53.000000  52.800000    0.000000
#
#        steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  \
# 91143  573.000000  440.000000    12.00000   8.350000   5.410000  1.357212
# 35758   23.077783   23.133661    23.18954   5.600000   5.600000  2.965926
# 65296   11.000000   14.000000    72.00000   7.090000   8.630000  1.123273
# 14652   27.193333   27.116667    27.04000   1.819452   1.817945  2.422618
# 54561    0.000000    0.000000     0.00000   5.720000   5.600000  2.939693
#
#        time_cos
# 91143  2.766044
# 35758  2.258819
# 65296  1.519011
# 14652  2.906308
# 54561  1.657980
#
# [5 rows x 30 columns]

# %%
print(y_train.shape)
y_train.head(5)
# Out:
# (132768,)
# 91143    7.6
# 35758    7.6
# 65296    6.2
# 14652    9.0
# 54561    5.7
# Name: bg+1:00, dtype: float64

# %% [markdown]
# ## Building model

# %% [markdown]
# ### Imports and GPU config

# %%
from keras.layers import TimeDistributed, Dense, Input, Lambda, BatchNormalization, Concatenate, Conv1D, ZeroPadding1D
from keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.callbacks import EarlyStopping
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Configurando para não alocar diretamente toda a memória da GPU (alocar conforme necessário)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)  # Aloca memória conforme necessário
    except RuntimeError as e:
        print(e)
# Out:
# 2024-11-19 19:17:52.090643: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-19 19:17:52.220975: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732054672.274154   64839 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732054672.288831   64839 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-19 19:17:52.411856: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available:  1

# %% [markdown]
# ### Model definition

# %%
def extrator_features(input_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims*4), activation=activation, use_bias=bias, kernel_regularizer="l2")(input_layer)
  x_1 = tf.keras.layers.Dropout(0.2)(x_0)
  x_2 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_1)
  x_3 = Dense(int(input_dims*8), activation=activation, use_bias=bias)(x_2)
  x_4 = Dense(int(input_dims*4), activation=activation, use_bias=bias)(x_3)
  x_bottleneck = Dense(int(input_dims), activation=activation, name='encoder', use_bias=True, kernel_regularizer="l1")(x_4)

  return Model(input_layer, x_bottleneck, name="features")

def regressor(input_dims, output_dims, activation, bias):
  input_layer = Input(shape=[input_dims])

  x_0 = Dense(int(input_dims/2), activation=activation, use_bias=bias)(input_layer)
  x_2 = Dense(int(input_dims/4), activation=activation, use_bias=bias)(x_0)
  saidas = Dense(output_dims, activation=None, name='regressor_saidas', use_bias=bias)(x_2)

  return Model(input_layer, saidas, name="regressor")

def build_models(input_dims, output_dims, activation, bias):
  # Camadas de entrada
  input_layer = Input(shape=[input_dims])

  x_n = BatchNormalization()(input_layer)

  # Kernels
  extrator = extrator_features(input_dims, activation, bias)

  # Features
  features = extrator(x_n)

  # Regressão
  regressao = regressor(features.shape[1], output_dims, activation, bias)

  saida = regressao(features)
  
  return (
      Model(input_layer, saida, name="regressao"),
      Model(input_layer, features, name="projecao")
  )

model, features = build_models(x_train.shape[1], 1, 'relu', False)
model.compile(optimizer='adam', loss='mse', metrics=['mae', 'mse', 'mean_absolute_percentage_error'])
plot_model(model, show_shapes=True, expand_nested=True)

# %% [markdown]
# ### Training model

# %%
# Callback para recuperar o melhor peso, e parar quando ficar três épocas sem melhora
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Treinando o modelo
history = model.fit(x_train, y_train, epochs=200, validation_split = 0.2, callbacks=[callback])
# Out:
# Epoch 1/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 9.2678 - mae: 2.0745 - mean_absolute_percentage_error: 26.7408 - mse: 7.9107 - val_loss: 4.7122 - val_mae: 1.5371 - val_mean_absolute_percentage_error: 19.9159 - val_mse: 4.2765
# Epoch 2/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 735us/step - loss: 5.1413 - mae: 1.6397 - mean_absolute_percentage_error: 21.5944 - mse: 4.7783 - val_loss: 4.3506 - val_mae: 1.5511 - val_mean_absolute_percentage_error: 21.5539 - val_mse: 4.1389
# Epoch 3/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 759us/step - loss: 4.7541 - mae: 1.5986 - mean_absolute_percentage_error: 21.1785 - mse: 4.5623 - val_loss: 4.1699 - val_mae: 1.4989 - val_mean_absolute_percentage_error: 20.0136 - val_mse: 4.0273
# Epoch 4/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 777us/step - loss: 4.5890 - mae: 1.5793 - mean_absolute_percentage_error: 20.9137 - mse: 4.4518 - val_loss: 4.1516 - val_mae: 1.5047 - val_mean_absolute_percentage_error: 20.2941 - val_mse: 4.0285
# Epoch 5/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 721us/step - loss: 4.5535 - mae: 1.5737 - mean_absolute_percentage_error: 20.8649 - mse: 4.4339 - val_loss: 4.1817 - val_mae: 1.5033 - val_mean_absolute_percentage_error: 19.6787 - val_mse: 4.0698
# Epoch 6/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 737us/step - loss: 4.4979 - mae: 1.5664 - mean_absolute_percentage_error: 20.6790 - mse: 4.3842 - val_loss: 4.2879 - val_mae: 1.4958 - val_mean_absolute_percentage_error: 18.7730 - val_mse: 4.1774
# Epoch 7/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 731us/step - loss: 4.5372 - mae: 1.5749 - mean_absolute_percentage_error: 20.7889 - mse: 4.4270 - val_loss: 4.1859 - val_mae: 1.5302 - val_mean_absolute_percentage_error: 21.1850 - val_mse: 4.0769
# Epoch 8/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 724us/step - loss: 4.5367 - mae: 1.5789 - mean_absolute_percentage_error: 20.8120 - mse: 4.4270 - val_loss: 4.0910 - val_mae: 1.5021 - val_mean_absolute_percentage_error: 20.2546 - val_mse: 3.9811
# Epoch 9/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 729us/step - loss: 4.4877 - mae: 1.5696 - mean_absolute_percentage_error: 20.7866 - mse: 4.3798 - val_loss: 4.0697 - val_mae: 1.4874 - val_mean_absolute_percentage_error: 19.8592 - val_mse: 3.9639
# Epoch 10/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 723us/step - loss: 4.5136 - mae: 1.5698 - mean_absolute_percentage_error: 20.7271 - mse: 4.4072 - val_loss: 4.2107 - val_mae: 1.5247 - val_mean_absolute_percentage_error: 20.9238 - val_mse: 4.1025
# Epoch 11/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 724us/step - loss: 4.4476 - mae: 1.5577 - mean_absolute_percentage_error: 20.5838 - mse: 4.3413 - val_loss: 4.2244 - val_mae: 1.5064 - val_mean_absolute_percentage_error: 19.5173 - val_mse: 4.1191
# Epoch 12/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 719us/step - loss: 4.5128 - mae: 1.5663 - mean_absolute_percentage_error: 20.6328 - mse: 4.4057 - val_loss: 4.1280 - val_mae: 1.4821 - val_mean_absolute_percentage_error: 19.1810 - val_mse: 4.0234
# Epoch 13/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 721us/step - loss: 4.4575 - mae: 1.5598 - mean_absolute_percentage_error: 20.6717 - mse: 4.3535 - val_loss: 4.0871 - val_mae: 1.4894 - val_mean_absolute_percentage_error: 20.0277 - val_mse: 3.9816
# Epoch 14/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 758us/step - loss: 4.4554 - mae: 1.5604 - mean_absolute_percentage_error: 20.6110 - mse: 4.3498 - val_loss: 4.0971 - val_mae: 1.4730 - val_mean_absolute_percentage_error: 19.0556 - val_mse: 3.9920
# Epoch 15/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 737us/step - loss: 4.4845 - mae: 1.5663 - mean_absolute_percentage_error: 20.6951 - mse: 4.3784 - val_loss: 4.0797 - val_mae: 1.4818 - val_mean_absolute_percentage_error: 19.5327 - val_mse: 3.9757
# Epoch 16/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 751us/step - loss: 4.4155 - mae: 1.5527 - mean_absolute_percentage_error: 20.5446 - mse: 4.3101 - val_loss: 4.0432 - val_mae: 1.4816 - val_mean_absolute_percentage_error: 19.8042 - val_mse: 3.9372
# Epoch 17/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 735us/step - loss: 4.3976 - mae: 1.5488 - mean_absolute_percentage_error: 20.4570 - mse: 4.2905 - val_loss: 4.0470 - val_mae: 1.4748 - val_mean_absolute_percentage_error: 19.5005 - val_mse: 3.9410
# Epoch 18/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 728us/step - loss: 4.4758 - mae: 1.5646 - mean_absolute_percentage_error: 20.7179 - mse: 4.3687 - val_loss: 4.1146 - val_mae: 1.5218 - val_mean_absolute_percentage_error: 20.8889 - val_mse: 4.0097
# Epoch 19/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 722us/step - loss: 4.4707 - mae: 1.5633 - mean_absolute_percentage_error: 20.7330 - mse: 4.3634 - val_loss: 4.0698 - val_mae: 1.4823 - val_mean_absolute_percentage_error: 19.5690 - val_mse: 3.9636
# Epoch 20/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 751us/step - loss: 4.4339 - mae: 1.5559 - mean_absolute_percentage_error: 20.6015 - mse: 4.3264 - val_loss: 4.0916 - val_mae: 1.4790 - val_mean_absolute_percentage_error: 19.5910 - val_mse: 3.9819
# Epoch 21/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 744us/step - loss: 4.4532 - mae: 1.5594 - mean_absolute_percentage_error: 20.5651 - mse: 4.3442 - val_loss: 4.0734 - val_mae: 1.4757 - val_mean_absolute_percentage_error: 19.2745 - val_mse: 3.9639
# Epoch 22/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 754us/step - loss: 4.4264 - mae: 1.5562 - mean_absolute_percentage_error: 20.5658 - mse: 4.3160 - val_loss: 4.0751 - val_mae: 1.4936 - val_mean_absolute_percentage_error: 20.2775 - val_mse: 3.9634
# Epoch 23/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 774us/step - loss: 4.4505 - mae: 1.5566 - mean_absolute_percentage_error: 20.5859 - mse: 4.3383 - val_loss: 4.0796 - val_mae: 1.4869 - val_mean_absolute_percentage_error: 20.1096 - val_mse: 3.9700
# Epoch 24/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 754us/step - loss: 4.4211 - mae: 1.5548 - mean_absolute_percentage_error: 20.5555 - mse: 4.3100 - val_loss: 4.0938 - val_mae: 1.5056 - val_mean_absolute_percentage_error: 20.5814 - val_mse: 3.9831
# Epoch 25/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 760us/step - loss: 4.4628 - mae: 1.5640 - mean_absolute_percentage_error: 20.6265 - mse: 4.3526 - val_loss: 4.0297 - val_mae: 1.4787 - val_mean_absolute_percentage_error: 19.7763 - val_mse: 3.9191
# Epoch 26/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 748us/step - loss: 4.4269 - mae: 1.5502 - mean_absolute_percentage_error: 20.5015 - mse: 4.3153 - val_loss: 4.0611 - val_mae: 1.4940 - val_mean_absolute_percentage_error: 20.2386 - val_mse: 3.9511
# Epoch 27/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 731us/step - loss: 4.4048 - mae: 1.5528 - mean_absolute_percentage_error: 20.5744 - mse: 4.2941 - val_loss: 4.1416 - val_mae: 1.4826 - val_mean_absolute_percentage_error: 19.0527 - val_mse: 4.0273
# Epoch 28/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 853us/step - loss: 4.4271 - mae: 1.5553 - mean_absolute_percentage_error: 20.5594 - mse: 4.3155 - val_loss: 4.0767 - val_mae: 1.4995 - val_mean_absolute_percentage_error: 20.3850 - val_mse: 3.9649
# Epoch 29/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 725us/step - loss: 4.4332 - mae: 1.5537 - mean_absolute_percentage_error: 20.5096 - mse: 4.3205 - val_loss: 4.0497 - val_mae: 1.4755 - val_mean_absolute_percentage_error: 19.7867 - val_mse: 3.9361
# Epoch 30/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 708us/step - loss: 4.3562 - mae: 1.5377 - mean_absolute_percentage_error: 20.3489 - mse: 4.2426 - val_loss: 4.0297 - val_mae: 1.4671 - val_mean_absolute_percentage_error: 19.3202 - val_mse: 3.9178
# Epoch 31/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 741us/step - loss: 4.4170 - mae: 1.5514 - mean_absolute_percentage_error: 20.5225 - mse: 4.3017 - val_loss: 4.0007 - val_mae: 1.4649 - val_mean_absolute_percentage_error: 19.4697 - val_mse: 3.8867
# Epoch 32/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 734us/step - loss: 4.3796 - mae: 1.5444 - mean_absolute_percentage_error: 20.4570 - mse: 4.2661 - val_loss: 4.0218 - val_mae: 1.4809 - val_mean_absolute_percentage_error: 19.9234 - val_mse: 3.9079
# Epoch 33/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 727us/step - loss: 4.3897 - mae: 1.5432 - mean_absolute_percentage_error: 20.4321 - mse: 4.2759 - val_loss: 4.0184 - val_mae: 1.4712 - val_mean_absolute_percentage_error: 19.5362 - val_mse: 3.9071
# Epoch 34/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 749us/step - loss: 4.3659 - mae: 1.5396 - mean_absolute_percentage_error: 20.3281 - mse: 4.2520 - val_loss: 4.1033 - val_mae: 1.5210 - val_mean_absolute_percentage_error: 21.0997 - val_mse: 3.9935
# Epoch 35/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 727us/step - loss: 4.4214 - mae: 1.5522 - mean_absolute_percentage_error: 20.5596 - mse: 4.3079 - val_loss: 4.0613 - val_mae: 1.4792 - val_mean_absolute_percentage_error: 19.7568 - val_mse: 3.9484
# Epoch 36/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 725us/step - loss: 4.4288 - mae: 1.5545 - mean_absolute_percentage_error: 20.5446 - mse: 4.3141 - val_loss: 4.0702 - val_mae: 1.4825 - val_mean_absolute_percentage_error: 19.7261 - val_mse: 3.9579
# Epoch 37/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 718us/step - loss: 4.3972 - mae: 1.5499 - mean_absolute_percentage_error: 20.4628 - mse: 4.2846 - val_loss: 4.1368 - val_mae: 1.4830 - val_mean_absolute_percentage_error: 19.1594 - val_mse: 4.0233
# Epoch 38/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 747us/step - loss: 4.4383 - mae: 1.5513 - mean_absolute_percentage_error: 20.4360 - mse: 4.3229 - val_loss: 3.9953 - val_mae: 1.4609 - val_mean_absolute_percentage_error: 19.3802 - val_mse: 3.8833
# Epoch 39/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 743us/step - loss: 4.3854 - mae: 1.5439 - mean_absolute_percentage_error: 20.3736 - mse: 4.2722 - val_loss: 4.1188 - val_mae: 1.4804 - val_mean_absolute_percentage_error: 19.2424 - val_mse: 4.0000
# Epoch 40/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 748us/step - loss: 4.3737 - mae: 1.5433 - mean_absolute_percentage_error: 20.3352 - mse: 4.2593 - val_loss: 4.0402 - val_mae: 1.4933 - val_mean_absolute_percentage_error: 20.4457 - val_mse: 3.9178
# Epoch 41/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 764us/step - loss: 4.3730 - mae: 1.5392 - mean_absolute_percentage_error: 20.3535 - mse: 4.2560 - val_loss: 4.0732 - val_mae: 1.4687 - val_mean_absolute_percentage_error: 19.0908 - val_mse: 3.9591
# Epoch 42/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 786us/step - loss: 4.3722 - mae: 1.5419 - mean_absolute_percentage_error: 20.3559 - mse: 4.2566 - val_loss: 4.2264 - val_mae: 1.5095 - val_mean_absolute_percentage_error: 19.4914 - val_mse: 4.1121
# Epoch 43/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 747us/step - loss: 4.4021 - mae: 1.5458 - mean_absolute_percentage_error: 20.4179 - mse: 4.2845 - val_loss: 4.0916 - val_mae: 1.4884 - val_mean_absolute_percentage_error: 20.0720 - val_mse: 3.9757
# Epoch 44/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 750us/step - loss: 4.4027 - mae: 1.5459 - mean_absolute_percentage_error: 20.4322 - mse: 4.2872 - val_loss: 4.0799 - val_mae: 1.4718 - val_mean_absolute_percentage_error: 19.1875 - val_mse: 3.9655
# Epoch 45/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 756us/step - loss: 4.3518 - mae: 1.5382 - mean_absolute_percentage_error: 20.2731 - mse: 4.2362 - val_loss: 4.2092 - val_mae: 1.4950 - val_mean_absolute_percentage_error: 19.0436 - val_mse: 4.0972
# Epoch 46/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 778us/step - loss: 4.3725 - mae: 1.5446 - mean_absolute_percentage_error: 20.3585 - mse: 4.2586 - val_loss: 4.1630 - val_mae: 1.5178 - val_mean_absolute_percentage_error: 20.8591 - val_mse: 4.0499
# Epoch 47/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 750us/step - loss: 4.4108 - mae: 1.5502 - mean_absolute_percentage_error: 20.4657 - mse: 4.2960 - val_loss: 4.1161 - val_mae: 1.4967 - val_mean_absolute_percentage_error: 20.3461 - val_mse: 4.0009
# Epoch 48/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 2s 740us/step - loss: 4.4145 - mae: 1.5543 - mean_absolute_percentage_error: 20.5825 - mse: 4.3004 - val_loss: 4.0012 - val_mae: 1.4759 - val_mean_absolute_percentage_error: 19.8792 - val_mse: 3.8843
# Epoch 49/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 762us/step - loss: 4.4435 - mae: 1.5535 - mean_absolute_percentage_error: 20.4159 - mse: 4.3253 - val_loss: 4.0809 - val_mae: 1.5015 - val_mean_absolute_percentage_error: 20.5843 - val_mse: 3.9635
# Epoch 50/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 777us/step - loss: 4.3140 - mae: 1.5281 - mean_absolute_percentage_error: 20.2293 - mse: 4.1980 - val_loss: 4.1010 - val_mae: 1.5159 - val_mean_absolute_percentage_error: 20.9951 - val_mse: 3.9838
# Epoch 51/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 784us/step - loss: 4.3978 - mae: 1.5502 - mean_absolute_percentage_error: 20.5455 - mse: 4.2788 - val_loss: 4.0325 - val_mae: 1.4568 - val_mean_absolute_percentage_error: 18.8874 - val_mse: 3.9173
# Epoch 52/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 760us/step - loss: 4.3757 - mae: 1.5447 - mean_absolute_percentage_error: 20.3570 - mse: 4.2588 - val_loss: 4.0306 - val_mae: 1.4929 - val_mean_absolute_percentage_error: 20.3385 - val_mse: 3.9117
# Epoch 53/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 756us/step - loss: 4.3242 - mae: 1.5351 - mean_absolute_percentage_error: 20.2535 - mse: 4.2062 - val_loss: 4.0368 - val_mae: 1.4908 - val_mean_absolute_percentage_error: 20.3412 - val_mse: 3.9172
# Epoch 54/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 790us/step - loss: 4.3714 - mae: 1.5409 - mean_absolute_percentage_error: 20.3480 - mse: 4.2543 - val_loss: 3.9897 - val_mae: 1.4705 - val_mean_absolute_percentage_error: 19.7542 - val_mse: 3.8697
# Epoch 55/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 861us/step - loss: 4.3633 - mae: 1.5418 - mean_absolute_percentage_error: 20.2920 - mse: 4.2449 - val_loss: 4.0656 - val_mae: 1.4763 - val_mean_absolute_percentage_error: 19.3862 - val_mse: 3.9486
# Epoch 56/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 825us/step - loss: 4.3539 - mae: 1.5346 - mean_absolute_percentage_error: 20.3023 - mse: 4.2363 - val_loss: 4.0232 - val_mae: 1.4658 - val_mean_absolute_percentage_error: 19.3147 - val_mse: 3.9036
# Epoch 57/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 783us/step - loss: 4.3756 - mae: 1.5430 - mean_absolute_percentage_error: 20.3244 - mse: 4.2570 - val_loss: 4.0676 - val_mae: 1.4936 - val_mean_absolute_percentage_error: 20.3215 - val_mse: 3.9485
# Epoch 58/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 788us/step - loss: 4.3907 - mae: 1.5431 - mean_absolute_percentage_error: 20.3593 - mse: 4.2719 - val_loss: 4.0059 - val_mae: 1.4728 - val_mean_absolute_percentage_error: 19.6852 - val_mse: 3.8892
# Epoch 59/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 851us/step - loss: 4.3402 - mae: 1.5347 - mean_absolute_percentage_error: 20.3155 - mse: 4.2225 - val_loss: 4.0408 - val_mae: 1.4651 - val_mean_absolute_percentage_error: 19.1318 - val_mse: 3.9247
# Epoch 60/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 876us/step - loss: 4.3367 - mae: 1.5362 - mean_absolute_percentage_error: 20.3277 - mse: 4.2193 - val_loss: 3.9791 - val_mae: 1.4704 - val_mean_absolute_percentage_error: 19.7983 - val_mse: 3.8586
# Epoch 61/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 918us/step - loss: 4.3691 - mae: 1.5418 - mean_absolute_percentage_error: 20.3789 - mse: 4.2507 - val_loss: 4.0453 - val_mae: 1.4963 - val_mean_absolute_percentage_error: 20.4371 - val_mse: 3.9259
# Epoch 62/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 815us/step - loss: 4.3436 - mae: 1.5382 - mean_absolute_percentage_error: 20.3323 - mse: 4.2246 - val_loss: 4.0444 - val_mae: 1.4742 - val_mean_absolute_percentage_error: 19.3745 - val_mse: 3.9233
# Epoch 63/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 833us/step - loss: 4.3239 - mae: 1.5302 - mean_absolute_percentage_error: 20.2457 - mse: 4.2048 - val_loss: 4.0119 - val_mae: 1.4785 - val_mean_absolute_percentage_error: 19.8891 - val_mse: 3.8927
# Epoch 64/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 807us/step - loss: 4.3486 - mae: 1.5386 - mean_absolute_percentage_error: 20.3402 - mse: 4.2282 - val_loss: 4.0053 - val_mae: 1.4509 - val_mean_absolute_percentage_error: 18.9853 - val_mse: 3.8873
# Epoch 65/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 815us/step - loss: 4.3455 - mae: 1.5376 - mean_absolute_percentage_error: 20.3316 - mse: 4.2270 - val_loss: 4.0067 - val_mae: 1.4520 - val_mean_absolute_percentage_error: 18.8702 - val_mse: 3.8891
# Epoch 66/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 809us/step - loss: 4.2930 - mae: 1.5289 - mean_absolute_percentage_error: 20.1829 - mse: 4.1735 - val_loss: 4.1129 - val_mae: 1.5114 - val_mean_absolute_percentage_error: 20.9164 - val_mse: 3.9940
# Epoch 67/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 800us/step - loss: 4.3956 - mae: 1.5471 - mean_absolute_percentage_error: 20.4205 - mse: 4.2740 - val_loss: 4.0241 - val_mae: 1.4697 - val_mean_absolute_percentage_error: 19.4915 - val_mse: 3.9056
# Epoch 68/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 803us/step - loss: 4.3644 - mae: 1.5374 - mean_absolute_percentage_error: 20.2972 - mse: 4.2452 - val_loss: 4.0361 - val_mae: 1.4867 - val_mean_absolute_percentage_error: 20.2264 - val_mse: 3.9155
# Epoch 69/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 793us/step - loss: 4.3503 - mae: 1.5381 - mean_absolute_percentage_error: 20.2732 - mse: 4.2301 - val_loss: 4.0091 - val_mae: 1.4557 - val_mean_absolute_percentage_error: 19.1101 - val_mse: 3.8878
# Epoch 70/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 806us/step - loss: 4.3891 - mae: 1.5418 - mean_absolute_percentage_error: 20.3158 - mse: 4.2667 - val_loss: 3.9768 - val_mae: 1.4594 - val_mean_absolute_percentage_error: 19.3929 - val_mse: 3.8557
# Epoch 71/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 813us/step - loss: 4.3429 - mae: 1.5368 - mean_absolute_percentage_error: 20.2806 - mse: 4.2217 - val_loss: 4.0395 - val_mae: 1.4763 - val_mean_absolute_percentage_error: 19.5121 - val_mse: 3.9208
# Epoch 72/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 905us/step - loss: 4.3931 - mae: 1.5451 - mean_absolute_percentage_error: 20.4248 - mse: 4.2729 - val_loss: 4.0301 - val_mae: 1.4801 - val_mean_absolute_percentage_error: 19.8634 - val_mse: 3.9089
# Epoch 73/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 911us/step - loss: 4.3537 - mae: 1.5379 - mean_absolute_percentage_error: 20.3730 - mse: 4.2336 - val_loss: 4.0041 - val_mae: 1.4827 - val_mean_absolute_percentage_error: 20.1998 - val_mse: 3.8820
# Epoch 74/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 862us/step - loss: 4.3330 - mae: 1.5311 - mean_absolute_percentage_error: 20.2303 - mse: 4.2095 - val_loss: 4.1602 - val_mae: 1.5089 - val_mean_absolute_percentage_error: 20.0764 - val_mse: 4.0297
# Epoch 75/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 892us/step - loss: 4.3640 - mae: 1.5378 - mean_absolute_percentage_error: 20.2764 - mse: 4.2412 - val_loss: 3.9775 - val_mae: 1.4751 - val_mean_absolute_percentage_error: 19.9538 - val_mse: 3.8574
# Epoch 76/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 852us/step - loss: 4.3700 - mae: 1.5392 - mean_absolute_percentage_error: 20.2851 - mse: 4.2489 - val_loss: 4.1580 - val_mae: 1.5051 - val_mean_absolute_percentage_error: 20.6355 - val_mse: 4.0345
# Epoch 77/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 910us/step - loss: 4.2777 - mae: 1.5232 - mean_absolute_percentage_error: 20.1404 - mse: 4.1553 - val_loss: 4.1737 - val_mae: 1.5475 - val_mean_absolute_percentage_error: 21.7833 - val_mse: 4.0514
# Epoch 78/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 817us/step - loss: 4.3157 - mae: 1.5308 - mean_absolute_percentage_error: 20.1879 - mse: 4.1927 - val_loss: 4.0132 - val_mae: 1.4883 - val_mean_absolute_percentage_error: 20.2102 - val_mse: 3.8875
# Epoch 79/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 797us/step - loss: 4.3347 - mae: 1.5306 - mean_absolute_percentage_error: 20.1227 - mse: 4.2102 - val_loss: 4.0023 - val_mae: 1.4579 - val_mean_absolute_percentage_error: 19.2311 - val_mse: 3.8809
# Epoch 80/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 842us/step - loss: 4.3879 - mae: 1.5463 - mean_absolute_percentage_error: 20.4276 - mse: 4.2644 - val_loss: 4.0373 - val_mae: 1.4897 - val_mean_absolute_percentage_error: 20.2614 - val_mse: 3.9162
# Epoch 81/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 778us/step - loss: 4.3105 - mae: 1.5300 - mean_absolute_percentage_error: 20.2360 - mse: 4.1879 - val_loss: 4.0931 - val_mae: 1.5248 - val_mean_absolute_percentage_error: 21.2507 - val_mse: 3.9722
# Epoch 82/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 850us/step - loss: 4.3425 - mae: 1.5326 - mean_absolute_percentage_error: 20.2846 - mse: 4.2212 - val_loss: 3.9906 - val_mae: 1.4710 - val_mean_absolute_percentage_error: 19.7592 - val_mse: 3.8678
# Epoch 83/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 889us/step - loss: 4.3202 - mae: 1.5308 - mean_absolute_percentage_error: 20.2489 - mse: 4.1983 - val_loss: 4.0060 - val_mae: 1.4634 - val_mean_absolute_percentage_error: 19.4543 - val_mse: 3.8833
# Epoch 84/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 803us/step - loss: 4.2419 - mae: 1.5198 - mean_absolute_percentage_error: 20.0724 - mse: 4.1196 - val_loss: 4.0734 - val_mae: 1.4839 - val_mean_absolute_percentage_error: 19.6061 - val_mse: 3.9497
# Epoch 85/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 830us/step - loss: 4.3654 - mae: 1.5389 - mean_absolute_percentage_error: 20.2921 - mse: 4.2410 - val_loss: 4.0397 - val_mae: 1.4944 - val_mean_absolute_percentage_error: 20.5401 - val_mse: 3.9149
# Epoch 86/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 825us/step - loss: 4.2847 - mae: 1.5229 - mean_absolute_percentage_error: 20.1704 - mse: 4.1604 - val_loss: 4.0157 - val_mae: 1.4536 - val_mean_absolute_percentage_error: 18.8156 - val_mse: 3.8915
# Epoch 87/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 813us/step - loss: 4.2606 - mae: 1.5202 - mean_absolute_percentage_error: 20.0471 - mse: 4.1358 - val_loss: 4.0995 - val_mae: 1.5180 - val_mean_absolute_percentage_error: 20.6740 - val_mse: 3.9725
# Epoch 88/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 828us/step - loss: 4.3238 - mae: 1.5333 - mean_absolute_percentage_error: 20.3077 - mse: 4.1990 - val_loss: 4.0769 - val_mae: 1.5112 - val_mean_absolute_percentage_error: 20.8712 - val_mse: 3.9505
# Epoch 89/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 826us/step - loss: 4.3019 - mae: 1.5272 - mean_absolute_percentage_error: 20.1460 - mse: 4.1751 - val_loss: 3.9941 - val_mae: 1.4689 - val_mean_absolute_percentage_error: 19.5480 - val_mse: 3.8718
# Epoch 90/200
# 3320/3320 ━━━━━━━━━━━━━━━━━━━━ 3s 821us/step - loss: 4.3555 - mae: 1.5365 - mean_absolute_percentage_error: 20.3039 - mse: 4.2315 - val_loss: 3.9887 - val_mae: 1.4693 - val_mean_absolute_percentage_error: 19.7444 - val_mse: 3.8634

# %% [markdown]
# ### Analysing error metrics

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist['rmse'] = np.sqrt(hist['mse'])
hist['val_rmse'] = np.sqrt(hist['val_mse'])
hist.tail()
# Out:
#         loss       mae  mean_absolute_percentage_error       mse  val_loss  \
# 85  4.320138  1.528788                       20.209381  4.196465  4.015745
# 86  4.313213  1.528723                       20.185493  4.188449  4.099468
# 87  4.342552  1.533631                       20.261429  4.216986  4.076857
# 88  4.327382  1.530554                       20.235701  4.201473  3.994097
# 89  4.348473  1.534696                       20.262125  4.224289  3.988659
#
#      val_mae  val_mean_absolute_percentage_error   val_mse  epoch      rmse  \
# 85  1.453576                           18.815647  3.891513     85  2.048528
# 86  1.518007                           20.674013  3.972479     86  2.046570
# 87  1.511236                           20.871208  3.950465     87  2.053530
# 88  1.468883                           19.548035  3.871846     88  2.049750
# 89  1.469301                           19.744429  3.863396     89  2.055308
#
#     val_rmse
# 85  1.972692
# 86  1.993108
# 87  1.987578
# 88  1.967701
# 89  1.965552

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.title("Evolução das funções de perda durante o treinamento da rede")
plt.xlabel('Rodada')
plt.ylabel('Root Mean Square Error')
plt.plot(hist['epoch'], hist['rmse'], label='RMSE Treino')
plt.plot(hist['epoch'], hist['val_rmse'], label = 'RMSE Validação')
plt.legend()

plt.figure()
plt.xlabel('Rodada')
plt.ylabel('Mean Absolute Error')
plt.plot(hist['epoch'], hist['mae'], label='MAE Treino')
plt.plot(hist['epoch'], hist['val_mae'], label = 'MAE Validação')
plt.legend()

plt.show()

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# ### Preparing test dataframe

# %%
x_test = test
y_test = test.pop('bg+1:00')
print(x_test.shape)
x_test.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bg+1:00'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 2
#       1 x_test = test
# ----> 2 y_test = test.pop('bg+1:00')
#       3 print(x_test.shape)
#       4 x_test.head(5)
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/pandas/core/frame.py:5819, in DataFrame.pop(self, item)
#    5778 def pop(self, item: Hashable) -> Series:
#    5779     """
#    5780     Return item and drop from frame. Raise KeyError if not found.
#    5781
#    (...)
#    5817     3  monkey        NaN
#    5818     """
# -> 5819     return super().pop(item=item)
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/pandas/core/generic.py:947, in NDFrame.pop(self, item)
#     946 def pop(self, item: Hashable) -> Series | Any:
# --> 947     result = self[item]
#     948     del self[item]
#     950     return result
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'bg+1:00'

# %%
y_test.head(5)
# Out:
# 2     15.5
# 10    17.4
# 21     4.8
# 27    13.1
# 30     8.3
# Name: bg+1:00, dtype: float64

# %% [markdown]
# ### Running prediction

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# 1383/1383 ━━━━━━━━━━━━━━━━━━━━ 1s 446us/step
# [[12.063585 ]
#  [10.383258 ]
#  [ 6.0580263]
#  ...
#  [ 7.0308657]
#  [ 9.622009 ]
#  [11.005292 ]]

# %% [markdown]
# ### Calculating error metrics

# %%
mse = tf.keras.losses.MSE(y_test, y_pred).numpy().mean()
mae = tf.keras.losses.MAE(y_test, y_pred).numpy().mean()
rmse = np.sqrt(mse)

# %%
print(f"RMSE Test: {rmse}")
print(f"MSE Test: {mse}")
print(f"MAE Test: {mae}")
# Out:
# RMSE Test: 1.9570223093032837
# MSE Test: 3.8299365043640137
# MAE Test: 1.4489670991897583

# %% [markdown]
# ## Saving the model

# %%
model.save("brist1d.keras")

# %% [markdown]
# ## Loading and processing submission dataframe

# %%
df_submission = pd.read_csv('dataset/test.csv', header=0)
print(df_submission.shape)
df_submission.head(5)
# Out:
# (3644, 507)
#          id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_8459   p01  06:45:00      NaN      9.2      NaN      NaN     10.2
# 1  p01_8460   p01  11:25:00      NaN      NaN      9.9      NaN      NaN
# 2  p01_8461   p01  14:45:00      NaN      5.5      NaN      NaN      5.5
# 3  p01_8462   p01  04:30:00      NaN      3.4      NaN      NaN      3.9
# 4  p01_8463   p01  04:20:00      NaN      NaN      8.3      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:45  activity-0:40  activity-0:35  \
# 0      NaN      NaN  ...            NaN            NaN            NaN
# 1      9.4      NaN  ...            NaN            NaN            NaN
# 2      NaN      NaN  ...            NaN            NaN            NaN
# 3      NaN      NaN  ...            NaN            NaN            NaN
# 4     10.0      NaN  ...            NaN            NaN            NaN
#
#    activity-0:30  activity-0:25  activity-0:20  activity-0:15  activity-0:10  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN           Walk
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    activity-0:05  activity-0:00
# 0            NaN            NaN
# 1           Walk           Walk
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
# [5 rows x 507 columns]

# %%
df_submission = filter_desired_columns(df_submission, False)
df_submission.head(5)
# Out:
#          id p_num      time  bg-0:00  bg-0:05  bg-0:10  bg-0:15  bg-0:20  \
# 0  p01_8459   p01  06:45:00      9.6      NaN      NaN      9.4      NaN
# 1  p01_8460   p01  11:25:00      4.6      NaN      NaN      6.3      NaN
# 2  p01_8461   p01  14:45:00      8.0      NaN      NaN      8.3      NaN
# 3  p01_8462   p01  04:30:00      9.9      NaN      NaN      8.5      NaN
# 4  p01_8463   p01  04:20:00      5.3      NaN      NaN      3.7      NaN
#
#    bg-0:25  bg-0:30  ...  hr-0:15  hr-0:20  hr-0:25  hr-0:30  steps-0:00  \
# 0      NaN      NaN  ...     55.6     53.2     54.4     55.8         NaN
# 1      NaN      6.4  ...     95.6     91.6     93.5     91.1       532.0
# 2      NaN      8.1  ...     75.7     81.1     87.9     92.1        69.0
# 3      NaN      7.8  ...     59.5     58.5     61.2     60.7         0.0
# 4      NaN      3.2  ...     58.9     57.6     55.1     56.2         NaN
#
#    steps-0:05  steps-0:10  steps-0:15  cals-0:00  cals-0:05
# 0         NaN         NaN         0.0       6.06       4.90
# 1       377.0       547.0       411.0      32.43      24.57
# 2       283.0        27.0        10.0      10.16      19.76
# 3         NaN         NaN        14.0       4.80       4.90
# 4         NaN         NaN         NaN       4.80       4.80
#
# [5 rows x 31 columns]

# %%
df_submission[columns_to_fill] = df_submission[columns_to_fill].interpolate()
df_submission[columns_to_fill] = imputer.transform(df_submission[columns_to_fill])

# %%
df_submission['minutes_since_start'] = pd.to_datetime(df_submission['time'], format="%H:%M:%S").dt.hour * 60 + pd.to_datetime(df_submission['time'], format="%H:%M:%S").dt.minute
df_submission = df_submission.drop(columns=['time'])
df_submission["time_sin"] = np.sin(2 * np.pi / 1440 * df_submission['minutes_since_start']) + 2
df_submission["time_cos"] = np.cos(2 * np.pi / 1440 * df_submission['minutes_since_start']) + 2
df_submission = df_submission.drop(columns=['minutes_since_start'])
df_submission.head(5)
# Out:
#          id p_num  bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25  \
# 0  p01_8459   p01      9.6  8.246322  8.33178      9.4  8.258647  8.430463
# 1  p01_8460   p01      4.6  8.246322  8.33178      6.3  8.258647  8.430463
# 2  p01_8461   p01      8.0  8.246322  8.33178      8.3  8.258647  8.430463
# 3  p01_8462   p01      9.9  8.246322  8.33178      8.5  8.258647  8.430463
# 4  p01_8463   p01      5.3  8.246322  8.33178      3.7  8.258647  8.430463
#
#     bg-0:30  bg-0:35  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.282302     10.5  ...     54.4     55.8   44.927039   43.967174
# 1  6.400000     10.2  ...     93.5     91.1  532.000000  377.000000
# 2  8.100000      9.9  ...     87.9     92.1   69.000000  283.000000
# 3  7.800000      9.6  ...     61.2     60.7    0.000000  205.333333
# 4  3.200000      9.3  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 32 columns]

# %%
identifiers_submission = df_submission[cols_to_pop].copy()
df_submission = df_submission.drop(columns=cols_to_pop)
df_submission.head(5)
# Out:
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25   bg-0:30  bg-0:35  \
# 0      9.6  8.246322  8.33178      9.4  8.258647  8.430463  8.282302     10.5
# 1      4.6  8.246322  8.33178      6.3  8.258647  8.430463  6.400000     10.2
# 2      8.0  8.246322  8.33178      8.3  8.258647  8.430463  8.100000      9.9
# 3      9.9  8.246322  8.33178      8.5  8.258647  8.430463  7.800000      9.6
# 4      5.3  8.246322  8.33178      3.7  8.258647  8.430463  3.200000      9.3
#
#     bg-0:40   bg-0:45  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.412561  8.283803  ...     54.4     55.8   44.927039   43.967174
# 1  8.412561  4.500000  ...     93.5     91.1  532.000000  377.000000
# 2  8.412561  6.600000  ...     87.9     92.1   69.000000  283.000000
# 3  8.412561  7.500000  ...     61.2     60.7    0.000000  205.333333
# 4  8.412561  3.400000  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 30 columns]

# %%
print(df_submission.shape)
df_submission.head(5)
# Out:
# (3644, 30)
#    bg-0:00   bg-0:05  bg-0:10  bg-0:15   bg-0:20   bg-0:25   bg-0:30  bg-0:35  \
# 0      9.6  8.246322  8.33178      9.4  8.258647  8.430463  8.282302     10.5
# 1      4.6  8.246322  8.33178      6.3  8.258647  8.430463  6.400000     10.2
# 2      8.0  8.246322  8.33178      8.3  8.258647  8.430463  8.100000      9.9
# 3      9.9  8.246322  8.33178      8.5  8.258647  8.430463  7.800000      9.6
# 4      5.3  8.246322  8.33178      3.7  8.258647  8.430463  3.200000      9.3
#
#     bg-0:40   bg-0:45  ...  hr-0:25  hr-0:30  steps-0:00  steps-0:05  \
# 0  8.412561  8.283803  ...     54.4     55.8   44.927039   43.967174
# 1  8.412561  4.500000  ...     93.5     91.1  532.000000  377.000000
# 2  8.412561  6.600000  ...     87.9     92.1   69.000000  283.000000
# 3  8.412561  7.500000  ...     61.2     60.7    0.000000  205.333333
# 4  8.412561  3.400000  ...     55.1     56.2    0.000000  127.666667
#
#    steps-0:10  steps-0:15  cals-0:00  cals-0:05  time_sin  time_cos
# 0    43.96972         0.0       6.06       4.90  2.980785  1.804910
# 1   547.00000       411.0      32.43      24.57  2.152123  1.011638
# 2    27.00000        10.0      10.16      19.76  1.340654  1.248160
# 3    63.00000        14.0       4.80       4.90  2.923880  2.382683
# 4    99.00000        57.0       4.80       4.80  2.906308  2.422618
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Predicting submission dataset

# %%
# model = tf.keras.models.load_model("brist1d.keras")
# Out:
# I0000 00:00:1732054676.487856   64839 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2609 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
y_submission = model.predict(df_submission)
df_pred_submission = pd.DataFrame(y_submission, columns=['bg+1:00'])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732054751.118594   65451 service.cc:148] XLA service 0x7255cc003220 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732054751.118805   65451 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2024-11-19 19:19:11.126557: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1732054751.158421   65451 cuda_dnn.cc:529] Loaded cuDNN version 90501
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 1:08 607ms/step
# I0000 00:00:1732054751.653514   65451 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %% [markdown]
# ### Joining identifiers

# %%
df_pred_submission = pd.concat([identifiers_submission, df_pred_submission], axis=1)
df_pred_submission.pop('p_num')
df_pred_submission.head(5)
# Out:
#          id    bg+1:00
# 0  p01_8459   9.406324
# 1  p01_8460   5.929535
# 2  p01_8461   6.582970
# 3  p01_8462  10.549760
# 4  p01_8463   7.325231

# %% [markdown]
# ### Exporting submission results

# %%
df_pred_submission.to_csv("dataset/predictions.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df_pred_submission.to_csv("/kaggle/working/predictions.csv", index=False)
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/@pessoal/brist1d/.venv/lib/python3.12/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '/kaggle/working'
